# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset, random_split
from torchvision import transforms, models
from PIL import Image
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import cv2
import numpy as np

# 自定义数据集类：假定数据集目录下每个子文件夹对应一个类别
class EnhancedDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        # 按文件夹名称排序得到类别列表
        self.classes = sorted(os.listdir(root_dir))
        self.class_to_idx = {cls: i for i, cls in enumerate(self.classes)}
        self.images = self._load_images()

    def _load_images(self):
        images = []
        for cls in self.classes:
            cls_path = os.path.join(self.root_dir, cls)
            for img_name in os.listdir(cls_path):
                if img_name.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp')):
                    img_path = os.path.join(cls_path, img_name)
                    images.append((img_path, self.class_to_idx[cls]))
        print(f"共加载 {len(images)} 张图片，共 {len(self.classes)} 个类别。")
        return images

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img_path, label = self.images[idx]
        image = Image.open(img_path).convert('RGB')
        if self.transform:
            image = self.transform(image)
        return image, label

# ---------------- Grad-CAM 实现 -------------------
class GradCAM:
    def __init__(self, model, target_layer):
        """
        model: 训练好的模型
        target_layer: 需要观察的卷积层
        """
        self.model = model
        self.target_layer = target_layer
        self.gradients = None
        self.activations = None
        self.hook_handles = []
        self._register_hooks()

    def _register_hooks(self):
        def forward_hook(module, input, output):
            self.activations = output.detach()

        def backward_hook(module, grad_in, grad_out):
            self.gradients = grad_out[0].detach()

        self.hook_handles.append(self.target_layer.register_forward_hook(forward_hook))
        self.hook_handles.append(self.target_layer.register_backward_hook(backward_hook))

    def remove_hooks(self):
        for handle in self.hook_handles:
            handle.remove()

    def __call__(self, input_image, target_class=None):
        """
        input_image: Tensor, 尺寸为 [1, C, H, W]
        target_class: 指定类别索引；若为 None，则取模型预测类别
        返回：cam (numpy 数组，归一化到 [0,1]) 和 target_class
        """
        output = self.model(input_image)
        if target_class is None:
            target_class = output.argmax(dim=1).item()
        loss = output[0, target_class]
        self.model.zero_grad()
        loss.backward(retain_graph=True)

        # 获取梯度和特征图，尺寸为 [C, H', W']
        gradients = self.gradients[0]
        activations = self.activations[0]
        # 计算每个通道的重要性权重：对梯度在空间上求平均
        weights = torch.mean(gradients, dim=(1, 2))
        # 计算加权求和
        cam = torch.zeros(activations.shape[1:], dtype=activations.dtype, device=activations.device)
        for i, w in enumerate(weights):
            cam += w * activations[i, :, :]
        cam = torch.clamp(cam, min=0)  # 保留正值部分
        # 归一化
        cam -= cam.min()
        cam /= (cam.max() + 1e-8)
        cam = cam.cpu().numpy()
        return cam, target_class

# ---------------- 辅助函数：生成渐进式热力图叠加效果 -------------------
def get_progressive_overlays(original_image, cam, steps=10):
    """
    original_image: PIL Image（RGB），调整为目标尺寸（例如 224x224）
    cam: 归一化后的热力图（二维 numpy 数组，尺寸为 [H', W']）
    steps: 渐进展示的步数
    返回：叠加效果列表和对应的 alpha 值
    """
    img = np.array(original_image)
    # 将 cam 调整到原图尺寸
    heatmap = cv2.resize(cam, (img.shape[1], img.shape[0]))
    heatmap = np.uint8(255 * heatmap)
    # 应用 Jet 色图
    heatmap_color = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)
    # cv2 默认颜色空间为 BGR，转换为 RGB
    heatmap_color = cv2.cvtColor(heatmap_color, cv2.COLOR_BGR2RGB)
    
    alphas = np.linspace(0, 1, steps)
    overlays = []
    for alpha in alphas:
        overlay = cv2.addWeighted(img, 1 - alpha, heatmap_color, alpha, 0)
        overlays.append(overlay)
    return overlays, alphas

# ---------------- 多层 Grad-CAM 可视化 -------------------
def generate_and_show_gradcam_layers(model, dataset, test_subset, device, sample_idx=0, steps=10):
    """
    从测试子集中选取一张图片，依次对指定的多个层生成 Grad-CAM，
    并以渐进式效果展示（网格中每一行对应一个目标层）。
    sample_idx: 测试子集中的样本索引（默认为 0）
    """
    # 获取原始图片路径与标签（用于可视化时加载原图）
    original_idx = test_subset.indices[sample_idx]
    img_path, label = dataset.images[original_idx]
    original_image = Image.open(img_path).convert("RGB")
    
    # 定义用于 Grad-CAM 的预处理（仅调整尺寸，不做数据增强）
    gradcam_transform = transforms.Compose([
         transforms.Resize((224, 224)),
         transforms.ToTensor(),
    ])
    input_tensor = gradcam_transform(original_image).unsqueeze(0).to(device)
    
    # 将原图调整为与输入一致的尺寸
    original_resized = original_image.resize((224, 224))
    
    # 选择部分关键层（可根据需要调整）
    target_layers = {
       "layer1": model.layer1[-1],
       "layer2": model.layer2[-1],
       "layer3": model.layer3[-1],
       "layer4": model.layer4[-1],
    }
    
    overlays_dict = {}
    # 对每个目标层计算 Grad-CAM
    for name, layer in target_layers.items():
         grad_cam = GradCAM(model, layer)
         cam, target_class = grad_cam(input_tensor)
         grad_cam.remove_hooks()
         overlays, alphas = get_progressive_overlays(original_resized, cam, steps=steps)
         overlays_dict[name] = overlays
         print(f"{name} Grad-CAM 目标类别索引：{target_class}")
    
    # 在一个图中以网格形式展示各层的渐进式热力图
    num_layers = len(target_layers)
    fig, axes = plt.subplots(num_layers, steps, figsize=(3*steps, 3*num_layers))
    # 如果只有一行，确保 axes 是二维数组
    if num_layers == 1:
         axes = np.expand_dims(axes, axis=0)
    for row, (layer_name, overlays) in enumerate(overlays_dict.items()):
         for col, overlay in enumerate(overlays):
             ax = axes[row, col]
             ax.imshow(overlay)
             ax.axis('off')
             if col == 0:
                 ax.set_ylabel(layer_name, fontsize=12)
             if row == 0:
                 ax.set_title(f'alpha={alphas[col]:.2f}', fontsize=10)
    plt.suptitle("各层 Grad-CAM 渐进式热力图", fontsize=16)
    plt.tight_layout()
    plt.show()

# ---------------- 主训练及测试流程 -------------------
def train():
    # 判断是否可用 GPU
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(f"使用设备：{device}")

    # 数据预处理：调整图片大小为 224x224，并进行数据增强
    transform = transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.RandomRotation(degrees=30),
        transforms.RandomResizedCrop(224, scale=(0.8, 1.0)), 
        transforms.ToTensor(),
        transforms.GaussianBlur(5),
        transforms.RandomHorizontalFlip(),
    ])

    # 加载数据集（请确认路径正确）
    dataset = EnhancedDataset(root_dir=r"L:\常惠林\萎凋\自然萎凋\分类", transform=transform)
    total_size = len(dataset)
    train_size = int(0.6 * total_size)
    val_size = int(0.2 * total_size)
    test_size = total_size - train_size - val_size
    train_dataset, val_dataset, test_dataset = random_split(dataset, [train_size, val_size, test_size])
    print(f"训练集：{train_size}，验证集：{val_size}，测试集：{test_size}")

    # 创建数据加载器
    train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True, num_workers=0)
    val_loader = DataLoader(val_dataset, batch_size=64, shuffle=False, num_workers=0)
    test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False, num_workers=0)

    # 加载预训练的 ResNet50 模型
    model = models.resnet50(pretrained=True)
    # 修改最后一层全连接层，适应数据集类别数
    num_classes = len(dataset.classes)
    in_features = model.fc.in_features
    model.fc = nn.Linear(in_features, num_classes)
    model = model.to(device)

    # 定义损失函数和优化器
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=1e-5)

    # 训练配置
    num_epochs = 100
    best_val_acc = 0.0

    # 用于记录训练过程的指标
    train_loss_history = []
    train_acc_history = []
    val_loss_history = []
    val_acc_history = []

    for epoch in range(num_epochs):
        # 训练阶段
        model.train()
        running_loss = 0.0
        running_correct = 0
        total_train = 0
        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item() * images.size(0)
            _, preds = torch.max(outputs, 1)
            running_correct += (preds == labels).sum().item()
            total_train += labels.size(0)
        epoch_loss = running_loss / total_train
        epoch_acc = running_correct / total_train
        train_loss_history.append(epoch_loss)
        train_acc_history.append(epoch_acc)

        # 验证阶段
        model.eval()
        val_running_loss = 0.0
        val_running_correct = 0
        total_val = 0
        with torch.no_grad():
            for images, labels in val_loader:
                images, labels = images.to(device), labels.to(device)
                outputs = model(images)
                loss = criterion(outputs, labels)
                val_running_loss += loss.item() * images.size(0)
                _, preds = torch.max(outputs, 1)
                val_running_correct += (preds == labels).sum().item()
                total_val += labels.size(0)
        val_loss = val_running_loss / total_val
        val_acc = val_running_correct / total_val
        val_loss_history.append(val_loss)
        val_acc_history.append(val_acc)

        print(f"Epoch [{epoch+1}/{num_epochs}] | Train Loss: {epoch_loss:.4f} | Train Acc: {epoch_acc:.4f} | Val Loss: {val_loss:.4f} | Val Acc: {val_acc:.4f}")
        
        save_dir = r"L:\常惠林\code\result"
        os.makedirs(save_dir, exist_ok=True)
        # 保存验证集上表现最好的模型
        if val_acc > best_val_acc:
            best_val_acc = val_acc
            save_path = os.path.join(save_dir, "best_resnet50.pth")
            torch.save(model.state_dict(), save_path)
            print(f"保存最佳模型到: {save_path}")

    # 绘制训练/验证曲线
    plt.figure(figsize=(12, 5))
    plt.subplot(1,2,1)
    plt.plot(train_loss_history, label="Train Loss")
    plt.plot(val_loss_history, label="Val Loss")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.title("Loss Curve")
    plt.legend()

    plt.subplot(1,2,2)
    plt.plot(train_acc_history, label="Train Acc")
    plt.plot(val_acc_history, label="Val Acc")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.title("Accuracy Curve")
    plt.legend()
    plt.show()

    # 测试阶段
    model.load_state_dict(torch.load(os.path.join(r"L:\常惠林\code\result", "best_resnet50.pth"), map_location=device))
    model.eval()
    correct = 0
    total = 0
    all_preds = []
    all_labels = []
    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            _, preds = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (preds == labels).sum().item()
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
    test_acc = 100 * correct / total
    print(f"Test Accuracy: {test_acc:.2f}%")

    # 计算混淆矩阵并显示
    cm = confusion_matrix(all_labels, all_preds)
    print("混淆矩阵：")
    print(cm)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=dataset.classes)
    disp.plot(cmap=plt.cm.Blues)
    plt.title("Confusion Matrix")
    plt.show()

    # ---------------- 多层 Grad-CAM 可视化 ----------------
    # 这里展示了部分关键层的 Grad-CAM（非全部中间层），并以渐进式效果显示
    generate_and_show_gradcam_layers(model, dataset, test_dataset, device, sample_idx=0, steps=10)

if __name__ == "__main__":
    train()
# Out:
# 使用设备：cuda
# 共加载 5616 张图片，共 3 个类别。
# 训练集：3369，验证集：1123，测试集：1124
# c:\Users\enine\anaconda3\envs\changhl\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\enine\anaconda3\envs\changhl\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Epoch [1/100] | Train Loss: 1.0391 | Train Acc: 0.4574 | Val Loss: 0.9700 | Val Acc: 0.5601
# 保存最佳模型到: L:\常惠林\code\result\best_resnet50.pth
# Epoch [2/100] | Train Loss: 0.8946 | Train Acc: 0.5862 | Val Loss: 0.8429 | Val Acc: 0.6126
# 保存最佳模型到: L:\常惠林\code\result\best_resnet50.pth
# Epoch [3/100] | Train Loss: 0.7849 | Train Acc: 0.6444 | Val Loss: 0.7735 | Val Acc: 0.6429
# 保存最佳模型到: L:\常惠林\code\result\best_resnet50.pth
# Epoch [4/100] | Train Loss: 0.7009 | Train Acc: 0.6860 | Val Loss: 0.7078 | Val Acc: 0.6839
# 保存最佳模型到: L:\常惠林\code\result\best_resnet50.pth
# Epoch [5/100] | Train Loss: 0.6419 | Train Acc: 0.7073 | Val Loss: 0.6637 | Val Acc: 0.7142
# 保存最佳模型到: L:\常惠林\code\result\best_resnet50.pth
# Epoch [6/100] | Train Loss: 0.5766 | Train Acc: 0.7640 | Val Loss: 0.6116 | Val Acc: 0.7106
# Epoch [7/100] | Train Loss: 0.5291 | Train Acc: 0.7786 | Val Loss: 0.5854 | Val Acc: 0.7427
# 保存最佳模型到: L:\常惠林\code\result\best_resnet50.pth
# Epoch [8/100] | Train Loss: 0.4598 | Train Acc: 0.8195 | Val Loss: 0.5285 | Val Acc: 0.7658
# 保存最佳模型到: L:\常惠林\code\result\best_resnet50.pth
# Epoch [9/100] | Train Loss: 0.4184 | Train Acc: 0.8323 | Val Loss: 0.5044 | Val Acc: 0.7827
# 保存最佳模型到: L:\常惠林\code\result\best_resnet50.pth
# Epoch [10/100] | Train Loss: 0.3684 | Train Acc: 0.8587 | Val Loss: 0.4789 | Val Acc: 0.7863
# 保存最佳模型到: L:\常惠林\code\result\best_resnet50.pth
# Epoch [11/100] | Train Loss: 0.3255 | Train Acc: 0.8706 | Val Loss: 0.4220 | Val Acc: 0.8148
# 保存最佳模型到: L:\常惠林\code\result\best_resnet50.pth
# Epoch [12/100] | Train Loss: 0.2819 | Train Acc: 0.8964 | Val Loss: 0.4342 | Val Acc: 0.8210
# 保存最佳模型到: L:\常惠林\code\result\best_resnet50.pth
# Epoch [13/100] | Train Loss: 0.2544 | Train Acc: 0.9112 | Val Loss: 0.3948 | Val Acc: 0.8468
# 保存最佳模型到: L:\常惠林\code\result\best_resnet50.pth
# Epoch [14/100] | Train Loss: 0.2293 | Train Acc: 0.9133 | Val Loss: 0.4044 | Val Acc: 0.8290
# Epoch [15/100] | Train Loss: 0.2083 | Train Acc: 0.9210 | Val Loss: 0.3515 | Val Acc: 0.8593
# 保存最佳模型到: L:\常惠林\code\result\best_resnet50.pth
# Epoch [16/100] | Train Loss: 0.1791 | Train Acc: 0.9362 | Val Loss: 0.3584 | Val Acc: 0.8522
# Epoch [17/100] | Train Loss: 0.1725 | Train Acc: 0.9350 | Val Loss: 0.3458 | Val Acc: 0.8691
# 保存最佳模型到: L:\常惠林\code\result\best_resnet50.pth
# Epoch [18/100] | Train Loss: 0.1527 | Train Acc: 0.9495 | Val Loss: 0.3527 | Val Acc: 0.8638
# Epoch [19/100] | Train Loss: 0.1263 | Train Acc: 0.9608 | Val Loss: 0.3411 | Val Acc: 0.8718
# 保存最佳模型到: L:\常惠林\code\result\best_resnet50.pth
# Epoch [20/100] | Train Loss: 0.1185 | Train Acc: 0.9608 | Val Loss: 0.3125 | Val Acc: 0.8780
# 保存最佳模型到: L:\常惠林\code\result\best_resnet50.pth
# Epoch [21/100] | Train Loss: 0.1099 | Train Acc: 0.9638 | Val Loss: 0.3133 | Val Acc: 0.8789
# 保存最佳模型到: L:\常惠林\code\result\best_resnet50.pth
# Epoch [22/100] | Train Loss: 0.0957 | Train Acc: 0.9730 | Val Loss: 0.3101 | Val Acc: 0.8825
# 保存最佳模型到: L:\常惠林\code\result\best_resnet50.pth
# Epoch [23/100] | Train Loss: 0.0860 | Train Acc: 0.9754 | Val Loss: 0.3075 | Val Acc: 0.8798
# Epoch [24/100] | Train Loss: 0.0767 | Train Acc: 0.9798 | Val Loss: 0.2970 | Val Acc: 0.8940
# 保存最佳模型到: L:\常惠林\code\result\best_resnet50.pth
# Epoch [25/100] | Train Loss: 0.0696 | Train Acc: 0.9777 | Val Loss: 0.2606 | Val Acc: 0.9047
# 保存最佳模型到: L:\常惠林\code\result\best_resnet50.pth
# Epoch [26/100] | Train Loss: 0.0691 | Train Acc: 0.9810 | Val Loss: 0.2834 | Val Acc: 0.8976
# Epoch [27/100] | Train Loss: 0.0613 | Train Acc: 0.9834 | Val Loss: 0.2800 | Val Acc: 0.8985
# Epoch [28/100] | Train Loss: 0.0616 | Train Acc: 0.9810 | Val Loss: 0.2761 | Val Acc: 0.8896
# Epoch [29/100] | Train Loss: 0.0590 | Train Acc: 0.9828 | Val Loss: 0.2864 | Val Acc: 0.9163
# 保存最佳模型到: L:\常惠林\code\result\best_resnet50.pth
# Epoch [30/100] | Train Loss: 0.0552 | Train Acc: 0.9846 | Val Loss: 0.2386 | Val Acc: 0.9154
# Epoch [31/100] | Train Loss: 0.0549 | Train Acc: 0.9819 | Val Loss: 0.2346 | Val Acc: 0.9118
# Epoch [32/100] | Train Loss: 0.0518 | Train Acc: 0.9866 | Val Loss: 0.2714 | Val Acc: 0.9065
# Epoch [33/100] | Train Loss: 0.0448 | Train Acc: 0.9872 | Val Loss: 0.2200 | Val Acc: 0.9207
# 保存最佳模型到: L:\常惠林\code\result\best_resnet50.pth
# Epoch [34/100] | Train Loss: 0.0380 | Train Acc: 0.9902 | Val Loss: 0.2650 | Val Acc: 0.9083
# Epoch [35/100] | Train Loss: 0.0430 | Train Acc: 0.9858 | Val Loss: 0.2722 | Val Acc: 0.9065
# Epoch [36/100] | Train Loss: 0.0352 | Train Acc: 0.9908 | Val Loss: 0.2526 | Val Acc: 0.9065
# Epoch [37/100] | Train Loss: 0.0360 | Train Acc: 0.9899 | Val Loss: 0.2450 | Val Acc: 0.9127
# Epoch [38/100] | Train Loss: 0.0331 | Train Acc: 0.9941 | Val Loss: 0.2376 | Val Acc: 0.9110
# Epoch [39/100] | Train Loss: 0.0306 | Train Acc: 0.9917 | Val Loss: 0.2518 | Val Acc: 0.9092
# Epoch [40/100] | Train Loss: 0.0269 | Train Acc: 0.9938 | Val Loss: 0.2486 | Val Acc: 0.9110
# Epoch [41/100] | Train Loss: 0.0226 | Train Acc: 0.9967 | Val Loss: 0.2297 | Val Acc: 0.9207
# Epoch [42/100] | Train Loss: 0.0299 | Train Acc: 0.9914 | Val Loss: 0.2444 | Val Acc: 0.9181
# Epoch [43/100] | Train Loss: 0.0263 | Train Acc: 0.9935 | Val Loss: 0.2465 | Val Acc: 0.9199
# Epoch [44/100] | Train Loss: 0.0275 | Train Acc: 0.9929 | Val Loss: 0.2272 | Val Acc: 0.9305
# 保存最佳模型到: L:\常惠林\code\result\best_resnet50.pth
# Epoch [45/100] | Train Loss: 0.0222 | Train Acc: 0.9955 | Val Loss: 0.2132 | Val Acc: 0.9270
# Epoch [46/100] | Train Loss: 0.0261 | Train Acc: 0.9920 | Val Loss: 0.2733 | Val Acc: 0.9029
# Epoch [47/100] | Train Loss: 0.0226 | Train Acc: 0.9947 | Val Loss: 0.2226 | Val Acc: 0.9314
# 保存最佳模型到: L:\常惠林\code\result\best_resnet50.pth
# Epoch [48/100] | Train Loss: 0.0223 | Train Acc: 0.9944 | Val Loss: 0.2421 | Val Acc: 0.9341
# 保存最佳模型到: L:\常惠林\code\result\best_resnet50.pth
# Epoch [49/100] | Train Loss: 0.0227 | Train Acc: 0.9929 | Val Loss: 0.2302 | Val Acc: 0.9270
# Epoch [50/100] | Train Loss: 0.0230 | Train Acc: 0.9938 | Val Loss: 0.2751 | Val Acc: 0.9172
# Epoch [51/100] | Train Loss: 0.0164 | Train Acc: 0.9961 | Val Loss: 0.1901 | Val Acc: 0.9305
# Epoch [52/100] | Train Loss: 0.0182 | Train Acc: 0.9961 | Val Loss: 0.2015 | Val Acc: 0.9297
# Epoch [53/100] | Train Loss: 0.0159 | Train Acc: 0.9970 | Val Loss: 0.2507 | Val Acc: 0.9234
# Epoch [54/100] | Train Loss: 0.0185 | Train Acc: 0.9964 | Val Loss: 0.2021 | Val Acc: 0.9341
# Epoch [55/100] | Train Loss: 0.0171 | Train Acc: 0.9955 | Val Loss: 0.2161 | Val Acc: 0.9305
# Epoch [56/100] | Train Loss: 0.0185 | Train Acc: 0.9955 | Val Loss: 0.2578 | Val Acc: 0.9216
# Epoch [57/100] | Train Loss: 0.0143 | Train Acc: 0.9961 | Val Loss: 0.2348 | Val Acc: 0.9207
# Epoch [58/100] | Train Loss: 0.0110 | Train Acc: 0.9988 | Val Loss: 0.2418 | Val Acc: 0.9154
# Epoch [59/100] | Train Loss: 0.0164 | Train Acc: 0.9967 | Val Loss: 0.2118 | Val Acc: 0.9350
# 保存最佳模型到: L:\常惠林\code\result\best_resnet50.pth
# Epoch [60/100] | Train Loss: 0.0132 | Train Acc: 0.9970 | Val Loss: 0.1930 | Val Acc: 0.9403
# 保存最佳模型到: L:\常惠林\code\result\best_resnet50.pth
# Epoch [61/100] | Train Loss: 0.0127 | Train Acc: 0.9958 | Val Loss: 0.2189 | Val Acc: 0.9288
# Epoch [62/100] | Train Loss: 0.0144 | Train Acc: 0.9982 | Val Loss: 0.2028 | Val Acc: 0.9323
# Epoch [63/100] | Train Loss: 0.0154 | Train Acc: 0.9964 | Val Loss: 0.2109 | Val Acc: 0.9314
# Epoch [64/100] | Train Loss: 0.0126 | Train Acc: 0.9973 | Val Loss: 0.2385 | Val Acc: 0.9305
# Epoch [65/100] | Train Loss: 0.0132 | Train Acc: 0.9964 | Val Loss: 0.2627 | Val Acc: 0.9261
# Epoch [66/100] | Train Loss: 0.0102 | Train Acc: 0.9982 | Val Loss: 0.2144 | Val Acc: 0.9270
# Epoch [67/100] | Train Loss: 0.0116 | Train Acc: 0.9979 | Val Loss: 0.2035 | Val Acc: 0.9297
# Epoch [68/100] | Train Loss: 0.0082 | Train Acc: 0.9994 | Val Loss: 0.2520 | Val Acc: 0.9190
# Epoch [69/100] | Train Loss: 0.0106 | Train Acc: 0.9973 | Val Loss: 0.1884 | Val Acc: 0.9421
# 保存最佳模型到: L:\常惠林\code\result\best_resnet50.pth
# Epoch [70/100] | Train Loss: 0.0095 | Train Acc: 0.9970 | Val Loss: 0.2028 | Val Acc: 0.9386
# Epoch [71/100] | Train Loss: 0.0091 | Train Acc: 0.9982 | Val Loss: 0.2072 | Val Acc: 0.9386
# Epoch [72/100] | Train Loss: 0.0121 | Train Acc: 0.9967 | Val Loss: 0.2208 | Val Acc: 0.9412
# Epoch [73/100] | Train Loss: 0.0094 | Train Acc: 0.9976 | Val Loss: 0.1949 | Val Acc: 0.9350
# Epoch [74/100] | Train Loss: 0.0103 | Train Acc: 0.9985 | Val Loss: 0.2221 | Val Acc: 0.9341
# Epoch [75/100] | Train Loss: 0.0114 | Train Acc: 0.9958 | Val Loss: 0.1941 | Val Acc: 0.9394
# Epoch [76/100] | Train Loss: 0.0135 | Train Acc: 0.9967 | Val Loss: 0.1989 | Val Acc: 0.9377
# Epoch [77/100] | Train Loss: 0.0109 | Train Acc: 0.9973 | Val Loss: 0.1924 | Val Acc: 0.9261
# Epoch [78/100] | Train Loss: 0.0078 | Train Acc: 0.9982 | Val Loss: 0.2112 | Val Acc: 0.9341
# Epoch [79/100] | Train Loss: 0.0076 | Train Acc: 0.9982 | Val Loss: 0.2044 | Val Acc: 0.9314
# Epoch [80/100] | Train Loss: 0.0070 | Train Acc: 0.9982 | Val Loss: 0.1814 | Val Acc: 0.9386
# Epoch [81/100] | Train Loss: 0.0082 | Train Acc: 0.9982 | Val Loss: 0.2118 | Val Acc: 0.9288
# Epoch [82/100] | Train Loss: 0.0071 | Train Acc: 0.9985 | Val Loss: 0.1824 | Val Acc: 0.9492
# 保存最佳模型到: L:\常惠林\code\result\best_resnet50.pth
# Epoch [83/100] | Train Loss: 0.0067 | Train Acc: 0.9994 | Val Loss: 0.1970 | Val Acc: 0.9386
# Epoch [84/100] | Train Loss: 0.0065 | Train Acc: 0.9994 | Val Loss: 0.1766 | Val Acc: 0.9466
# Epoch [85/100] | Train Loss: 0.0072 | Train Acc: 0.9979 | Val Loss: 0.1732 | Val Acc: 0.9430
# Epoch [86/100] | Train Loss: 0.0064 | Train Acc: 0.9988 | Val Loss: 0.1945 | Val Acc: 0.9448
# Epoch [87/100] | Train Loss: 0.0078 | Train Acc: 0.9982 | Val Loss: 0.2091 | Val Acc: 0.9421
# Epoch [88/100] | Train Loss: 0.0081 | Train Acc: 0.9982 | Val Loss: 0.1981 | Val Acc: 0.9386
# Epoch [89/100] | Train Loss: 0.0056 | Train Acc: 0.9991 | Val Loss: 0.1771 | Val Acc: 0.9475
# Epoch [90/100] | Train Loss: 0.0074 | Train Acc: 0.9982 | Val Loss: 0.1972 | Val Acc: 0.9359
# Epoch [91/100] | Train Loss: 0.0062 | Train Acc: 0.9985 | Val Loss: 0.2085 | Val Acc: 0.9377
# Epoch [92/100] | Train Loss: 0.0078 | Train Acc: 0.9979 | Val Loss: 0.2005 | Val Acc: 0.9394
# Epoch [93/100] | Train Loss: 0.0087 | Train Acc: 0.9970 | Val Loss: 0.2107 | Val Acc: 0.9359
# Epoch [94/100] | Train Loss: 0.0053 | Train Acc: 0.9985 | Val Loss: 0.2279 | Val Acc: 0.9439
# Epoch [95/100] | Train Loss: 0.0058 | Train Acc: 0.9976 | Val Loss: 0.1944 | Val Acc: 0.9448
# Epoch [96/100] | Train Loss: 0.0047 | Train Acc: 0.9994 | Val Loss: 0.1936 | Val Acc: 0.9403
# Epoch [97/100] | Train Loss: 0.0049 | Train Acc: 0.9988 | Val Loss: 0.1784 | Val Acc: 0.9546
# 保存最佳模型到: L:\常惠林\code\result\best_resnet50.pth
# Epoch [98/100] | Train Loss: 0.0059 | Train Acc: 0.9994 | Val Loss: 0.2088 | Val Acc: 0.9421
# Epoch [99/100] | Train Loss: 0.0058 | Train Acc: 0.9985 | Val Loss: 0.2032 | Val Acc: 0.9377
# Epoch [100/100] | Train Loss: 0.0032 | Train Acc: 1.0000 | Val Loss: 0.2216 | Val Acc: 0.9510
# C:\Users\enine\AppData\Local\Temp\ipykernel_31560\3972355229.py:309: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(os.path.join(r"L:\常惠林\code\result", "best_resnet50.pth"), map_location=device))
# Test Accuracy: 93.86%
# 混淆矩阵：
# [[397  28   5]
#  [ 25 318   9]
#  [  0   2 340]]
# layer1 Grad-CAM 目标类别索引：0
# layer2 Grad-CAM 目标类别索引：0
# layer3 Grad-CAM 目标类别索引：0
# layer4 Grad-CAM 目标类别索引：0
# c:\Users\enine\anaconda3\envs\changhl\Lib\site-packages\torch\nn\modules\module.py:1827: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# C:\Users\enine\AppData\Local\Temp\ipykernel_31560\3972355229.py:181: UserWarning: Glyph 21508 (\N{CJK UNIFIED IDEOGRAPH-5404}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\enine\AppData\Local\Temp\ipykernel_31560\3972355229.py:181: UserWarning: Glyph 23618 (\N{CJK UNIFIED IDEOGRAPH-5C42}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\enine\AppData\Local\Temp\ipykernel_31560\3972355229.py:181: UserWarning: Glyph 28176 (\N{CJK UNIFIED IDEOGRAPH-6E10}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\enine\AppData\Local\Temp\ipykernel_31560\3972355229.py:181: UserWarning: Glyph 36827 (\N{CJK UNIFIED IDEOGRAPH-8FDB}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\enine\AppData\Local\Temp\ipykernel_31560\3972355229.py:181: UserWarning: Glyph 24335 (\N{CJK UNIFIED IDEOGRAPH-5F0F}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\enine\AppData\Local\Temp\ipykernel_31560\3972355229.py:181: UserWarning: Glyph 28909 (\N{CJK UNIFIED IDEOGRAPH-70ED}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\enine\AppData\Local\Temp\ipykernel_31560\3972355229.py:181: UserWarning: Glyph 21147 (\N{CJK UNIFIED IDEOGRAPH-529B}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\enine\AppData\Local\Temp\ipykernel_31560\3972355229.py:181: UserWarning: Glyph 22270 (\N{CJK UNIFIED IDEOGRAPH-56FE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# c:\Users\enine\anaconda3\envs\changhl\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 21508 (\N{CJK UNIFIED IDEOGRAPH-5404}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\enine\anaconda3\envs\changhl\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 23618 (\N{CJK UNIFIED IDEOGRAPH-5C42}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\enine\anaconda3\envs\changhl\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 28176 (\N{CJK UNIFIED IDEOGRAPH-6E10}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\enine\anaconda3\envs\changhl\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 36827 (\N{CJK UNIFIED IDEOGRAPH-8FDB}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\enine\anaconda3\envs\changhl\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 24335 (\N{CJK UNIFIED IDEOGRAPH-5F0F}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\enine\anaconda3\envs\changhl\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 28909 (\N{CJK UNIFIED IDEOGRAPH-70ED}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\enine\anaconda3\envs\changhl\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 21147 (\N{CJK UNIFIED IDEOGRAPH-529B}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\enine\anaconda3\envs\changhl\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 22270 (\N{CJK UNIFIED IDEOGRAPH-56FE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
