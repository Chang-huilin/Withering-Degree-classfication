# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
from torchvision import transforms
from torchvision.datasets import ImageFolder
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score
import matplotlib.pyplot as plt
import scipy.io as sio
from PIL import Image
import numpy as np
# Out:
# c:\Users\enine\anaconda3\envs\changhl\Lib\site-packages\torchvision\io\image.py:13: UserWarning: Failed to load image Python extension: '[WinError 127] 找不到指定的程序。'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(

# %%
# --------------------- 数据集 ---------------------
class MultiModalDataset(Dataset):
    def __init__(self, image_paths, nir_data, labels, transform=None):
        self.image_paths = image_paths
        self.nir_data = nir_data
        self.labels = labels
        self.transform = transform

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        img_path = self.image_paths[idx][0]  # 这里是路径
        img = Image.open(img_path).convert('RGB')  # 正确打开图片！

        if self.transform:
            img = self.transform(img)  # 对PIL Image应用transform
        
        nir = torch.tensor(self.nir_data[idx], dtype=torch.float32)
        label = torch.tensor(self.labels[idx], dtype=torch.long)
        
        return img, nir, label

# %%
# --------------------- 图像特征提取器（金字塔） ---------------------
class PyramidCNN(nn.Module):
    def __init__(self):
        super(PyramidCNN, self).__init__()
        self.layer1 = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=3, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )
        self.layer2 = nn.Sequential(
            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )
        self.layer3 = nn.Sequential(
            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.AdaptiveAvgPool2d((1, 1))
        )

    def forward(self, x):
        x = self.layer1(x)
        x = self.layer2(x)
        x = self.layer3(x)
        return x.view(x.size(0), -1)  # 确保输出是[batch_size, 128]


# --------------------- NIR特征提取器（A-CNN + A-GRU） ---------------------
class NIRAttentionExtractor(nn.Module):
    def __init__(self):
        super(NIRAttentionExtractor, self).__init__()
        
        # 改进的A-CNN
        self.conv = nn.Sequential(
            nn.Conv1d(1, 32, kernel_size=3, padding=1),
            nn.BatchNorm1d(32),
            nn.ReLU(),
            nn.Conv1d(32, 64, kernel_size=3, padding=1),
            nn.BatchNorm1d(64),
            nn.ReLU(),
            nn.AdaptiveAvgPool1d(64)  # 统一输出长度
        )
        
        # 改进的SE block
        self.se_block = nn.Sequential(
            nn.AdaptiveAvgPool1d(1),
            nn.Flatten(),
            nn.Linear(64, 64),  # 减少压缩比例
            nn.SiLU(),  # 更平滑的激活
            nn.Linear(64, 64),
            nn.Sigmoid()
        )
        
        # 改进的A-GRU
        self.pre_gru = nn.Linear(128, 64)  # 前置特征提取
        self.gru = nn.GRU(input_size=64, hidden_size=64, batch_first=True, bidirectional=True)
        
        # 改进的注意力
        self.attn_fc = nn.Sequential(
            nn.Linear(128, 64),
            nn.Tanh(),
            nn.Linear(64, 1)
        )
        
        # 修正的特征融合层
        # 输入应该是CNN(64) + GRU(128) = 192
        # 输出保持192维或调整为其他统一维度
        self.fusion = nn.Linear(192, 192)  # 输入输出都设为192

    def forward(self, x):
        # A-CNN
        x_cnn = x.unsqueeze(1)  # (batch_size, 1, 128)
        x_cnn = self.conv(x_cnn)  # (batch_size, 64, 64)
        se = self.se_block(x_cnn).unsqueeze(-1)  # (batch_size, 64, 1)
        x_cnn = x_cnn * se  # SE加权
        x_cnn = x_cnn.mean(dim=-1)  # (batch_size, 64)
        
        # A-GRU
        x_gru = self.pre_gru(x)  # (batch_size, 64)
        x_gru = x_gru.unsqueeze(1)  # (batch_size, 1, 64)
        x_gru, _ = self.gru(x_gru)  # (batch_size, 1, 128)
        
        # 改进的注意力计算
        attn_weights = torch.softmax(self.attn_fc(x_gru), dim=1)  # (batch_size, 1, 1)
        x_gru = torch.sum(x_gru * attn_weights, dim=1)  # (batch_size, 128)
        
        # 特征融合
        features = torch.cat([x_cnn, x_gru], dim=1)  # (batch_size, 192)
        features = self.fusion(features)  # (batch_size, 192)
        
        return features

# --------------------- 蒸馏三分类模型 ---------------------
class CrossModalFusion(nn.Module):
    def __init__(self, img_dim=128, nir_dim=192, hidden_dim=256):
        super().__init__()
        
        # 跨模态注意力机制
        self.img_proj = nn.Linear(img_dim, hidden_dim)
        self.nir_proj = nn.Linear(nir_dim, hidden_dim)
        
        self.attention = nn.Sequential(
            nn.Linear(hidden_dim, hidden_dim//4),
            nn.ReLU(),
            nn.Linear(hidden_dim//4, 1),
            nn.Sigmoid()
        )
        
        self.fusion = nn.Linear(hidden_dim*2, hidden_dim)
        
    def forward(self, img_feat, nir_feat):
        # 投影到共同空间
        img_proj = self.img_proj(img_feat)  # (B, hidden_dim)
        nir_proj = self.nir_proj(nir_feat)  # (B, hidden_dim)
        
        # 计算跨模态注意力
        combined = img_proj + nir_proj
        attn_weights = self.attention(combined)  # (B, 1)
        
        # 注意力加权融合
        fused = torch.cat([
            img_proj * attn_weights,
            nir_proj * (1 - attn_weights)
        ], dim=1)
        
        return self.fusion(fused)  # (B, hidden_dim)

class MultiModalNet(nn.Module):
    def __init__(self, num_classes=3):
        super().__init__()
        
        # 特征提取器
        self.image_encoder = PyramidCNN()
        self.nir_encoder = NIRAttentionExtractor()
        
        # 改进的特征融合
        self.fusion = CrossModalFusion()
        
        # 增强的分类头
        self.classifier = nn.Sequential(
            nn.Linear(256, 128),
            nn.BatchNorm1d(128),
            nn.ReLU(),
            nn.Dropout(0.5),
            
            nn.Linear(128, 64),
            nn.BatchNorm1d(64),
            nn.ReLU(),
            nn.Dropout(0.3),
            
            nn.Linear(64, num_classes)
        )
        
        # 初始化权重
        self._init_weights()
    
    def _init_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Linear):
                nn.init.kaiming_normal_(m.weight)
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0)
    
    def forward(self, img, nir):
        img_feat = self.image_encoder(img)
        nir_feat = self.nir_encoder(nir)
        
        # 跨模态融合
        fused = self.fusion(img_feat, nir_feat)
        
        # 分类
        out = self.classifier(fused)
        return out

# %%
# --------------------- 主程序 ---------------------
# 加载数据
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor()
])

# 训练集的数据增强
train_transform = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.RandomCrop((224, 224)),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomVerticalFlip(p=0.5),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    transforms.ToTensor(),
])

# 验证集和测试集，只做基本处理
val_test_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
])
image_dataset = ImageFolder(root=r"L:\\常惠林\\萎凋\\所有样本", transform=transform)
nir_mat = sio.loadmat(r"L:\\常惠林\\萎凋\\NIR.mat")
nir_data = nir_mat['nir']  # (300, 128)

# 数据划分
# 划分训练集（40%）和临时集（60%）
train_idx, temp_idx = train_test_split(
    range(300),
    test_size=0.6,  # 留60%给验证+测试
    stratify=image_dataset.targets,  # 分层抽样，保持类别比例
    random_state=42
)

# 划分验证集（20%）和测试集（40%）
val_idx, test_idx = train_test_split(
    temp_idx,
    test_size=0.5,  
    stratify=[image_dataset.targets[i] for i in temp_idx],  # 保持类别比例一致
    random_state=42
)

def subset(dataset, idxs):
    imgs = [dataset.imgs[i] for i in idxs]
    targets = [dataset.targets[i] for i in idxs]
    return imgs, targets

train_imgs, train_labels = subset(image_dataset, train_idx)
val_imgs, val_labels = subset(image_dataset, val_idx)
test_imgs, test_labels = subset(image_dataset, test_idx)

# 注意，分别赋不同的transform！
train_dataset = MultiModalDataset(train_imgs, nir_data[train_idx], train_labels, transform=train_transform)
val_dataset = MultiModalDataset(val_imgs, nir_data[val_idx], val_labels, transform=val_test_transform)
test_dataset = MultiModalDataset(test_imgs, nir_data[test_idx], test_labels, transform=val_test_transform)

train_loader = DataLoader(train_dataset, batch_size=48, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=48)
test_loader = DataLoader(test_dataset, batch_size=48)

# 初始化模型
model = MultiModalNet().cuda()
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=1e-4)

# 添加容器来存储loss和准确率
train_losses = []
train_accuracies = []
val_accuracies = []

# ------------------ 训练 ------------------

best_acc = 0
for epoch in range(150):
    model.train()
    epoch_loss = 0
    correct_preds = 0
    total_preds = 0
    
    for imgs, nirs, labels in train_loader:
        imgs, nirs, labels = imgs.cuda(), nirs.cuda(), labels.cuda()
        optimizer.zero_grad()
        
        outputs = model(imgs, nirs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        # 记录训练loss
        epoch_loss += loss.item()
        
        # 计算训练准确率
        preds = outputs.argmax(dim=1)
        correct_preds += (preds == labels).sum().item()
        total_preds += labels.size(0)
    
    # 计算每个epoch的平均loss和准确率
    avg_train_loss = epoch_loss / len(train_loader)
    train_acc = correct_preds / total_preds
    
    train_losses.append(avg_train_loss)
    train_accuracies.append(train_acc)
    
    # 每轮结束后验证
    model.eval()
    preds_val, trues_val = [], []
    with torch.no_grad():
        for imgs, nirs, labels in val_loader:
            imgs, nirs = imgs.cuda(), nirs.cuda()
            outputs = model(imgs, nirs)
            preds_val.extend(outputs.argmax(dim=1).cpu().numpy())
            trues_val.extend(labels.numpy())
    
    val_acc = accuracy_score(trues_val, preds_val)
    val_accuracies.append(val_acc)
    
    print(f"Epoch {epoch+1}: Train Loss = {avg_train_loss:.4f}, Train Acc = {train_acc:.4f}, Val Acc = {val_acc:.4f}")
    
    # 保存验证集上效果最好的模型及其在验证集的预测
    if val_acc > best_acc:
        best_acc = val_acc
        best_val_preds = preds_val.copy()
        best_val_trues = trues_val.copy()
        torch.save(model.state_dict(), "best_model.pth")
        print(f"Best model updated at epoch {epoch+1}")

# ------------------ 验证集混淆矩阵（best model） ------------------
cm_val = confusion_matrix(best_val_trues, best_val_preds)
val_acc = accuracy_score(best_val_trues, best_val_preds)

print("Best Model Validation Accuracy:", val_acc)

plt.figure(figsize=(6, 6))
plt.imshow(cm_val, cmap='Blues')
plt.title('Confusion Matrix (Validation Set)')
plt.colorbar()

classes = np.arange(cm_val.shape[0])

for i in range(cm_val.shape[0]):
    for j in range(cm_val.shape[1]):
        plt.text(j, i, str(cm_val[i, j]), ha='center', va='center', color='red', fontsize=12)

plt.xticks(classes)
plt.yticks(classes)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# ------------------ 测试集混淆矩阵（best model） ------------------
# 加载最佳模型
model.load_state_dict(torch.load("best_model.pth"))
model.eval()

preds_test, trues_test = [], []
with torch.no_grad():
    for imgs, nirs, labels in test_loader:
        imgs, nirs = imgs.cuda(), nirs.cuda()
        outputs = model(imgs, nirs)
        preds_test.extend(outputs.argmax(dim=1).cpu().numpy())
        trues_test.extend(labels.numpy())

cm_test = confusion_matrix(trues_test, preds_test)
test_acc = accuracy_score(trues_test, preds_test)

print("Best Model Test Accuracy:", test_acc)

plt.figure(figsize=(6, 6))
plt.imshow(cm_test, cmap='Blues')
plt.title('Confusion Matrix (Test Set)')
plt.colorbar()

classes = np.arange(cm_test.shape[0])

for i in range(cm_test.shape[0]):
    for j in range(cm_test.shape[1]):
        plt.text(j, i, str(cm_test[i, j]), ha='center', va='center', color='red', fontsize=12)

plt.xticks(classes)
plt.yticks(classes)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# ------------------ 绘制训练损失和准确率曲线 ------------------
# 绘制训练过程中的损失和准确率
plt.figure(figsize=(12, 5))

# 绘制训练损失曲线
plt.subplot(1, 2, 1)
plt.plot(range(1, len(train_losses) + 1), train_losses, label="Train Loss", color='blue')
plt.title("Train Loss Curve")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.grid(True)

# 绘制训练和验证准确率曲线
plt.subplot(1, 2, 2)
plt.plot(range(1, len(train_accuracies) + 1), train_accuracies, label="Train Accuracy", color='green')
plt.plot(range(1, len(val_accuracies) + 1), val_accuracies, label="Validation Accuracy", color='orange')
plt.title("Accuracy Curve")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# Epoch 1: Train Loss = 1.4941, Train Acc = 0.3083, Val Acc = 0.3111
# Best model updated at epoch 1
# Epoch 2: Train Loss = 1.4959, Train Acc = 0.3167, Val Acc = 0.3111
# Epoch 3: Train Loss = 1.3124, Train Acc = 0.4000, Val Acc = 0.3111
# Epoch 4: Train Loss = 1.3713, Train Acc = 0.3583, Val Acc = 0.3667
# Best model updated at epoch 4
# Epoch 5: Train Loss = 1.1935, Train Acc = 0.4333, Val Acc = 0.4556
# Best model updated at epoch 5
# Epoch 6: Train Loss = 1.0845, Train Acc = 0.5083, Val Acc = 0.4556
# Epoch 7: Train Loss = 1.0612, Train Acc = 0.4917, Val Acc = 0.5000
# Best model updated at epoch 7
# Epoch 8: Train Loss = 1.0653, Train Acc = 0.4667, Val Acc = 0.4889
# Epoch 9: Train Loss = 1.0214, Train Acc = 0.5000, Val Acc = 0.5333
# Best model updated at epoch 9
# Epoch 10: Train Loss = 1.0701, Train Acc = 0.5083, Val Acc = 0.5444
# Best model updated at epoch 10
# Epoch 11: Train Loss = 1.0872, Train Acc = 0.5250, Val Acc = 0.5667
# Best model updated at epoch 11
# Epoch 12: Train Loss = 0.9325, Train Acc = 0.6000, Val Acc = 0.6222
# Best model updated at epoch 12
# Epoch 13: Train Loss = 0.9233, Train Acc = 0.6500, Val Acc = 0.6333
# Best model updated at epoch 13
# Epoch 14: Train Loss = 0.8694, Train Acc = 0.5667, Val Acc = 0.6444
# Best model updated at epoch 14
# Epoch 15: Train Loss = 0.8712, Train Acc = 0.6583, Val Acc = 0.6333
# Epoch 16: Train Loss = 0.8031, Train Acc = 0.6333, Val Acc = 0.6778
# Best model updated at epoch 16
# Epoch 17: Train Loss = 0.8757, Train Acc = 0.6417, Val Acc = 0.7222
# Best model updated at epoch 17
# Epoch 18: Train Loss = 0.7863, Train Acc = 0.6667, Val Acc = 0.6778
# Epoch 19: Train Loss = 0.7272, Train Acc = 0.6333, Val Acc = 0.7556
# Best model updated at epoch 19
# Epoch 20: Train Loss = 0.7671, Train Acc = 0.6417, Val Acc = 0.7333
# Epoch 21: Train Loss = 0.7797, Train Acc = 0.6667, Val Acc = 0.7000
# Epoch 22: Train Loss = 0.7304, Train Acc = 0.7083, Val Acc = 0.7222
# Epoch 23: Train Loss = 0.7559, Train Acc = 0.6417, Val Acc = 0.7000
# Epoch 24: Train Loss = 0.7578, Train Acc = 0.6000, Val Acc = 0.6667
# Epoch 25: Train Loss = 0.7552, Train Acc = 0.6750, Val Acc = 0.7778
# Best model updated at epoch 25
# Epoch 26: Train Loss = 0.6482, Train Acc = 0.7250, Val Acc = 0.7778
# Epoch 27: Train Loss = 0.6013, Train Acc = 0.7417, Val Acc = 0.7000
# Epoch 28: Train Loss = 0.6798, Train Acc = 0.7583, Val Acc = 0.7222
# Epoch 29: Train Loss = 0.5971, Train Acc = 0.7583, Val Acc = 0.7444
# Epoch 30: Train Loss = 0.6028, Train Acc = 0.7833, Val Acc = 0.6667
# Epoch 31: Train Loss = 0.6073, Train Acc = 0.7667, Val Acc = 0.7444
# Epoch 32: Train Loss = 0.5073, Train Acc = 0.8250, Val Acc = 0.8333
# Best model updated at epoch 32
# Epoch 33: Train Loss = 0.6130, Train Acc = 0.7583, Val Acc = 0.8222
# Epoch 34: Train Loss = 0.6023, Train Acc = 0.7917, Val Acc = 0.8333
# Epoch 35: Train Loss = 0.5298, Train Acc = 0.8083, Val Acc = 0.8111
# Epoch 36: Train Loss = 0.5274, Train Acc = 0.8667, Val Acc = 0.7889
# Epoch 37: Train Loss = 0.5120, Train Acc = 0.7750, Val Acc = 0.7667
# Epoch 38: Train Loss = 0.5300, Train Acc = 0.8000, Val Acc = 0.7444
# Epoch 39: Train Loss = 0.4233, Train Acc = 0.8500, Val Acc = 0.7667
# Epoch 40: Train Loss = 0.5465, Train Acc = 0.8167, Val Acc = 0.7889
# Epoch 41: Train Loss = 0.5953, Train Acc = 0.8250, Val Acc = 0.8111
# Epoch 42: Train Loss = 0.5592, Train Acc = 0.7500, Val Acc = 0.8111
# Epoch 43: Train Loss = 0.4695, Train Acc = 0.8250, Val Acc = 0.7778
# Epoch 44: Train Loss = 0.4666, Train Acc = 0.8500, Val Acc = 0.8111
# Epoch 45: Train Loss = 0.4466, Train Acc = 0.8250, Val Acc = 0.8333
# Epoch 46: Train Loss = 0.4332, Train Acc = 0.8500, Val Acc = 0.7667
# Epoch 47: Train Loss = 0.4886, Train Acc = 0.8167, Val Acc = 0.7889
# Epoch 48: Train Loss = 0.4666, Train Acc = 0.7833, Val Acc = 0.8222
# Epoch 49: Train Loss = 0.4327, Train Acc = 0.8500, Val Acc = 0.8111
# Epoch 50: Train Loss = 0.4033, Train Acc = 0.8667, Val Acc = 0.7889
# Epoch 51: Train Loss = 0.4534, Train Acc = 0.8667, Val Acc = 0.8111
# Epoch 52: Train Loss = 0.4164, Train Acc = 0.8833, Val Acc = 0.8000
# Epoch 53: Train Loss = 0.4356, Train Acc = 0.8750, Val Acc = 0.7667
# Epoch 54: Train Loss = 0.4421, Train Acc = 0.8250, Val Acc = 0.8111
# Epoch 55: Train Loss = 0.4386, Train Acc = 0.8583, Val Acc = 0.8556
# Best model updated at epoch 55
# Epoch 56: Train Loss = 0.4857, Train Acc = 0.8500, Val Acc = 0.8000
# Epoch 57: Train Loss = 0.5040, Train Acc = 0.8250, Val Acc = 0.8000
# Epoch 58: Train Loss = 0.3683, Train Acc = 0.8667, Val Acc = 0.7778
# Epoch 59: Train Loss = 0.3941, Train Acc = 0.8500, Val Acc = 0.8000
# Epoch 60: Train Loss = 0.3491, Train Acc = 0.8833, Val Acc = 0.8111
# Epoch 61: Train Loss = 0.3993, Train Acc = 0.9000, Val Acc = 0.8444
# Epoch 62: Train Loss = 0.4114, Train Acc = 0.8667, Val Acc = 0.7778
# Epoch 63: Train Loss = 0.3660, Train Acc = 0.8583, Val Acc = 0.8000
# Epoch 64: Train Loss = 0.3433, Train Acc = 0.9000, Val Acc = 0.8111
# Epoch 65: Train Loss = 0.3122, Train Acc = 0.8917, Val Acc = 0.8444
# Epoch 66: Train Loss = 0.3145, Train Acc = 0.8750, Val Acc = 0.8889
# Best model updated at epoch 66
# Epoch 67: Train Loss = 0.4184, Train Acc = 0.8667, Val Acc = 0.8444
# Epoch 68: Train Loss = 0.3619, Train Acc = 0.8833, Val Acc = 0.8556
# Epoch 69: Train Loss = 0.2904, Train Acc = 0.9167, Val Acc = 0.8222
# Epoch 70: Train Loss = 0.3344, Train Acc = 0.9250, Val Acc = 0.8444
# Epoch 71: Train Loss = 0.2947, Train Acc = 0.9083, Val Acc = 0.8444
# Epoch 72: Train Loss = 0.3535, Train Acc = 0.9000, Val Acc = 0.8333
# Epoch 73: Train Loss = 0.2655, Train Acc = 0.9500, Val Acc = 0.8556
# Epoch 74: Train Loss = 0.2924, Train Acc = 0.9333, Val Acc = 0.8222
# Epoch 75: Train Loss = 0.2960, Train Acc = 0.9083, Val Acc = 0.9000
# Best model updated at epoch 75
# Epoch 76: Train Loss = 0.2756, Train Acc = 0.9167, Val Acc = 0.7778
# Epoch 77: Train Loss = 0.3088, Train Acc = 0.9083, Val Acc = 0.7889
# Epoch 78: Train Loss = 0.2981, Train Acc = 0.9083, Val Acc = 0.8667
# Epoch 79: Train Loss = 0.3076, Train Acc = 0.9167, Val Acc = 0.8444
# Epoch 80: Train Loss = 0.3206, Train Acc = 0.8917, Val Acc = 0.8111
# Epoch 81: Train Loss = 0.2979, Train Acc = 0.9333, Val Acc = 0.7778
# Epoch 82: Train Loss = 0.2912, Train Acc = 0.9167, Val Acc = 0.8556
# Epoch 83: Train Loss = 0.2929, Train Acc = 0.9333, Val Acc = 0.8667
# Epoch 84: Train Loss = 0.4302, Train Acc = 0.8750, Val Acc = 0.7556
# Epoch 85: Train Loss = 0.3064, Train Acc = 0.9250, Val Acc = 0.7000
# Epoch 86: Train Loss = 0.3206, Train Acc = 0.8917, Val Acc = 0.8333
# Epoch 87: Train Loss = 0.2872, Train Acc = 0.9167, Val Acc = 0.8778
# Epoch 88: Train Loss = 0.2568, Train Acc = 0.9250, Val Acc = 0.8444
# Epoch 89: Train Loss = 0.3199, Train Acc = 0.9000, Val Acc = 0.8000
# Epoch 90: Train Loss = 0.2948, Train Acc = 0.8917, Val Acc = 0.8667
# Epoch 91: Train Loss = 0.3043, Train Acc = 0.9167, Val Acc = 0.8444
# Epoch 92: Train Loss = 0.2648, Train Acc = 0.9167, Val Acc = 0.8778
# Epoch 93: Train Loss = 0.2305, Train Acc = 0.9250, Val Acc = 0.8778
# Epoch 94: Train Loss = 0.2774, Train Acc = 0.9583, Val Acc = 0.8222
# Epoch 95: Train Loss = 0.3003, Train Acc = 0.9083, Val Acc = 0.8556
# Epoch 96: Train Loss = 0.2822, Train Acc = 0.9333, Val Acc = 0.9000
# Epoch 97: Train Loss = 0.2962, Train Acc = 0.9083, Val Acc = 0.8222
# Epoch 98: Train Loss = 0.2524, Train Acc = 0.9417, Val Acc = 0.8000
# Epoch 99: Train Loss = 0.2979, Train Acc = 0.9250, Val Acc = 0.8556
# Epoch 100: Train Loss = 0.2497, Train Acc = 0.9417, Val Acc = 0.8667
# Epoch 101: Train Loss = 0.2284, Train Acc = 0.9167, Val Acc = 0.9000
# Epoch 102: Train Loss = 0.2448, Train Acc = 0.9333, Val Acc = 0.8889
# Epoch 103: Train Loss = 0.2132, Train Acc = 0.9500, Val Acc = 0.8889
# Epoch 104: Train Loss = 0.2564, Train Acc = 0.9417, Val Acc = 0.8444
# Epoch 105: Train Loss = 0.2347, Train Acc = 0.9417, Val Acc = 0.8778
# Epoch 106: Train Loss = 0.2235, Train Acc = 0.9167, Val Acc = 0.8444
# Epoch 107: Train Loss = 0.2254, Train Acc = 0.9500, Val Acc = 0.8444
# Epoch 108: Train Loss = 0.1900, Train Acc = 0.9417, Val Acc = 0.8889
# Epoch 109: Train Loss = 0.1952, Train Acc = 0.9667, Val Acc = 0.8778
# Epoch 110: Train Loss = 0.1887, Train Acc = 0.9500, Val Acc = 0.8778
# Epoch 111: Train Loss = 0.1787, Train Acc = 0.9750, Val Acc = 0.8889
# Epoch 112: Train Loss = 0.2687, Train Acc = 0.9167, Val Acc = 0.9000
# Epoch 113: Train Loss = 0.2556, Train Acc = 0.9417, Val Acc = 0.9111
# Best model updated at epoch 113
# Epoch 114: Train Loss = 0.1974, Train Acc = 0.9500, Val Acc = 0.8333
# Epoch 115: Train Loss = 0.2447, Train Acc = 0.9250, Val Acc = 0.8667
# Epoch 116: Train Loss = 0.1933, Train Acc = 0.9583, Val Acc = 0.9111
# Epoch 117: Train Loss = 0.1669, Train Acc = 0.9500, Val Acc = 0.8778
# Epoch 118: Train Loss = 0.1780, Train Acc = 0.9667, Val Acc = 0.8333
# Epoch 119: Train Loss = 0.1880, Train Acc = 0.9583, Val Acc = 0.8889
# Epoch 120: Train Loss = 0.2163, Train Acc = 0.9500, Val Acc = 0.8889
# Epoch 121: Train Loss = 0.2459, Train Acc = 0.9000, Val Acc = 0.8333
# Epoch 122: Train Loss = 0.2042, Train Acc = 0.9417, Val Acc = 0.8778
# Epoch 123: Train Loss = 0.1866, Train Acc = 0.9750, Val Acc = 0.8889
# Epoch 124: Train Loss = 0.2137, Train Acc = 0.9333, Val Acc = 0.8778
# Epoch 125: Train Loss = 0.1933, Train Acc = 0.9583, Val Acc = 0.8778
# Epoch 126: Train Loss = 0.2040, Train Acc = 0.9333, Val Acc = 0.8556
# Epoch 127: Train Loss = 0.1974, Train Acc = 0.9417, Val Acc = 0.8889
# Epoch 128: Train Loss = 0.1781, Train Acc = 0.9667, Val Acc = 0.9444
# Best model updated at epoch 128
# Epoch 129: Train Loss = 0.1831, Train Acc = 0.9500, Val Acc = 0.9111
# Epoch 130: Train Loss = 0.2179, Train Acc = 0.9500, Val Acc = 0.8889
# Epoch 131: Train Loss = 0.2675, Train Acc = 0.9167, Val Acc = 0.8778
# Epoch 132: Train Loss = 0.2295, Train Acc = 0.9667, Val Acc = 0.8889
# Epoch 133: Train Loss = 0.2201, Train Acc = 0.9417, Val Acc = 0.9000
# Epoch 134: Train Loss = 0.1764, Train Acc = 0.9667, Val Acc = 0.9000
# Epoch 135: Train Loss = 0.1888, Train Acc = 0.9500, Val Acc = 0.9111
# Epoch 136: Train Loss = 0.1332, Train Acc = 0.9750, Val Acc = 0.9222
# Epoch 137: Train Loss = 0.1527, Train Acc = 0.9583, Val Acc = 0.9333
# Epoch 138: Train Loss = 0.1530, Train Acc = 0.9583, Val Acc = 0.8889
# Epoch 139: Train Loss = 0.1608, Train Acc = 0.9750, Val Acc = 0.8556
# Epoch 140: Train Loss = 0.1623, Train Acc = 0.9750, Val Acc = 0.8667
# Epoch 141: Train Loss = 0.1560, Train Acc = 0.9750, Val Acc = 0.8778
# Epoch 142: Train Loss = 0.1756, Train Acc = 0.9500, Val Acc = 0.8889
# Epoch 143: Train Loss = 0.2209, Train Acc = 0.9500, Val Acc = 0.9000
# Epoch 144: Train Loss = 0.1560, Train Acc = 0.9750, Val Acc = 0.8444
# Epoch 145: Train Loss = 0.1604, Train Acc = 0.9583, Val Acc = 0.8778
# Epoch 146: Train Loss = 0.2573, Train Acc = 0.9417, Val Acc = 0.9000
# Epoch 147: Train Loss = 0.1585, Train Acc = 0.9667, Val Acc = 0.9000
# Epoch 148: Train Loss = 0.2155, Train Acc = 0.9583, Val Acc = 0.8778
# Epoch 149: Train Loss = 0.1734, Train Acc = 0.9583, Val Acc = 0.6778
# Epoch 150: Train Loss = 0.2890, Train Acc = 0.9083, Val Acc = 0.8222
# Best Model Validation Accuracy: 0.9444444444444444
# C:\Users\enine\AppData\Local\Temp\ipykernel_32540\349950317.py:153: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load("best_model.pth"))
# Best Model Test Accuracy: 0.9333333333333333
