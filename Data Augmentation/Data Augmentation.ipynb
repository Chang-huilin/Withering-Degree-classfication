# %%
from PIL import Image
import os

def split_image(image_path, output_folder):
    # 打开图片
    img = Image.open(image_path)
    img_width, img_height = img.size

    # 计算每张小图的宽度和高度
    tile_width = img_width // 2
    tile_height = img_height // 2

    # 切割图片并保存
    for i in range(2):
        for j in range(2):
            left = j * tile_width
            upper = i * tile_height
            right = left + tile_width
            lower = upper + tile_height

            # 切割图片
            tile = img.crop((left, upper, right, lower))

            # 保存切割后的小图
            tile_name = f"{os.path.splitext(os.path.basename(image_path))[0]}_tile_{i}_{j}.png"
            tile.save(os.path.join(output_folder, tile_name))

            # 对小图进行旋转
            for angle in [90, 180, 270]:
                rotated_tile = tile.rotate(angle, expand=True)
                rotated_tile_name = f"{os.path.splitext(os.path.basename(image_path))[0]}_tile_{i}_{j}_rotated_{angle}.png"
                rotated_tile.save(os.path.join(output_folder, rotated_tile_name))

def process_folder(input_folder, output_folder):
    # 确保输出文件夹存在
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # 遍历输入文件夹中的所有图片
    for filename in os.listdir(input_folder):
        if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif')):
            image_path = os.path.join(input_folder, filename)
            split_image(image_path, output_folder)

if __name__ == "__main__":
    input_folder = r"L:\常惠林\萎凋\自然萎凋\原始\3萎凋过度"
    output_folder = r"L:\常惠林\萎凋\自然萎凋\原始\class_3"
    process_folder(input_folder, output_folder)

# %%
from PIL import Image
import numpy as np
import os

# 设置图片所在的目录路径
folder_path = r'L:\常惠林\萎凋\自然萎凋\分类\class_3'
output_folder = r'L:\常惠林\萎凋\自然萎凋\分类\class_3_四通道'

# 创建输出文件夹
os.makedirs(output_folder, exist_ok=True)

# 获取所有图片文件
image_files = [f for f in os.listdir(folder_path) if f.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp'))]

# 对每个图像进行处理
for image_file in image_files:
    # 构建图像文件路径
    img_path = os.path.join(folder_path, image_file)
    
    # 读取图像（彩色图像）
    img = Image.open(img_path)
    
    # 转换为灰度图像
    img_gray = img.convert('L')  # 'L' 模式表示灰度图像
    
    # 将图像和灰度图像转化为 NumPy 数组
    img_array = np.array(img)  # RGB 图像
    img_gray_array = np.array(img_gray)  # 灰度图像
    
    # 将灰度图像扩展为三个通道（复制灰度图像到三个通道）
    img_gray_array = np.stack([img_gray_array] * 3, axis=-1)
    
    # 合并原始 RGB 图像和灰度图像（灰度图像作为额外的通道）
    combined_image = np.concatenate((img_array, img_gray_array[:, :, :1]), axis=-1)  # 添加灰度作为第四通道
    
    # 保存处理后的图像
    output_path = os.path.join(output_folder, f"combined_{image_file}")
    Image.fromarray(combined_image.astype(np.uint8)).save(output_path)
    print(f"已保存合并图像：{image_file} -> combined_{image_file}")

print("图像保存完成！")
# Out:
# 已保存合并图像：104_tile_0_0.png -> combined_104_tile_0_0.png
# 已保存合并图像：104_tile_0_0_rotated_180.png -> combined_104_tile_0_0_rotated_180.png
# 已保存合并图像：104_tile_0_0_rotated_270.png -> combined_104_tile_0_0_rotated_270.png
# 已保存合并图像：104_tile_0_0_rotated_90.png -> combined_104_tile_0_0_rotated_90.png
# 已保存合并图像：104_tile_0_1.png -> combined_104_tile_0_1.png
# 已保存合并图像：104_tile_0_1_rotated_180.png -> combined_104_tile_0_1_rotated_180.png
# 已保存合并图像：108_tile_2_2_rotated_90.png -> combined_108_tile_2_2_rotated_90.png
# 已保存合并图像：110_tile_0_0.png -> combined_110_tile_0_0.png
# 已保存合并图像：110_tile_0_0_rotated_180.png -> combined_110_tile_0_0_rotated_180.png
# 已保存合并图像：110_tile_0_0_rotated_270.png -> combined_110_tile_0_0_rotated_270.png
# 已保存合并图像：110_tile_0_0_rotated_90.png -> combined_110_tile_0_0_rotated_90.png
# 已保存合并图像：110_tile_0_1.png -> combined_110_tile_0_1.png
# 已保存合并图像：110_tile_0_1_rotated_180.png -> combined_110_tile_0_1_rotated_180.png
# 已保存合并图像：110_tile_0_1_rotated_270.png -> combined_110_tile_0_1_rotated_270.png
# 已保存合并图像：110_tile_0_1_rotated_90.png -> combined_110_tile_0_1_rotated_90.png
# 已保存合并图像：110_tile_0_2.png -> combined_110_tile_0_2.png
# 已保存合并图像：110_tile_0_2_rotated_180.png -> combined_110_tile_0_2_rotated_180.png
# 已保存合并图像：110_tile_0_2_rotated_270.png -> combined_110_tile_0_2_rotated_270.png
# 已保存合并图像：110_tile_0_2_rotated_90.png -> combined_110_tile_0_2_rotated_90.png
# 已保存合并图像：110_tile_1_0.png -> combined_110_tile_1_0.png
# 已保存合并图像：110_tile_1_0_rotated_180.png -> combined_110_tile_1_0_rotated_180.png
# 已保存合并图像：110_tile_1_0_rotated_270.png -> combined_110_tile_1_0_rotated_270.png
# 已保存合并图像：110_tile_1_0_rotated_90.png -> combined_110_tile_1_0_rotated_90.png
# 已保存合并图像：110_tile_1_1.png -> combined_110_tile_1_1.png
# 已保存合并图像：110_tile_1_1_rotated_180.png -> combined_110_tile_1_1_rotated_180.png
# 已保存合并图像：110_tile_1_1_rotated_270.png -> combined_110_tile_1_1_rotated_270.png
# 已保存合并图像：110_tile_1_1_rotated_90.png -> combined_110_tile_1_1_rotated_90.png
# 已保存合并图像：110_tile_1_2.png -> combined_110_tile_1_2.png
# 已保存合并图像：110_tile_1_2_rotated_180.png -> combined_110_tile_1_2_rotated_180.png
# 已保存合并图像：110_tile_1_2_rotated_270.png -> combined_110_tile_1_2_rotated_270.png
# 已保存合并图像：110_tile_1_2_rotated_90.png -> combined_110_tile_1_2_rotated_90.png
# 已保存合并图像：110_tile_2_0.png -> combined_110_tile_2_0.png
# 已保存合并图像：110_tile_2_0_rotated_180.png -> combined_110_tile_2_0_rotated_180.png
# 已保存合并图像：110_tile_2_0_rotated_270.png -> combined_110_tile_2_0_rotated_270.png
# 已保存合并图像：110_tile_2_0_rotated_90.png -> combined_110_tile_2_0_rotated_90.png
# 已保存合并图像：110_tile_2_1.png -> combined_110_tile_2_1.png
# 已保存合并图像：110_tile_2_1_rotated_180.png -> combined_110_tile_2_1_rotated_180.png
# 已保存合并图像：110_tile_2_1_rotated_270.png -> combined_110_tile_2_1_rotated_270.png
# 已保存合并图像：110_tile_2_1_rotated_90.png -> combined_110_tile_2_1_rotated_90.png
# 已保存合并图像：110_tile_2_2.png -> combined_110_tile_2_2.png
# 图像保存完成！

# %%
from PIL import Image

# 读取图像
img_path = "L:\常惠林\萎凋\自然萎凋\四通道\class_1\combined_img_001.png"  # 替换为实际图像路径
image = Image.open(img_path)

# 获取图像的模式和通道数
mode = image.mode
if mode == 'RGB':
    print("该图像有3个通道（RGB）。")
elif mode == 'RGBA':
    print("该图像有4个通道（RGBA）。")
elif mode == 'L':
    print("该图像有1个通道（灰度）。")
else:
    print(f"该图像的模式为 {mode}，通道数未知。")
# Out:
# 该图像有4个通道（RGBA）。

# %%
import os
import random
import numpy as np
import torch
from PIL import Image
import torchvision.transforms as transforms
from torch.utils.data import Dataset

# 定义添加高斯噪声的函数
def add_gaussian_noise(image_tensor, mean=0.0, std=0.1):
    # 生成高斯噪声
    noise = torch.randn_like(image_tensor) * std + mean
    
    # 添加噪声到图像
    noisy_image = image_tensor + noise
    
    # Clip values to make sure they are within the valid range [0, 1]
    noisy_image = torch.clamp(noisy_image, 0, 1)
    
    return noisy_image

# 定义数据扩增的转换操作
transform = transforms.Compose([
    transforms.RandomHorizontalFlip(),  # 随机水平翻转
    transforms.RandomVerticalFlip(),    # 随机垂直翻转
    transforms.RandomRotation(30),      # 随机旋转30度
    transforms.RandomResizedCrop(224, scale=(0.8, 1.0)),  # 随机裁剪并缩放到224x224
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.2),  # 改变亮度、对比度、饱和度和色调
    transforms.ToTensor(),              # 转换为Tensor
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])  # 图像归一化
])

# 定义数据集类
class AugmentedDataset(Dataset):
    def __init__(self, root_dir, transform=None, add_noise=True):
        self.root_dir = root_dir
        self.transform = transform
        self.add_noise = add_noise
        self.image_files = [f for f in os.listdir(root_dir) if f.endswith(('.png', '.jpg', '.jpeg'))]

    def __len__(self):
        return len(self.image_files)

    def __getitem__(self, idx):
        img_path = os.path.join(self.root_dir, self.image_files[idx])
        image = Image.open(img_path).convert('RGB')  # 确保图像是RGB格式

        # 应用数据扩增
        if self.transform:
            image = self.transform(image)
        
        # 添加噪声
        if self.add_noise:
            image = add_gaussian_noise(image)

        return image

# 加载数据集
dataset = AugmentedDataset(root_dir=r"L:\常惠林\萎凋\自然萎凋\分类\class_1", transform=transform)

# 生成扩增后的图像并保存
output_folder = "augmented_with_noise_images"  # 设置保存扩增图像的文件夹
os.makedirs(output_folder, exist_ok=True)

for idx in range(len(dataset)):
    image = dataset[idx]
    img_name = f"augmented_with_noise_{idx}.png"
    img_path = os.path.join(output_folder, img_name)
    
    # 转换为PIL图像以便保存
    image_pil = transforms.ToPILImage()(image)
    image_pil.save(img_path)
    print(f"保存扩增并添加噪声的图像: {img_name}")
print("图像保存完成！")
# Out:
# 保存扩增并添加噪声的图像: augmented_with_noise_0.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2.png
# 保存扩增并添加噪声的图像: augmented_with_noise_3.png
# 保存扩增并添加噪声的图像: augmented_with_noise_4.png
# 保存扩增并添加噪声的图像: augmented_with_noise_5.png
# 保存扩增并添加噪声的图像: augmented_with_noise_6.png
# 保存扩增并添加噪声的图像: augmented_with_noise_7.png
# 保存扩增并添加噪声的图像: augmented_with_noise_8.png
# 保存扩增并添加噪声的图像: augmented_with_noise_9.png
# 保存扩增并添加噪声的图像: augmented_with_noise_10.png
# 保存扩增并添加噪声的图像: augmented_with_noise_11.png
# 保存扩增并添加噪声的图像: augmented_with_noise_12.png
# 保存扩增并添加噪声的图像: augmented_with_noise_13.png
# 保存扩增并添加噪声的图像: augmented_with_noise_14.png
# 保存扩增并添加噪声的图像: augmented_with_noise_15.png
# 保存扩增并添加噪声的图像: augmented_with_noise_16.png
# 保存扩增并添加噪声的图像: augmented_with_noise_17.png
# 保存扩增并添加噪声的图像: augmented_with_noise_18.png
# 保存扩增并添加噪声的图像: augmented_with_noise_19.png
# 保存扩增并添加噪声的图像: augmented_with_noise_20.png
# 保存扩增并添加噪声的图像: augmented_with_noise_21.png
# 保存扩增并添加噪声的图像: augmented_with_noise_22.png
# 保存扩增并添加噪声的图像: augmented_with_noise_23.png
# 保存扩增并添加噪声的图像: augmented_with_noise_24.png
# 保存扩增并添加噪声的图像: augmented_with_noise_25.png
# 保存扩增并添加噪声的图像: augmented_with_noise_26.png
# 保存扩增并添加噪声的图像: augmented_with_noise_27.png
# 保存扩增并添加噪声的图像: augmented_with_noise_28.png
# 保存扩增并添加噪声的图像: augmented_with_noise_29.png
# 保存扩增并添加噪声的图像: augmented_with_noise_30.png
# 保存扩增并添加噪声的图像: augmented_with_noise_31.png
# 保存扩增并添加噪声的图像: augmented_with_noise_32.png
# 保存扩增并添加噪声的图像: augmented_with_noise_33.png
# 保存扩增并添加噪声的图像: augmented_with_noise_34.png
# 保存扩增并添加噪声的图像: augmented_with_noise_35.png
# 保存扩增并添加噪声的图像: augmented_with_noise_36.png
# 保存扩增并添加噪声的图像: augmented_with_noise_37.png
# 保存扩增并添加噪声的图像: augmented_with_noise_38.png
# 保存扩增并添加噪声的图像: augmented_with_noise_39.png
# 保存扩增并添加噪声的图像: augmented_with_noise_40.png
# 保存扩增并添加噪声的图像: augmented_with_noise_41.png
# 保存扩增并添加噪声的图像: augmented_with_noise_42.png
# 保存扩增并添加噪声的图像: augmented_with_noise_43.png
# 保存扩增并添加噪声的图像: augmented_with_noise_44.png
# 保存扩增并添加噪声的图像: augmented_with_noise_45.png
# 保存扩增并添加噪声的图像: augmented_with_noise_46.png
# 保存扩增并添加噪声的图像: augmented_with_noise_47.png
# 保存扩增并添加噪声的图像: augmented_with_noise_48.png
# 保存扩增并添加噪声的图像: augmented_with_noise_49.png
# 保存扩增并添加噪声的图像: augmented_with_noise_50.png
# 保存扩增并添加噪声的图像: augmented_with_noise_51.png
# 保存扩增并添加噪声的图像: augmented_with_noise_52.png
# 保存扩增并添加噪声的图像: augmented_with_noise_53.png
# 保存扩增并添加噪声的图像: augmented_with_noise_54.png
# 保存扩增并添加噪声的图像: augmented_with_noise_55.png
# 保存扩增并添加噪声的图像: augmented_with_noise_56.png
# 保存扩增并添加噪声的图像: augmented_with_noise_57.png
# 保存扩增并添加噪声的图像: augmented_with_noise_58.png
# 保存扩增并添加噪声的图像: augmented_with_noise_59.png
# 保存扩增并添加噪声的图像: augmented_with_noise_60.png
# 保存扩增并添加噪声的图像: augmented_with_noise_61.png
# 保存扩增并添加噪声的图像: augmented_with_noise_62.png
# 保存扩增并添加噪声的图像: augmented_with_noise_63.png
# 保存扩增并添加噪声的图像: augmented_with_noise_64.png
# 保存扩增并添加噪声的图像: augmented_with_noise_65.png
# 保存扩增并添加噪声的图像: augmented_with_noise_66.png
# 保存扩增并添加噪声的图像: augmented_with_noise_67.png
# 保存扩增并添加噪声的图像: augmented_with_noise_68.png
# 保存扩增并添加噪声的图像: augmented_with_noise_69.png
# 保存扩增并添加噪声的图像: augmented_with_noise_70.png
# 保存扩增并添加噪声的图像: augmented_with_noise_71.png
# 保存扩增并添加噪声的图像: augmented_with_noise_72.png
# 保存扩增并添加噪声的图像: augmented_with_noise_73.png
# 保存扩增并添加噪声的图像: augmented_with_noise_74.png
# 保存扩增并添加噪声的图像: augmented_with_noise_75.png
# 保存扩增并添加噪声的图像: augmented_with_noise_76.png
# 保存扩增并添加噪声的图像: augmented_with_noise_77.png
# 保存扩增并添加噪声的图像: augmented_with_noise_78.png
# 保存扩增并添加噪声的图像: augmented_with_noise_79.png
# 保存扩增并添加噪声的图像: augmented_with_noise_80.png
# 保存扩增并添加噪声的图像: augmented_with_noise_81.png
# 保存扩增并添加噪声的图像: augmented_with_noise_82.png
# 保存扩增并添加噪声的图像: augmented_with_noise_83.png
# 保存扩增并添加噪声的图像: augmented_with_noise_84.png
# 保存扩增并添加噪声的图像: augmented_with_noise_85.png
# 保存扩增并添加噪声的图像: augmented_with_noise_86.png
# 保存扩增并添加噪声的图像: augmented_with_noise_87.png
# 保存扩增并添加噪声的图像: augmented_with_noise_88.png
# 保存扩增并添加噪声的图像: augmented_with_noise_89.png
# 保存扩增并添加噪声的图像: augmented_with_noise_90.png
# 保存扩增并添加噪声的图像: augmented_with_noise_91.png
# 保存扩增并添加噪声的图像: augmented_with_noise_92.png
# 保存扩增并添加噪声的图像: augmented_with_noise_93.png
# 保存扩增并添加噪声的图像: augmented_with_noise_94.png
# 保存扩增并添加噪声的图像: augmented_with_noise_95.png
# 保存扩增并添加噪声的图像: augmented_with_noise_96.png
# 保存扩增并添加噪声的图像: augmented_with_noise_97.png
# 保存扩增并添加噪声的图像: augmented_with_noise_98.png
# 保存扩增并添加噪声的图像: augmented_with_noise_99.png
# 保存扩增并添加噪声的图像: augmented_with_noise_100.png
# 保存扩增并添加噪声的图像: augmented_with_noise_101.png
# 保存扩增并添加噪声的图像: augmented_with_noise_102.png
# 保存扩增并添加噪声的图像: augmented_with_noise_103.png
# 保存扩增并添加噪声的图像: augmented_with_noise_104.png
# 保存扩增并添加噪声的图像: augmented_with_noise_105.png
# 保存扩增并添加噪声的图像: augmented_with_noise_106.png
# 保存扩增并添加噪声的图像: augmented_with_noise_107.png
# 保存扩增并添加噪声的图像: augmented_with_noise_108.png
# 保存扩增并添加噪声的图像: augmented_with_noise_109.png
# 保存扩增并添加噪声的图像: augmented_with_noise_110.png
# 保存扩增并添加噪声的图像: augmented_with_noise_111.png
# 保存扩增并添加噪声的图像: augmented_with_noise_112.png
# 保存扩增并添加噪声的图像: augmented_with_noise_113.png
# 保存扩增并添加噪声的图像: augmented_with_noise_114.png
# 保存扩增并添加噪声的图像: augmented_with_noise_115.png
# 保存扩增并添加噪声的图像: augmented_with_noise_116.png
# 保存扩增并添加噪声的图像: augmented_with_noise_117.png
# 保存扩增并添加噪声的图像: augmented_with_noise_118.png
# 保存扩增并添加噪声的图像: augmented_with_noise_119.png
# 保存扩增并添加噪声的图像: augmented_with_noise_120.png
# 保存扩增并添加噪声的图像: augmented_with_noise_121.png
# 保存扩增并添加噪声的图像: augmented_with_noise_122.png
# 保存扩增并添加噪声的图像: augmented_with_noise_123.png
# 保存扩增并添加噪声的图像: augmented_with_noise_124.png
# 保存扩增并添加噪声的图像: augmented_with_noise_125.png
# 保存扩增并添加噪声的图像: augmented_with_noise_126.png
# 保存扩增并添加噪声的图像: augmented_with_noise_127.png
# 保存扩增并添加噪声的图像: augmented_with_noise_128.png
# 保存扩增并添加噪声的图像: augmented_with_noise_129.png
# 保存扩增并添加噪声的图像: augmented_with_noise_130.png
# 保存扩增并添加噪声的图像: augmented_with_noise_131.png
# 保存扩增并添加噪声的图像: augmented_with_noise_132.png
# 保存扩增并添加噪声的图像: augmented_with_noise_133.png
# 保存扩增并添加噪声的图像: augmented_with_noise_134.png
# 保存扩增并添加噪声的图像: augmented_with_noise_135.png
# 保存扩增并添加噪声的图像: augmented_with_noise_136.png
# 保存扩增并添加噪声的图像: augmented_with_noise_137.png
# 保存扩增并添加噪声的图像: augmented_with_noise_138.png
# 保存扩增并添加噪声的图像: augmented_with_noise_139.png
# 保存扩增并添加噪声的图像: augmented_with_noise_140.png
# 保存扩增并添加噪声的图像: augmented_with_noise_141.png
# 保存扩增并添加噪声的图像: augmented_with_noise_142.png
# 保存扩增并添加噪声的图像: augmented_with_noise_143.png
# 保存扩增并添加噪声的图像: augmented_with_noise_144.png
# 保存扩增并添加噪声的图像: augmented_with_noise_145.png
# 保存扩增并添加噪声的图像: augmented_with_noise_146.png
# 保存扩增并添加噪声的图像: augmented_with_noise_147.png
# 保存扩增并添加噪声的图像: augmented_with_noise_148.png
# 保存扩增并添加噪声的图像: augmented_with_noise_149.png
# 保存扩增并添加噪声的图像: augmented_with_noise_150.png
# 保存扩增并添加噪声的图像: augmented_with_noise_151.png
# 保存扩增并添加噪声的图像: augmented_with_noise_152.png
# 保存扩增并添加噪声的图像: augmented_with_noise_153.png
# 保存扩增并添加噪声的图像: augmented_with_noise_154.png
# 保存扩增并添加噪声的图像: augmented_with_noise_155.png
# 保存扩增并添加噪声的图像: augmented_with_noise_156.png
# 保存扩增并添加噪声的图像: augmented_with_noise_157.png
# 保存扩增并添加噪声的图像: augmented_with_noise_158.png
# 保存扩增并添加噪声的图像: augmented_with_noise_159.png
# 保存扩增并添加噪声的图像: augmented_with_noise_160.png
# 保存扩增并添加噪声的图像: augmented_with_noise_161.png
# 保存扩增并添加噪声的图像: augmented_with_noise_162.png
# 保存扩增并添加噪声的图像: augmented_with_noise_163.png
# 保存扩增并添加噪声的图像: augmented_with_noise_164.png
# 保存扩增并添加噪声的图像: augmented_with_noise_165.png
# 保存扩增并添加噪声的图像: augmented_with_noise_166.png
# 保存扩增并添加噪声的图像: augmented_with_noise_167.png
# 保存扩增并添加噪声的图像: augmented_with_noise_168.png
# 保存扩增并添加噪声的图像: augmented_with_noise_169.png
# 保存扩增并添加噪声的图像: augmented_with_noise_170.png
# 保存扩增并添加噪声的图像: augmented_with_noise_171.png
# 保存扩增并添加噪声的图像: augmented_with_noise_172.png
# 保存扩增并添加噪声的图像: augmented_with_noise_173.png
# 保存扩增并添加噪声的图像: augmented_with_noise_174.png
# 保存扩增并添加噪声的图像: augmented_with_noise_175.png
# 保存扩增并添加噪声的图像: augmented_with_noise_176.png
# 保存扩增并添加噪声的图像: augmented_with_noise_177.png
# 保存扩增并添加噪声的图像: augmented_with_noise_178.png
# 保存扩增并添加噪声的图像: augmented_with_noise_179.png
# 保存扩增并添加噪声的图像: augmented_with_noise_180.png
# 保存扩增并添加噪声的图像: augmented_with_noise_181.png
# 保存扩增并添加噪声的图像: augmented_with_noise_182.png
# 保存扩增并添加噪声的图像: augmented_with_noise_183.png
# 保存扩增并添加噪声的图像: augmented_with_noise_184.png
# 保存扩增并添加噪声的图像: augmented_with_noise_185.png
# 保存扩增并添加噪声的图像: augmented_with_noise_186.png
# 保存扩增并添加噪声的图像: augmented_with_noise_187.png
# 保存扩增并添加噪声的图像: augmented_with_noise_188.png
# 保存扩增并添加噪声的图像: augmented_with_noise_189.png
# 保存扩增并添加噪声的图像: augmented_with_noise_190.png
# 保存扩增并添加噪声的图像: augmented_with_noise_191.png
# 保存扩增并添加噪声的图像: augmented_with_noise_192.png
# 保存扩增并添加噪声的图像: augmented_with_noise_193.png
# 保存扩增并添加噪声的图像: augmented_with_noise_194.png
# 保存扩增并添加噪声的图像: augmented_with_noise_195.png
# 保存扩增并添加噪声的图像: augmented_with_noise_196.png
# 保存扩增并添加噪声的图像: augmented_with_noise_197.png
# 保存扩增并添加噪声的图像: augmented_with_noise_198.png
# 保存扩增并添加噪声的图像: augmented_with_noise_199.png
# 保存扩增并添加噪声的图像: augmented_with_noise_200.png
# 保存扩增并添加噪声的图像: augmented_with_noise_201.png
# 保存扩增并添加噪声的图像: augmented_with_noise_202.png
# 保存扩增并添加噪声的图像: augmented_with_noise_203.png
# 保存扩增并添加噪声的图像: augmented_with_noise_204.png
# 保存扩增并添加噪声的图像: augmented_with_noise_205.png
# 保存扩增并添加噪声的图像: augmented_with_noise_206.png
# 保存扩增并添加噪声的图像: augmented_with_noise_207.png
# 保存扩增并添加噪声的图像: augmented_with_noise_208.png
# 保存扩增并添加噪声的图像: augmented_with_noise_209.png
# 保存扩增并添加噪声的图像: augmented_with_noise_210.png
# 保存扩增并添加噪声的图像: augmented_with_noise_211.png
# 保存扩增并添加噪声的图像: augmented_with_noise_212.png
# 保存扩增并添加噪声的图像: augmented_with_noise_213.png
# 保存扩增并添加噪声的图像: augmented_with_noise_214.png
# 保存扩增并添加噪声的图像: augmented_with_noise_215.png
# 保存扩增并添加噪声的图像: augmented_with_noise_216.png
# 保存扩增并添加噪声的图像: augmented_with_noise_217.png
# 保存扩增并添加噪声的图像: augmented_with_noise_218.png
# 保存扩增并添加噪声的图像: augmented_with_noise_219.png
# 保存扩增并添加噪声的图像: augmented_with_noise_220.png
# 保存扩增并添加噪声的图像: augmented_with_noise_221.png
# 保存扩增并添加噪声的图像: augmented_with_noise_222.png
# 保存扩增并添加噪声的图像: augmented_with_noise_223.png
# 保存扩增并添加噪声的图像: augmented_with_noise_224.png
# 保存扩增并添加噪声的图像: augmented_with_noise_225.png
# 保存扩增并添加噪声的图像: augmented_with_noise_226.png
# 保存扩增并添加噪声的图像: augmented_with_noise_227.png
# 保存扩增并添加噪声的图像: augmented_with_noise_228.png
# 保存扩增并添加噪声的图像: augmented_with_noise_229.png
# 保存扩增并添加噪声的图像: augmented_with_noise_230.png
# 保存扩增并添加噪声的图像: augmented_with_noise_231.png
# 保存扩增并添加噪声的图像: augmented_with_noise_232.png
# 保存扩增并添加噪声的图像: augmented_with_noise_233.png
# 保存扩增并添加噪声的图像: augmented_with_noise_234.png
# 保存扩增并添加噪声的图像: augmented_with_noise_235.png
# 保存扩增并添加噪声的图像: augmented_with_noise_236.png
# 保存扩增并添加噪声的图像: augmented_with_noise_237.png
# 保存扩增并添加噪声的图像: augmented_with_noise_238.png
# 保存扩增并添加噪声的图像: augmented_with_noise_239.png
# 保存扩增并添加噪声的图像: augmented_with_noise_240.png
# 保存扩增并添加噪声的图像: augmented_with_noise_241.png
# 保存扩增并添加噪声的图像: augmented_with_noise_242.png
# 保存扩增并添加噪声的图像: augmented_with_noise_243.png
# 保存扩增并添加噪声的图像: augmented_with_noise_244.png
# 保存扩增并添加噪声的图像: augmented_with_noise_245.png
# 保存扩增并添加噪声的图像: augmented_with_noise_246.png
# 保存扩增并添加噪声的图像: augmented_with_noise_247.png
# 保存扩增并添加噪声的图像: augmented_with_noise_248.png
# 保存扩增并添加噪声的图像: augmented_with_noise_249.png
# 保存扩增并添加噪声的图像: augmented_with_noise_250.png
# 保存扩增并添加噪声的图像: augmented_with_noise_251.png
# 保存扩增并添加噪声的图像: augmented_with_noise_252.png
# 保存扩增并添加噪声的图像: augmented_with_noise_253.png
# 保存扩增并添加噪声的图像: augmented_with_noise_254.png
# 保存扩增并添加噪声的图像: augmented_with_noise_255.png
# 保存扩增并添加噪声的图像: augmented_with_noise_256.png
# 保存扩增并添加噪声的图像: augmented_with_noise_257.png
# 保存扩增并添加噪声的图像: augmented_with_noise_258.png
# 保存扩增并添加噪声的图像: augmented_with_noise_259.png
# 保存扩增并添加噪声的图像: augmented_with_noise_260.png
# 保存扩增并添加噪声的图像: augmented_with_noise_261.png
# 保存扩增并添加噪声的图像: augmented_with_noise_262.png
# 保存扩增并添加噪声的图像: augmented_with_noise_263.png
# 保存扩增并添加噪声的图像: augmented_with_noise_264.png
# 保存扩增并添加噪声的图像: augmented_with_noise_265.png
# 保存扩增并添加噪声的图像: augmented_with_noise_266.png
# 保存扩增并添加噪声的图像: augmented_with_noise_267.png
# 保存扩增并添加噪声的图像: augmented_with_noise_268.png
# 保存扩增并添加噪声的图像: augmented_with_noise_269.png
# 保存扩增并添加噪声的图像: augmented_with_noise_270.png
# 保存扩增并添加噪声的图像: augmented_with_noise_271.png
# 保存扩增并添加噪声的图像: augmented_with_noise_272.png
# 保存扩增并添加噪声的图像: augmented_with_noise_273.png
# 保存扩增并添加噪声的图像: augmented_with_noise_274.png
# 保存扩增并添加噪声的图像: augmented_with_noise_275.png
# 保存扩增并添加噪声的图像: augmented_with_noise_276.png
# 保存扩增并添加噪声的图像: augmented_with_noise_277.png
# 保存扩增并添加噪声的图像: augmented_with_noise_278.png
# 保存扩增并添加噪声的图像: augmented_with_noise_279.png
# 保存扩增并添加噪声的图像: augmented_with_noise_280.png
# 保存扩增并添加噪声的图像: augmented_with_noise_281.png
# 保存扩增并添加噪声的图像: augmented_with_noise_282.png
# 保存扩增并添加噪声的图像: augmented_with_noise_283.png
# 保存扩增并添加噪声的图像: augmented_with_noise_284.png
# 保存扩增并添加噪声的图像: augmented_with_noise_285.png
# 保存扩增并添加噪声的图像: augmented_with_noise_286.png
# 保存扩增并添加噪声的图像: augmented_with_noise_287.png
# 保存扩增并添加噪声的图像: augmented_with_noise_288.png
# 保存扩增并添加噪声的图像: augmented_with_noise_289.png
# 保存扩增并添加噪声的图像: augmented_with_noise_290.png
# 保存扩增并添加噪声的图像: augmented_with_noise_291.png
# 保存扩增并添加噪声的图像: augmented_with_noise_292.png
# 保存扩增并添加噪声的图像: augmented_with_noise_293.png
# 保存扩增并添加噪声的图像: augmented_with_noise_294.png
# 保存扩增并添加噪声的图像: augmented_with_noise_295.png
# 保存扩增并添加噪声的图像: augmented_with_noise_296.png
# 保存扩增并添加噪声的图像: augmented_with_noise_297.png
# 保存扩增并添加噪声的图像: augmented_with_noise_298.png
# 保存扩增并添加噪声的图像: augmented_with_noise_299.png
# 保存扩增并添加噪声的图像: augmented_with_noise_300.png
# 保存扩增并添加噪声的图像: augmented_with_noise_301.png
# 保存扩增并添加噪声的图像: augmented_with_noise_302.png
# 保存扩增并添加噪声的图像: augmented_with_noise_303.png
# 保存扩增并添加噪声的图像: augmented_with_noise_304.png
# 保存扩增并添加噪声的图像: augmented_with_noise_305.png
# 保存扩增并添加噪声的图像: augmented_with_noise_306.png
# 保存扩增并添加噪声的图像: augmented_with_noise_307.png
# 保存扩增并添加噪声的图像: augmented_with_noise_308.png
# 保存扩增并添加噪声的图像: augmented_with_noise_309.png
# 保存扩增并添加噪声的图像: augmented_with_noise_310.png
# 保存扩增并添加噪声的图像: augmented_with_noise_311.png
# 保存扩增并添加噪声的图像: augmented_with_noise_312.png
# 保存扩增并添加噪声的图像: augmented_with_noise_313.png
# 保存扩增并添加噪声的图像: augmented_with_noise_314.png
# 保存扩增并添加噪声的图像: augmented_with_noise_315.png
# 保存扩增并添加噪声的图像: augmented_with_noise_316.png
# 保存扩增并添加噪声的图像: augmented_with_noise_317.png
# 保存扩增并添加噪声的图像: augmented_with_noise_318.png
# 保存扩增并添加噪声的图像: augmented_with_noise_319.png
# 保存扩增并添加噪声的图像: augmented_with_noise_320.png
# 保存扩增并添加噪声的图像: augmented_with_noise_321.png
# 保存扩增并添加噪声的图像: augmented_with_noise_322.png
# 保存扩增并添加噪声的图像: augmented_with_noise_323.png
# 保存扩增并添加噪声的图像: augmented_with_noise_324.png
# 保存扩增并添加噪声的图像: augmented_with_noise_325.png
# 保存扩增并添加噪声的图像: augmented_with_noise_326.png
# 保存扩增并添加噪声的图像: augmented_with_noise_327.png
# 保存扩增并添加噪声的图像: augmented_with_noise_328.png
# 保存扩增并添加噪声的图像: augmented_with_noise_329.png
# 保存扩增并添加噪声的图像: augmented_with_noise_330.png
# 保存扩增并添加噪声的图像: augmented_with_noise_331.png
# 保存扩增并添加噪声的图像: augmented_with_noise_332.png
# 保存扩增并添加噪声的图像: augmented_with_noise_333.png
# 保存扩增并添加噪声的图像: augmented_with_noise_334.png
# 保存扩增并添加噪声的图像: augmented_with_noise_335.png
# 保存扩增并添加噪声的图像: augmented_with_noise_336.png
# 保存扩增并添加噪声的图像: augmented_with_noise_337.png
# 保存扩增并添加噪声的图像: augmented_with_noise_338.png
# 保存扩增并添加噪声的图像: augmented_with_noise_339.png
# 保存扩增并添加噪声的图像: augmented_with_noise_340.png
# 保存扩增并添加噪声的图像: augmented_with_noise_341.png
# 保存扩增并添加噪声的图像: augmented_with_noise_342.png
# 保存扩增并添加噪声的图像: augmented_with_noise_343.png
# 保存扩增并添加噪声的图像: augmented_with_noise_344.png
# 保存扩增并添加噪声的图像: augmented_with_noise_345.png
# 保存扩增并添加噪声的图像: augmented_with_noise_346.png
# 保存扩增并添加噪声的图像: augmented_with_noise_347.png
# 保存扩增并添加噪声的图像: augmented_with_noise_348.png
# 保存扩增并添加噪声的图像: augmented_with_noise_349.png
# 保存扩增并添加噪声的图像: augmented_with_noise_350.png
# 保存扩增并添加噪声的图像: augmented_with_noise_351.png
# 保存扩增并添加噪声的图像: augmented_with_noise_352.png
# 保存扩增并添加噪声的图像: augmented_with_noise_353.png
# 保存扩增并添加噪声的图像: augmented_with_noise_354.png
# 保存扩增并添加噪声的图像: augmented_with_noise_355.png
# 保存扩增并添加噪声的图像: augmented_with_noise_356.png
# 保存扩增并添加噪声的图像: augmented_with_noise_357.png
# 保存扩增并添加噪声的图像: augmented_with_noise_358.png
# 保存扩增并添加噪声的图像: augmented_with_noise_359.png
# 保存扩增并添加噪声的图像: augmented_with_noise_360.png
# 保存扩增并添加噪声的图像: augmented_with_noise_361.png
# 保存扩增并添加噪声的图像: augmented_with_noise_362.png
# 保存扩增并添加噪声的图像: augmented_with_noise_363.png
# 保存扩增并添加噪声的图像: augmented_with_noise_364.png
# 保存扩增并添加噪声的图像: augmented_with_noise_365.png
# 保存扩增并添加噪声的图像: augmented_with_noise_366.png
# 保存扩增并添加噪声的图像: augmented_with_noise_367.png
# 保存扩增并添加噪声的图像: augmented_with_noise_368.png
# 保存扩增并添加噪声的图像: augmented_with_noise_369.png
# 保存扩增并添加噪声的图像: augmented_with_noise_370.png
# 保存扩增并添加噪声的图像: augmented_with_noise_371.png
# 保存扩增并添加噪声的图像: augmented_with_noise_372.png
# 保存扩增并添加噪声的图像: augmented_with_noise_373.png
# 保存扩增并添加噪声的图像: augmented_with_noise_374.png
# 保存扩增并添加噪声的图像: augmented_with_noise_375.png
# 保存扩增并添加噪声的图像: augmented_with_noise_376.png
# 保存扩增并添加噪声的图像: augmented_with_noise_377.png
# 保存扩增并添加噪声的图像: augmented_with_noise_378.png
# 保存扩增并添加噪声的图像: augmented_with_noise_379.png
# 保存扩增并添加噪声的图像: augmented_with_noise_380.png
# 保存扩增并添加噪声的图像: augmented_with_noise_381.png
# 保存扩增并添加噪声的图像: augmented_with_noise_382.png
# 保存扩增并添加噪声的图像: augmented_with_noise_383.png
# 保存扩增并添加噪声的图像: augmented_with_noise_384.png
# 保存扩增并添加噪声的图像: augmented_with_noise_385.png
# 保存扩增并添加噪声的图像: augmented_with_noise_386.png
# 保存扩增并添加噪声的图像: augmented_with_noise_387.png
# 保存扩增并添加噪声的图像: augmented_with_noise_388.png
# 保存扩增并添加噪声的图像: augmented_with_noise_389.png
# 保存扩增并添加噪声的图像: augmented_with_noise_390.png
# 保存扩增并添加噪声的图像: augmented_with_noise_391.png
# 保存扩增并添加噪声的图像: augmented_with_noise_392.png
# 保存扩增并添加噪声的图像: augmented_with_noise_393.png
# 保存扩增并添加噪声的图像: augmented_with_noise_394.png
# 保存扩增并添加噪声的图像: augmented_with_noise_395.png
# 保存扩增并添加噪声的图像: augmented_with_noise_396.png
# 保存扩增并添加噪声的图像: augmented_with_noise_397.png
# 保存扩增并添加噪声的图像: augmented_with_noise_398.png
# 保存扩增并添加噪声的图像: augmented_with_noise_399.png
# 保存扩增并添加噪声的图像: augmented_with_noise_400.png
# 保存扩增并添加噪声的图像: augmented_with_noise_401.png
# 保存扩增并添加噪声的图像: augmented_with_noise_402.png
# 保存扩增并添加噪声的图像: augmented_with_noise_403.png
# 保存扩增并添加噪声的图像: augmented_with_noise_404.png
# 保存扩增并添加噪声的图像: augmented_with_noise_405.png
# 保存扩增并添加噪声的图像: augmented_with_noise_406.png
# 保存扩增并添加噪声的图像: augmented_with_noise_407.png
# 保存扩增并添加噪声的图像: augmented_with_noise_408.png
# 保存扩增并添加噪声的图像: augmented_with_noise_409.png
# 保存扩增并添加噪声的图像: augmented_with_noise_410.png
# 保存扩增并添加噪声的图像: augmented_with_noise_411.png
# 保存扩增并添加噪声的图像: augmented_with_noise_412.png
# 保存扩增并添加噪声的图像: augmented_with_noise_413.png
# 保存扩增并添加噪声的图像: augmented_with_noise_414.png
# 保存扩增并添加噪声的图像: augmented_with_noise_415.png
# 保存扩增并添加噪声的图像: augmented_with_noise_416.png
# 保存扩增并添加噪声的图像: augmented_with_noise_417.png
# 保存扩增并添加噪声的图像: augmented_with_noise_418.png
# 保存扩增并添加噪声的图像: augmented_with_noise_419.png
# 保存扩增并添加噪声的图像: augmented_with_noise_420.png
# 保存扩增并添加噪声的图像: augmented_with_noise_421.png
# 保存扩增并添加噪声的图像: augmented_with_noise_422.png
# 保存扩增并添加噪声的图像: augmented_with_noise_423.png
# 保存扩增并添加噪声的图像: augmented_with_noise_424.png
# 保存扩增并添加噪声的图像: augmented_with_noise_425.png
# 保存扩增并添加噪声的图像: augmented_with_noise_426.png
# 保存扩增并添加噪声的图像: augmented_with_noise_427.png
# 保存扩增并添加噪声的图像: augmented_with_noise_428.png
# 保存扩增并添加噪声的图像: augmented_with_noise_429.png
# 保存扩增并添加噪声的图像: augmented_with_noise_430.png
# 保存扩增并添加噪声的图像: augmented_with_noise_431.png
# 保存扩增并添加噪声的图像: augmented_with_noise_432.png
# 保存扩增并添加噪声的图像: augmented_with_noise_433.png
# 保存扩增并添加噪声的图像: augmented_with_noise_434.png
# 保存扩增并添加噪声的图像: augmented_with_noise_435.png
# 保存扩增并添加噪声的图像: augmented_with_noise_436.png
# 保存扩增并添加噪声的图像: augmented_with_noise_437.png
# 保存扩增并添加噪声的图像: augmented_with_noise_438.png
# 保存扩增并添加噪声的图像: augmented_with_noise_439.png
# 保存扩增并添加噪声的图像: augmented_with_noise_440.png
# 保存扩增并添加噪声的图像: augmented_with_noise_441.png
# 保存扩增并添加噪声的图像: augmented_with_noise_442.png
# 保存扩增并添加噪声的图像: augmented_with_noise_443.png
# 保存扩增并添加噪声的图像: augmented_with_noise_444.png
# 保存扩增并添加噪声的图像: augmented_with_noise_445.png
# 保存扩增并添加噪声的图像: augmented_with_noise_446.png
# 保存扩增并添加噪声的图像: augmented_with_noise_447.png
# 保存扩增并添加噪声的图像: augmented_with_noise_448.png
# 保存扩增并添加噪声的图像: augmented_with_noise_449.png
# 保存扩增并添加噪声的图像: augmented_with_noise_450.png
# 保存扩增并添加噪声的图像: augmented_with_noise_451.png
# 保存扩增并添加噪声的图像: augmented_with_noise_452.png
# 保存扩增并添加噪声的图像: augmented_with_noise_453.png
# 保存扩增并添加噪声的图像: augmented_with_noise_454.png
# 保存扩增并添加噪声的图像: augmented_with_noise_455.png
# 保存扩增并添加噪声的图像: augmented_with_noise_456.png
# 保存扩增并添加噪声的图像: augmented_with_noise_457.png
# 保存扩增并添加噪声的图像: augmented_with_noise_458.png
# 保存扩增并添加噪声的图像: augmented_with_noise_459.png
# 保存扩增并添加噪声的图像: augmented_with_noise_460.png
# 保存扩增并添加噪声的图像: augmented_with_noise_461.png
# 保存扩增并添加噪声的图像: augmented_with_noise_462.png
# 保存扩增并添加噪声的图像: augmented_with_noise_463.png
# 保存扩增并添加噪声的图像: augmented_with_noise_464.png
# 保存扩增并添加噪声的图像: augmented_with_noise_465.png
# 保存扩增并添加噪声的图像: augmented_with_noise_466.png
# 保存扩增并添加噪声的图像: augmented_with_noise_467.png
# 保存扩增并添加噪声的图像: augmented_with_noise_468.png
# 保存扩增并添加噪声的图像: augmented_with_noise_469.png
# 保存扩增并添加噪声的图像: augmented_with_noise_470.png
# 保存扩增并添加噪声的图像: augmented_with_noise_471.png
# 保存扩增并添加噪声的图像: augmented_with_noise_472.png
# 保存扩增并添加噪声的图像: augmented_with_noise_473.png
# 保存扩增并添加噪声的图像: augmented_with_noise_474.png
# 保存扩增并添加噪声的图像: augmented_with_noise_475.png
# 保存扩增并添加噪声的图像: augmented_with_noise_476.png
# 保存扩增并添加噪声的图像: augmented_with_noise_477.png
# 保存扩增并添加噪声的图像: augmented_with_noise_478.png
# 保存扩增并添加噪声的图像: augmented_with_noise_479.png
# 保存扩增并添加噪声的图像: augmented_with_noise_480.png
# 保存扩增并添加噪声的图像: augmented_with_noise_481.png
# 保存扩增并添加噪声的图像: augmented_with_noise_482.png
# 保存扩增并添加噪声的图像: augmented_with_noise_483.png
# 保存扩增并添加噪声的图像: augmented_with_noise_484.png
# 保存扩增并添加噪声的图像: augmented_with_noise_485.png
# 保存扩增并添加噪声的图像: augmented_with_noise_486.png
# 保存扩增并添加噪声的图像: augmented_with_noise_487.png
# 保存扩增并添加噪声的图像: augmented_with_noise_488.png
# 保存扩增并添加噪声的图像: augmented_with_noise_489.png
# 保存扩增并添加噪声的图像: augmented_with_noise_490.png
# 保存扩增并添加噪声的图像: augmented_with_noise_491.png
# 保存扩增并添加噪声的图像: augmented_with_noise_492.png
# 保存扩增并添加噪声的图像: augmented_with_noise_493.png
# 保存扩增并添加噪声的图像: augmented_with_noise_494.png
# 保存扩增并添加噪声的图像: augmented_with_noise_495.png
# 保存扩增并添加噪声的图像: augmented_with_noise_496.png
# 保存扩增并添加噪声的图像: augmented_with_noise_497.png
# 保存扩增并添加噪声的图像: augmented_with_noise_498.png
# 保存扩增并添加噪声的图像: augmented_with_noise_499.png
# 保存扩增并添加噪声的图像: augmented_with_noise_500.png
# 保存扩增并添加噪声的图像: augmented_with_noise_501.png
# 保存扩增并添加噪声的图像: augmented_with_noise_502.png
# 保存扩增并添加噪声的图像: augmented_with_noise_503.png
# 保存扩增并添加噪声的图像: augmented_with_noise_504.png
# 保存扩增并添加噪声的图像: augmented_with_noise_505.png
# 保存扩增并添加噪声的图像: augmented_with_noise_506.png
# 保存扩增并添加噪声的图像: augmented_with_noise_507.png
# 保存扩增并添加噪声的图像: augmented_with_noise_508.png
# 保存扩增并添加噪声的图像: augmented_with_noise_509.png
# 保存扩增并添加噪声的图像: augmented_with_noise_510.png
# 保存扩增并添加噪声的图像: augmented_with_noise_511.png
# 保存扩增并添加噪声的图像: augmented_with_noise_512.png
# 保存扩增并添加噪声的图像: augmented_with_noise_513.png
# 保存扩增并添加噪声的图像: augmented_with_noise_514.png
# 保存扩增并添加噪声的图像: augmented_with_noise_515.png
# 保存扩增并添加噪声的图像: augmented_with_noise_516.png
# 保存扩增并添加噪声的图像: augmented_with_noise_517.png
# 保存扩增并添加噪声的图像: augmented_with_noise_518.png
# 保存扩增并添加噪声的图像: augmented_with_noise_519.png
# 保存扩增并添加噪声的图像: augmented_with_noise_520.png
# 保存扩增并添加噪声的图像: augmented_with_noise_521.png
# 保存扩增并添加噪声的图像: augmented_with_noise_522.png
# 保存扩增并添加噪声的图像: augmented_with_noise_523.png
# 保存扩增并添加噪声的图像: augmented_with_noise_524.png
# 保存扩增并添加噪声的图像: augmented_with_noise_525.png
# 保存扩增并添加噪声的图像: augmented_with_noise_526.png
# 保存扩增并添加噪声的图像: augmented_with_noise_527.png
# 保存扩增并添加噪声的图像: augmented_with_noise_528.png
# 保存扩增并添加噪声的图像: augmented_with_noise_529.png
# 保存扩增并添加噪声的图像: augmented_with_noise_530.png
# 保存扩增并添加噪声的图像: augmented_with_noise_531.png
# 保存扩增并添加噪声的图像: augmented_with_noise_532.png
# 保存扩增并添加噪声的图像: augmented_with_noise_533.png
# 保存扩增并添加噪声的图像: augmented_with_noise_534.png
# 保存扩增并添加噪声的图像: augmented_with_noise_535.png
# 保存扩增并添加噪声的图像: augmented_with_noise_536.png
# 保存扩增并添加噪声的图像: augmented_with_noise_537.png
# 保存扩增并添加噪声的图像: augmented_with_noise_538.png
# 保存扩增并添加噪声的图像: augmented_with_noise_539.png
# 保存扩增并添加噪声的图像: augmented_with_noise_540.png
# 保存扩增并添加噪声的图像: augmented_with_noise_541.png
# 保存扩增并添加噪声的图像: augmented_with_noise_542.png
# 保存扩增并添加噪声的图像: augmented_with_noise_543.png
# 保存扩增并添加噪声的图像: augmented_with_noise_544.png
# 保存扩增并添加噪声的图像: augmented_with_noise_545.png
# 保存扩增并添加噪声的图像: augmented_with_noise_546.png
# 保存扩增并添加噪声的图像: augmented_with_noise_547.png
# 保存扩增并添加噪声的图像: augmented_with_noise_548.png
# 保存扩增并添加噪声的图像: augmented_with_noise_549.png
# 保存扩增并添加噪声的图像: augmented_with_noise_550.png
# 保存扩增并添加噪声的图像: augmented_with_noise_551.png
# 保存扩增并添加噪声的图像: augmented_with_noise_552.png
# 保存扩增并添加噪声的图像: augmented_with_noise_553.png
# 保存扩增并添加噪声的图像: augmented_with_noise_554.png
# 保存扩增并添加噪声的图像: augmented_with_noise_555.png
# 保存扩增并添加噪声的图像: augmented_with_noise_556.png
# 保存扩增并添加噪声的图像: augmented_with_noise_557.png
# 保存扩增并添加噪声的图像: augmented_with_noise_558.png
# 保存扩增并添加噪声的图像: augmented_with_noise_559.png
# 保存扩增并添加噪声的图像: augmented_with_noise_560.png
# 保存扩增并添加噪声的图像: augmented_with_noise_561.png
# 保存扩增并添加噪声的图像: augmented_with_noise_562.png
# 保存扩增并添加噪声的图像: augmented_with_noise_563.png
# 保存扩增并添加噪声的图像: augmented_with_noise_564.png
# 保存扩增并添加噪声的图像: augmented_with_noise_565.png
# 保存扩增并添加噪声的图像: augmented_with_noise_566.png
# 保存扩增并添加噪声的图像: augmented_with_noise_567.png
# 保存扩增并添加噪声的图像: augmented_with_noise_568.png
# 保存扩增并添加噪声的图像: augmented_with_noise_569.png
# 保存扩增并添加噪声的图像: augmented_with_noise_570.png
# 保存扩增并添加噪声的图像: augmented_with_noise_571.png
# 保存扩增并添加噪声的图像: augmented_with_noise_572.png
# 保存扩增并添加噪声的图像: augmented_with_noise_573.png
# 保存扩增并添加噪声的图像: augmented_with_noise_574.png
# 保存扩增并添加噪声的图像: augmented_with_noise_575.png
# 保存扩增并添加噪声的图像: augmented_with_noise_576.png
# 保存扩增并添加噪声的图像: augmented_with_noise_577.png
# 保存扩增并添加噪声的图像: augmented_with_noise_578.png
# 保存扩增并添加噪声的图像: augmented_with_noise_579.png
# 保存扩增并添加噪声的图像: augmented_with_noise_580.png
# 保存扩增并添加噪声的图像: augmented_with_noise_581.png
# 保存扩增并添加噪声的图像: augmented_with_noise_582.png
# 保存扩增并添加噪声的图像: augmented_with_noise_583.png
# 保存扩增并添加噪声的图像: augmented_with_noise_584.png
# 保存扩增并添加噪声的图像: augmented_with_noise_585.png
# 保存扩增并添加噪声的图像: augmented_with_noise_586.png
# 保存扩增并添加噪声的图像: augmented_with_noise_587.png
# 保存扩增并添加噪声的图像: augmented_with_noise_588.png
# 保存扩增并添加噪声的图像: augmented_with_noise_589.png
# 保存扩增并添加噪声的图像: augmented_with_noise_590.png
# 保存扩增并添加噪声的图像: augmented_with_noise_591.png
# 保存扩增并添加噪声的图像: augmented_with_noise_592.png
# 保存扩增并添加噪声的图像: augmented_with_noise_593.png
# 保存扩增并添加噪声的图像: augmented_with_noise_594.png
# 保存扩增并添加噪声的图像: augmented_with_noise_595.png
# 保存扩增并添加噪声的图像: augmented_with_noise_596.png
# 保存扩增并添加噪声的图像: augmented_with_noise_597.png
# 保存扩增并添加噪声的图像: augmented_with_noise_598.png
# 保存扩增并添加噪声的图像: augmented_with_noise_599.png
# 保存扩增并添加噪声的图像: augmented_with_noise_600.png
# 保存扩增并添加噪声的图像: augmented_with_noise_601.png
# 保存扩增并添加噪声的图像: augmented_with_noise_602.png
# 保存扩增并添加噪声的图像: augmented_with_noise_603.png
# 保存扩增并添加噪声的图像: augmented_with_noise_604.png
# 保存扩增并添加噪声的图像: augmented_with_noise_605.png
# 保存扩增并添加噪声的图像: augmented_with_noise_606.png
# 保存扩增并添加噪声的图像: augmented_with_noise_607.png
# 保存扩增并添加噪声的图像: augmented_with_noise_608.png
# 保存扩增并添加噪声的图像: augmented_with_noise_609.png
# 保存扩增并添加噪声的图像: augmented_with_noise_610.png
# 保存扩增并添加噪声的图像: augmented_with_noise_611.png
# 保存扩增并添加噪声的图像: augmented_with_noise_612.png
# 保存扩增并添加噪声的图像: augmented_with_noise_613.png
# 保存扩增并添加噪声的图像: augmented_with_noise_614.png
# 保存扩增并添加噪声的图像: augmented_with_noise_615.png
# 保存扩增并添加噪声的图像: augmented_with_noise_616.png
# 保存扩增并添加噪声的图像: augmented_with_noise_617.png
# 保存扩增并添加噪声的图像: augmented_with_noise_618.png
# 保存扩增并添加噪声的图像: augmented_with_noise_619.png
# 保存扩增并添加噪声的图像: augmented_with_noise_620.png
# 保存扩增并添加噪声的图像: augmented_with_noise_621.png
# 保存扩增并添加噪声的图像: augmented_with_noise_622.png
# 保存扩增并添加噪声的图像: augmented_with_noise_623.png
# 保存扩增并添加噪声的图像: augmented_with_noise_624.png
# 保存扩增并添加噪声的图像: augmented_with_noise_625.png
# 保存扩增并添加噪声的图像: augmented_with_noise_626.png
# 保存扩增并添加噪声的图像: augmented_with_noise_627.png
# 保存扩增并添加噪声的图像: augmented_with_noise_628.png
# 保存扩增并添加噪声的图像: augmented_with_noise_629.png
# 保存扩增并添加噪声的图像: augmented_with_noise_630.png
# 保存扩增并添加噪声的图像: augmented_with_noise_631.png
# 保存扩增并添加噪声的图像: augmented_with_noise_632.png
# 保存扩增并添加噪声的图像: augmented_with_noise_633.png
# 保存扩增并添加噪声的图像: augmented_with_noise_634.png
# 保存扩增并添加噪声的图像: augmented_with_noise_635.png
# 保存扩增并添加噪声的图像: augmented_with_noise_636.png
# 保存扩增并添加噪声的图像: augmented_with_noise_637.png
# 保存扩增并添加噪声的图像: augmented_with_noise_638.png
# 保存扩增并添加噪声的图像: augmented_with_noise_639.png
# 保存扩增并添加噪声的图像: augmented_with_noise_640.png
# 保存扩增并添加噪声的图像: augmented_with_noise_641.png
# 保存扩增并添加噪声的图像: augmented_with_noise_642.png
# 保存扩增并添加噪声的图像: augmented_with_noise_643.png
# 保存扩增并添加噪声的图像: augmented_with_noise_644.png
# 保存扩增并添加噪声的图像: augmented_with_noise_645.png
# 保存扩增并添加噪声的图像: augmented_with_noise_646.png
# 保存扩增并添加噪声的图像: augmented_with_noise_647.png
# 保存扩增并添加噪声的图像: augmented_with_noise_648.png
# 保存扩增并添加噪声的图像: augmented_with_noise_649.png
# 保存扩增并添加噪声的图像: augmented_with_noise_650.png
# 保存扩增并添加噪声的图像: augmented_with_noise_651.png
# 保存扩增并添加噪声的图像: augmented_with_noise_652.png
# 保存扩增并添加噪声的图像: augmented_with_noise_653.png
# 保存扩增并添加噪声的图像: augmented_with_noise_654.png
# 保存扩增并添加噪声的图像: augmented_with_noise_655.png
# 保存扩增并添加噪声的图像: augmented_with_noise_656.png
# 保存扩增并添加噪声的图像: augmented_with_noise_657.png
# 保存扩增并添加噪声的图像: augmented_with_noise_658.png
# 保存扩增并添加噪声的图像: augmented_with_noise_659.png
# 保存扩增并添加噪声的图像: augmented_with_noise_660.png
# 保存扩增并添加噪声的图像: augmented_with_noise_661.png
# 保存扩增并添加噪声的图像: augmented_with_noise_662.png
# 保存扩增并添加噪声的图像: augmented_with_noise_663.png
# 保存扩增并添加噪声的图像: augmented_with_noise_664.png
# 保存扩增并添加噪声的图像: augmented_with_noise_665.png
# 保存扩增并添加噪声的图像: augmented_with_noise_666.png
# 保存扩增并添加噪声的图像: augmented_with_noise_667.png
# 保存扩增并添加噪声的图像: augmented_with_noise_668.png
# 保存扩增并添加噪声的图像: augmented_with_noise_669.png
# 保存扩增并添加噪声的图像: augmented_with_noise_670.png
# 保存扩增并添加噪声的图像: augmented_with_noise_671.png
# 保存扩增并添加噪声的图像: augmented_with_noise_672.png
# 保存扩增并添加噪声的图像: augmented_with_noise_673.png
# 保存扩增并添加噪声的图像: augmented_with_noise_674.png
# 保存扩增并添加噪声的图像: augmented_with_noise_675.png
# 保存扩增并添加噪声的图像: augmented_with_noise_676.png
# 保存扩增并添加噪声的图像: augmented_with_noise_677.png
# 保存扩增并添加噪声的图像: augmented_with_noise_678.png
# 保存扩增并添加噪声的图像: augmented_with_noise_679.png
# 保存扩增并添加噪声的图像: augmented_with_noise_680.png
# 保存扩增并添加噪声的图像: augmented_with_noise_681.png
# 保存扩增并添加噪声的图像: augmented_with_noise_682.png
# 保存扩增并添加噪声的图像: augmented_with_noise_683.png
# 保存扩增并添加噪声的图像: augmented_with_noise_684.png
# 保存扩增并添加噪声的图像: augmented_with_noise_685.png
# 保存扩增并添加噪声的图像: augmented_with_noise_686.png
# 保存扩增并添加噪声的图像: augmented_with_noise_687.png
# 保存扩增并添加噪声的图像: augmented_with_noise_688.png
# 保存扩增并添加噪声的图像: augmented_with_noise_689.png
# 保存扩增并添加噪声的图像: augmented_with_noise_690.png
# 保存扩增并添加噪声的图像: augmented_with_noise_691.png
# 保存扩增并添加噪声的图像: augmented_with_noise_692.png
# 保存扩增并添加噪声的图像: augmented_with_noise_693.png
# 保存扩增并添加噪声的图像: augmented_with_noise_694.png
# 保存扩增并添加噪声的图像: augmented_with_noise_695.png
# 保存扩增并添加噪声的图像: augmented_with_noise_696.png
# 保存扩增并添加噪声的图像: augmented_with_noise_697.png
# 保存扩增并添加噪声的图像: augmented_with_noise_698.png
# 保存扩增并添加噪声的图像: augmented_with_noise_699.png
# 保存扩增并添加噪声的图像: augmented_with_noise_700.png
# 保存扩增并添加噪声的图像: augmented_with_noise_701.png
# 保存扩增并添加噪声的图像: augmented_with_noise_702.png
# 保存扩增并添加噪声的图像: augmented_with_noise_703.png
# 保存扩增并添加噪声的图像: augmented_with_noise_704.png
# 保存扩增并添加噪声的图像: augmented_with_noise_705.png
# 保存扩增并添加噪声的图像: augmented_with_noise_706.png
# 保存扩增并添加噪声的图像: augmented_with_noise_707.png
# 保存扩增并添加噪声的图像: augmented_with_noise_708.png
# 保存扩增并添加噪声的图像: augmented_with_noise_709.png
# 保存扩增并添加噪声的图像: augmented_with_noise_710.png
# 保存扩增并添加噪声的图像: augmented_with_noise_711.png
# 保存扩增并添加噪声的图像: augmented_with_noise_712.png
# 保存扩增并添加噪声的图像: augmented_with_noise_713.png
# 保存扩增并添加噪声的图像: augmented_with_noise_714.png
# 保存扩增并添加噪声的图像: augmented_with_noise_715.png
# 保存扩增并添加噪声的图像: augmented_with_noise_716.png
# 保存扩增并添加噪声的图像: augmented_with_noise_717.png
# 保存扩增并添加噪声的图像: augmented_with_noise_718.png
# 保存扩增并添加噪声的图像: augmented_with_noise_719.png
# 保存扩增并添加噪声的图像: augmented_with_noise_720.png
# 保存扩增并添加噪声的图像: augmented_with_noise_721.png
# 保存扩增并添加噪声的图像: augmented_with_noise_722.png
# 保存扩增并添加噪声的图像: augmented_with_noise_723.png
# 保存扩增并添加噪声的图像: augmented_with_noise_724.png
# 保存扩增并添加噪声的图像: augmented_with_noise_725.png
# 保存扩增并添加噪声的图像: augmented_with_noise_726.png
# 保存扩增并添加噪声的图像: augmented_with_noise_727.png
# 保存扩增并添加噪声的图像: augmented_with_noise_728.png
# 保存扩增并添加噪声的图像: augmented_with_noise_729.png
# 保存扩增并添加噪声的图像: augmented_with_noise_730.png
# 保存扩增并添加噪声的图像: augmented_with_noise_731.png
# 保存扩增并添加噪声的图像: augmented_with_noise_732.png
# 保存扩增并添加噪声的图像: augmented_with_noise_733.png
# 保存扩增并添加噪声的图像: augmented_with_noise_734.png
# 保存扩增并添加噪声的图像: augmented_with_noise_735.png
# 保存扩增并添加噪声的图像: augmented_with_noise_736.png
# 保存扩增并添加噪声的图像: augmented_with_noise_737.png
# 保存扩增并添加噪声的图像: augmented_with_noise_738.png
# 保存扩增并添加噪声的图像: augmented_with_noise_739.png
# 保存扩增并添加噪声的图像: augmented_with_noise_740.png
# 保存扩增并添加噪声的图像: augmented_with_noise_741.png
# 保存扩增并添加噪声的图像: augmented_with_noise_742.png
# 保存扩增并添加噪声的图像: augmented_with_noise_743.png
# 保存扩增并添加噪声的图像: augmented_with_noise_744.png
# 保存扩增并添加噪声的图像: augmented_with_noise_745.png
# 保存扩增并添加噪声的图像: augmented_with_noise_746.png
# 保存扩增并添加噪声的图像: augmented_with_noise_747.png
# 保存扩增并添加噪声的图像: augmented_with_noise_748.png
# 保存扩增并添加噪声的图像: augmented_with_noise_749.png
# 保存扩增并添加噪声的图像: augmented_with_noise_750.png
# 保存扩增并添加噪声的图像: augmented_with_noise_751.png
# 保存扩增并添加噪声的图像: augmented_with_noise_752.png
# 保存扩增并添加噪声的图像: augmented_with_noise_753.png
# 保存扩增并添加噪声的图像: augmented_with_noise_754.png
# 保存扩增并添加噪声的图像: augmented_with_noise_755.png
# 保存扩增并添加噪声的图像: augmented_with_noise_756.png
# 保存扩增并添加噪声的图像: augmented_with_noise_757.png
# 保存扩增并添加噪声的图像: augmented_with_noise_758.png
# 保存扩增并添加噪声的图像: augmented_with_noise_759.png
# 保存扩增并添加噪声的图像: augmented_with_noise_760.png
# 保存扩增并添加噪声的图像: augmented_with_noise_761.png
# 保存扩增并添加噪声的图像: augmented_with_noise_762.png
# 保存扩增并添加噪声的图像: augmented_with_noise_763.png
# 保存扩增并添加噪声的图像: augmented_with_noise_764.png
# 保存扩增并添加噪声的图像: augmented_with_noise_765.png
# 保存扩增并添加噪声的图像: augmented_with_noise_766.png
# 保存扩增并添加噪声的图像: augmented_with_noise_767.png
# 保存扩增并添加噪声的图像: augmented_with_noise_768.png
# 保存扩增并添加噪声的图像: augmented_with_noise_769.png
# 保存扩增并添加噪声的图像: augmented_with_noise_770.png
# 保存扩增并添加噪声的图像: augmented_with_noise_771.png
# 保存扩增并添加噪声的图像: augmented_with_noise_772.png
# 保存扩增并添加噪声的图像: augmented_with_noise_773.png
# 保存扩增并添加噪声的图像: augmented_with_noise_774.png
# 保存扩增并添加噪声的图像: augmented_with_noise_775.png
# 保存扩增并添加噪声的图像: augmented_with_noise_776.png
# 保存扩增并添加噪声的图像: augmented_with_noise_777.png
# 保存扩增并添加噪声的图像: augmented_with_noise_778.png
# 保存扩增并添加噪声的图像: augmented_with_noise_779.png
# 保存扩增并添加噪声的图像: augmented_with_noise_780.png
# 保存扩增并添加噪声的图像: augmented_with_noise_781.png
# 保存扩增并添加噪声的图像: augmented_with_noise_782.png
# 保存扩增并添加噪声的图像: augmented_with_noise_783.png
# 保存扩增并添加噪声的图像: augmented_with_noise_784.png
# 保存扩增并添加噪声的图像: augmented_with_noise_785.png
# 保存扩增并添加噪声的图像: augmented_with_noise_786.png
# 保存扩增并添加噪声的图像: augmented_with_noise_787.png
# 保存扩增并添加噪声的图像: augmented_with_noise_788.png
# 保存扩增并添加噪声的图像: augmented_with_noise_789.png
# 保存扩增并添加噪声的图像: augmented_with_noise_790.png
# 保存扩增并添加噪声的图像: augmented_with_noise_791.png
# 保存扩增并添加噪声的图像: augmented_with_noise_792.png
# 保存扩增并添加噪声的图像: augmented_with_noise_793.png
# 保存扩增并添加噪声的图像: augmented_with_noise_794.png
# 保存扩增并添加噪声的图像: augmented_with_noise_795.png
# 保存扩增并添加噪声的图像: augmented_with_noise_796.png
# 保存扩增并添加噪声的图像: augmented_with_noise_797.png
# 保存扩增并添加噪声的图像: augmented_with_noise_798.png
# 保存扩增并添加噪声的图像: augmented_with_noise_799.png
# 保存扩增并添加噪声的图像: augmented_with_noise_800.png
# 保存扩增并添加噪声的图像: augmented_with_noise_801.png
# 保存扩增并添加噪声的图像: augmented_with_noise_802.png
# 保存扩增并添加噪声的图像: augmented_with_noise_803.png
# 保存扩增并添加噪声的图像: augmented_with_noise_804.png
# 保存扩增并添加噪声的图像: augmented_with_noise_805.png
# 保存扩增并添加噪声的图像: augmented_with_noise_806.png
# 保存扩增并添加噪声的图像: augmented_with_noise_807.png
# 保存扩增并添加噪声的图像: augmented_with_noise_808.png
# 保存扩增并添加噪声的图像: augmented_with_noise_809.png
# 保存扩增并添加噪声的图像: augmented_with_noise_810.png
# 保存扩增并添加噪声的图像: augmented_with_noise_811.png
# 保存扩增并添加噪声的图像: augmented_with_noise_812.png
# 保存扩增并添加噪声的图像: augmented_with_noise_813.png
# 保存扩增并添加噪声的图像: augmented_with_noise_814.png
# 保存扩增并添加噪声的图像: augmented_with_noise_815.png
# 保存扩增并添加噪声的图像: augmented_with_noise_816.png
# 保存扩增并添加噪声的图像: augmented_with_noise_817.png
# 保存扩增并添加噪声的图像: augmented_with_noise_818.png
# 保存扩增并添加噪声的图像: augmented_with_noise_819.png
# 保存扩增并添加噪声的图像: augmented_with_noise_820.png
# 保存扩增并添加噪声的图像: augmented_with_noise_821.png
# 保存扩增并添加噪声的图像: augmented_with_noise_822.png
# 保存扩增并添加噪声的图像: augmented_with_noise_823.png
# 保存扩增并添加噪声的图像: augmented_with_noise_824.png
# 保存扩增并添加噪声的图像: augmented_with_noise_825.png
# 保存扩增并添加噪声的图像: augmented_with_noise_826.png
# 保存扩增并添加噪声的图像: augmented_with_noise_827.png
# 保存扩增并添加噪声的图像: augmented_with_noise_828.png
# 保存扩增并添加噪声的图像: augmented_with_noise_829.png
# 保存扩增并添加噪声的图像: augmented_with_noise_830.png
# 保存扩增并添加噪声的图像: augmented_with_noise_831.png
# 保存扩增并添加噪声的图像: augmented_with_noise_832.png
# 保存扩增并添加噪声的图像: augmented_with_noise_833.png
# 保存扩增并添加噪声的图像: augmented_with_noise_834.png
# 保存扩增并添加噪声的图像: augmented_with_noise_835.png
# 保存扩增并添加噪声的图像: augmented_with_noise_836.png
# 保存扩增并添加噪声的图像: augmented_with_noise_837.png
# 保存扩增并添加噪声的图像: augmented_with_noise_838.png
# 保存扩增并添加噪声的图像: augmented_with_noise_839.png
# 保存扩增并添加噪声的图像: augmented_with_noise_840.png
# 保存扩增并添加噪声的图像: augmented_with_noise_841.png
# 保存扩增并添加噪声的图像: augmented_with_noise_842.png
# 保存扩增并添加噪声的图像: augmented_with_noise_843.png
# 保存扩增并添加噪声的图像: augmented_with_noise_844.png
# 保存扩增并添加噪声的图像: augmented_with_noise_845.png
# 保存扩增并添加噪声的图像: augmented_with_noise_846.png
# 保存扩增并添加噪声的图像: augmented_with_noise_847.png
# 保存扩增并添加噪声的图像: augmented_with_noise_848.png
# 保存扩增并添加噪声的图像: augmented_with_noise_849.png
# 保存扩增并添加噪声的图像: augmented_with_noise_850.png
# 保存扩增并添加噪声的图像: augmented_with_noise_851.png
# 保存扩增并添加噪声的图像: augmented_with_noise_852.png
# 保存扩增并添加噪声的图像: augmented_with_noise_853.png
# 保存扩增并添加噪声的图像: augmented_with_noise_854.png
# 保存扩增并添加噪声的图像: augmented_with_noise_855.png
# 保存扩增并添加噪声的图像: augmented_with_noise_856.png
# 保存扩增并添加噪声的图像: augmented_with_noise_857.png
# 保存扩增并添加噪声的图像: augmented_with_noise_858.png
# 保存扩增并添加噪声的图像: augmented_with_noise_859.png
# 保存扩增并添加噪声的图像: augmented_with_noise_860.png
# 保存扩增并添加噪声的图像: augmented_with_noise_861.png
# 保存扩增并添加噪声的图像: augmented_with_noise_862.png
# 保存扩增并添加噪声的图像: augmented_with_noise_863.png
# 保存扩增并添加噪声的图像: augmented_with_noise_864.png
# 保存扩增并添加噪声的图像: augmented_with_noise_865.png
# 保存扩增并添加噪声的图像: augmented_with_noise_866.png
# 保存扩增并添加噪声的图像: augmented_with_noise_867.png
# 保存扩增并添加噪声的图像: augmented_with_noise_868.png
# 保存扩增并添加噪声的图像: augmented_with_noise_869.png
# 保存扩增并添加噪声的图像: augmented_with_noise_870.png
# 保存扩增并添加噪声的图像: augmented_with_noise_871.png
# 保存扩增并添加噪声的图像: augmented_with_noise_872.png
# 保存扩增并添加噪声的图像: augmented_with_noise_873.png
# 保存扩增并添加噪声的图像: augmented_with_noise_874.png
# 保存扩增并添加噪声的图像: augmented_with_noise_875.png
# 保存扩增并添加噪声的图像: augmented_with_noise_876.png
# 保存扩增并添加噪声的图像: augmented_with_noise_877.png
# 保存扩增并添加噪声的图像: augmented_with_noise_878.png
# 保存扩增并添加噪声的图像: augmented_with_noise_879.png
# 保存扩增并添加噪声的图像: augmented_with_noise_880.png
# 保存扩增并添加噪声的图像: augmented_with_noise_881.png
# 保存扩增并添加噪声的图像: augmented_with_noise_882.png
# 保存扩增并添加噪声的图像: augmented_with_noise_883.png
# 保存扩增并添加噪声的图像: augmented_with_noise_884.png
# 保存扩增并添加噪声的图像: augmented_with_noise_885.png
# 保存扩增并添加噪声的图像: augmented_with_noise_886.png
# 保存扩增并添加噪声的图像: augmented_with_noise_887.png
# 保存扩增并添加噪声的图像: augmented_with_noise_888.png
# 保存扩增并添加噪声的图像: augmented_with_noise_889.png
# 保存扩增并添加噪声的图像: augmented_with_noise_890.png
# 保存扩增并添加噪声的图像: augmented_with_noise_891.png
# 保存扩增并添加噪声的图像: augmented_with_noise_892.png
# 保存扩增并添加噪声的图像: augmented_with_noise_893.png
# 保存扩增并添加噪声的图像: augmented_with_noise_894.png
# 保存扩增并添加噪声的图像: augmented_with_noise_895.png
# 保存扩增并添加噪声的图像: augmented_with_noise_896.png
# 保存扩增并添加噪声的图像: augmented_with_noise_897.png
# 保存扩增并添加噪声的图像: augmented_with_noise_898.png
# 保存扩增并添加噪声的图像: augmented_with_noise_899.png
# 保存扩增并添加噪声的图像: augmented_with_noise_900.png
# 保存扩增并添加噪声的图像: augmented_with_noise_901.png
# 保存扩增并添加噪声的图像: augmented_with_noise_902.png
# 保存扩增并添加噪声的图像: augmented_with_noise_903.png
# 保存扩增并添加噪声的图像: augmented_with_noise_904.png
# 保存扩增并添加噪声的图像: augmented_with_noise_905.png
# 保存扩增并添加噪声的图像: augmented_with_noise_906.png
# 保存扩增并添加噪声的图像: augmented_with_noise_907.png
# 保存扩增并添加噪声的图像: augmented_with_noise_908.png
# 保存扩增并添加噪声的图像: augmented_with_noise_909.png
# 保存扩增并添加噪声的图像: augmented_with_noise_910.png
# 保存扩增并添加噪声的图像: augmented_with_noise_911.png
# 保存扩增并添加噪声的图像: augmented_with_noise_912.png
# 保存扩增并添加噪声的图像: augmented_with_noise_913.png
# 保存扩增并添加噪声的图像: augmented_with_noise_914.png
# 保存扩增并添加噪声的图像: augmented_with_noise_915.png
# 保存扩增并添加噪声的图像: augmented_with_noise_916.png
# 保存扩增并添加噪声的图像: augmented_with_noise_917.png
# 保存扩增并添加噪声的图像: augmented_with_noise_918.png
# 保存扩增并添加噪声的图像: augmented_with_noise_919.png
# 保存扩增并添加噪声的图像: augmented_with_noise_920.png
# 保存扩增并添加噪声的图像: augmented_with_noise_921.png
# 保存扩增并添加噪声的图像: augmented_with_noise_922.png
# 保存扩增并添加噪声的图像: augmented_with_noise_923.png
# 保存扩增并添加噪声的图像: augmented_with_noise_924.png
# 保存扩增并添加噪声的图像: augmented_with_noise_925.png
# 保存扩增并添加噪声的图像: augmented_with_noise_926.png
# 保存扩增并添加噪声的图像: augmented_with_noise_927.png
# 保存扩增并添加噪声的图像: augmented_with_noise_928.png
# 保存扩增并添加噪声的图像: augmented_with_noise_929.png
# 保存扩增并添加噪声的图像: augmented_with_noise_930.png
# 保存扩增并添加噪声的图像: augmented_with_noise_931.png
# 保存扩增并添加噪声的图像: augmented_with_noise_932.png
# 保存扩增并添加噪声的图像: augmented_with_noise_933.png
# 保存扩增并添加噪声的图像: augmented_with_noise_934.png
# 保存扩增并添加噪声的图像: augmented_with_noise_935.png
# 保存扩增并添加噪声的图像: augmented_with_noise_936.png
# 保存扩增并添加噪声的图像: augmented_with_noise_937.png
# 保存扩增并添加噪声的图像: augmented_with_noise_938.png
# 保存扩增并添加噪声的图像: augmented_with_noise_939.png
# 保存扩增并添加噪声的图像: augmented_with_noise_940.png
# 保存扩增并添加噪声的图像: augmented_with_noise_941.png
# 保存扩增并添加噪声的图像: augmented_with_noise_942.png
# 保存扩增并添加噪声的图像: augmented_with_noise_943.png
# 保存扩增并添加噪声的图像: augmented_with_noise_944.png
# 保存扩增并添加噪声的图像: augmented_with_noise_945.png
# 保存扩增并添加噪声的图像: augmented_with_noise_946.png
# 保存扩增并添加噪声的图像: augmented_with_noise_947.png
# 保存扩增并添加噪声的图像: augmented_with_noise_948.png
# 保存扩增并添加噪声的图像: augmented_with_noise_949.png
# 保存扩增并添加噪声的图像: augmented_with_noise_950.png
# 保存扩增并添加噪声的图像: augmented_with_noise_951.png
# 保存扩增并添加噪声的图像: augmented_with_noise_952.png
# 保存扩增并添加噪声的图像: augmented_with_noise_953.png
# 保存扩增并添加噪声的图像: augmented_with_noise_954.png
# 保存扩增并添加噪声的图像: augmented_with_noise_955.png
# 保存扩增并添加噪声的图像: augmented_with_noise_956.png
# 保存扩增并添加噪声的图像: augmented_with_noise_957.png
# 保存扩增并添加噪声的图像: augmented_with_noise_958.png
# 保存扩增并添加噪声的图像: augmented_with_noise_959.png
# 保存扩增并添加噪声的图像: augmented_with_noise_960.png
# 保存扩增并添加噪声的图像: augmented_with_noise_961.png
# 保存扩增并添加噪声的图像: augmented_with_noise_962.png
# 保存扩增并添加噪声的图像: augmented_with_noise_963.png
# 保存扩增并添加噪声的图像: augmented_with_noise_964.png
# 保存扩增并添加噪声的图像: augmented_with_noise_965.png
# 保存扩增并添加噪声的图像: augmented_with_noise_966.png
# 保存扩增并添加噪声的图像: augmented_with_noise_967.png
# 保存扩增并添加噪声的图像: augmented_with_noise_968.png
# 保存扩增并添加噪声的图像: augmented_with_noise_969.png
# 保存扩增并添加噪声的图像: augmented_with_noise_970.png
# 保存扩增并添加噪声的图像: augmented_with_noise_971.png
# 保存扩增并添加噪声的图像: augmented_with_noise_972.png
# 保存扩增并添加噪声的图像: augmented_with_noise_973.png
# 保存扩增并添加噪声的图像: augmented_with_noise_974.png
# 保存扩增并添加噪声的图像: augmented_with_noise_975.png
# 保存扩增并添加噪声的图像: augmented_with_noise_976.png
# 保存扩增并添加噪声的图像: augmented_with_noise_977.png
# 保存扩增并添加噪声的图像: augmented_with_noise_978.png
# 保存扩增并添加噪声的图像: augmented_with_noise_979.png
# 保存扩增并添加噪声的图像: augmented_with_noise_980.png
# 保存扩增并添加噪声的图像: augmented_with_noise_981.png
# 保存扩增并添加噪声的图像: augmented_with_noise_982.png
# 保存扩增并添加噪声的图像: augmented_with_noise_983.png
# 保存扩增并添加噪声的图像: augmented_with_noise_984.png
# 保存扩增并添加噪声的图像: augmented_with_noise_985.png
# 保存扩增并添加噪声的图像: augmented_with_noise_986.png
png
# 保存扩增并添加噪声的图像: augmented_with_noise_1922.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1923.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1924.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1925.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1926.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1927.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1928.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1929.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1930.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1931.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1932.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1933.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1934.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1935.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1936.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1937.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1938.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1939.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1940.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1941.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1942.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1943.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1944.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1945.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1946.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1947.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1948.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1949.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1950.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1951.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1952.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1953.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1954.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1955.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1956.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1957.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1958.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1959.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1960.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1961.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1962.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1963.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1964.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1965.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1966.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1967.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1968.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1969.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1970.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1971.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1972.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1973.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1974.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1975.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1976.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1977.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1978.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1979.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1980.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1981.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1982.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1983.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1984.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1985.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1986.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1987.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1988.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1989.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1990.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1991.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1992.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1993.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1994.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1995.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1996.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1997.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1998.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1999.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2000.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2001.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2002.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2003.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2004.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2005.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2006.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2007.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2008.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2009.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2010.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2011.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2012.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2013.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2014.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2015.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2016.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2017.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2018.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2019.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2020.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2021.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2022.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2023.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2024.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2025.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2026.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2027.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2028.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2029.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2030.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2031.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2032.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2033.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2034.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2035.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2036.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2037.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2038.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2039.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2040.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2041.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2042.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2043.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2044.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2045.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2046.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2047.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2048.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2049.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2050.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2051.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2052.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2053.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2054.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2055.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2056.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2057.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2058.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2059.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2060.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2061.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2062.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2063.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2064.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2065.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2066.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2067.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2068.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2069.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2070.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2071.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2072.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2073.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2074.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2075.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2076.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2077.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2078.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2079.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2080.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2081.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2082.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2083.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2084.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2085.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2086.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2087.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2088.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2089.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2090.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2091.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2092.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2093.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2094.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2095.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2096.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2097.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2098.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2099.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2100.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2101.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2102.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2103.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2104.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2105.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2106.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2107.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2108.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2109.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2110.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2111.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2112.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2113.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2114.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2115.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2116.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2117.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2118.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2119.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2120.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2121.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2122.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2123.png
# 图像保存完成！

# %%
import os
import random
import numpy as np
import torch
from PIL import Image
import torchvision.transforms as transforms
from torch.utils.data import Dataset

# 设置设备：如果有GPU，就使用GPU，否则使用CPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# 定义添加高斯噪声的函数
def add_gaussian_noise(image_tensor, mean=0.0, std=0.1):
    # 生成高斯噪声
    noise = torch.randn_like(image_tensor) * std + mean
    
    # 添加噪声到图像
    noisy_image = image_tensor + noise
    
    # Clip values to make sure they are within the valid range [0, 1]
    noisy_image = torch.clamp(noisy_image, 0, 1)
    
    return noisy_image

# 定义数据扩增的转换操作
transform = transforms.Compose([
    transforms.RandomHorizontalFlip(),  # 随机水平翻转
    transforms.RandomVerticalFlip(),    # 随机垂直翻转
    transforms.RandomRotation(30),      # 随机旋转30度
    transforms.RandomResizedCrop(224, scale=(0.8, 1.0)),  # 随机裁剪并缩放到224x224
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.2),  # 改变亮度、对比度、饱和度和色调
    transforms.ToTensor(),              # 转换为Tensor
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])  # 图像归一化
])

# 定义数据集类
class AugmentedDataset(Dataset):
    def __init__(self, root_dir, transform=None, add_noise=True):
        self.root_dir = root_dir
        self.transform = transform
        self.add_noise = add_noise
        self.image_files = [f for f in os.listdir(root_dir) if f.endswith(('.png', '.jpg', '.jpeg'))]

    def __len__(self):
        return len(self.image_files)

    def __getitem__(self, idx):
        img_path = os.path.join(self.root_dir, self.image_files[idx])
        image = Image.open(img_path).convert('RGB')  # 确保图像是RGB格式

        # 应用数据扩增
        if self.transform:
            image = self.transform(image)
        
        # 将图像转移到GPU
        image = image.to(device)
        
        # 添加噪声
        if self.add_noise:
            image = add_gaussian_noise(image)

        return image

# 加载数据集
dataset = AugmentedDataset(root_dir=r"L:\常惠林\萎凋\自然萎凋\分类\class_3", transform=transform)

# 生成扩增后的图像并保存
output_folder = r"L:\常惠林\萎凋\自然萎凋\分类\AD3" # 设置保存扩增图像的文件夹
os.makedirs(output_folder, exist_ok=True)

for idx in range(len(dataset)):
    image = dataset[idx]
    img_name = f"augmented_with_noise_{idx}.png"
    img_path = os.path.join(output_folder, img_name)
    
    # 将图像转回到CPU以便保存
    image_cpu = image.cpu()
    
    # 转换为PIL图像以便保存
    image_pil = transforms.ToPILImage()(image_cpu)
    image_pil.save(img_path)
    print(f"保存扩增并添加噪声的图像: {img_name}")
print("图像保存完成！")
# Out:
# 保存扩增并添加噪声的图像: augmented_with_noise_0.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1.png
# 保存扩增并添加噪声的图像: augmented_with_noise_2.png
# 保存扩增并添加噪声的图像: augmented_with_noise_3.png
# 保存扩增并添加噪声的图像: augmented_with_noise_4.png
# 保存扩增并添加噪声的图像: augmented_with_noise_5.png
# 保存扩增并添加噪声的图像: augmented_with_noise_6.png
# 保存扩增并添加噪声的图像: augmented_with_noise_7.png
# 保存扩增并添加噪声的图像: augmented_with_noise_8.png
# 保存扩增并添加噪声的图像: augmented_with_noise_9.png
# 保存扩增并添加噪声的图像: augmented_with_noise_10.png
# 保存扩增并添加噪声的图像: augmented_with_noise_11.png
# 保存扩增并添加噪声的图像: augmented_with_noise_12.png
# 保存扩增并添加噪声的图像: augmented_with_noise_13.png
# 保存扩增并添加噪声的图像: augmented_with_noise_14.png
# 保存扩增并添加噪声的图像: augmented_with_noise_15.png
# 保存扩增并添加噪声的图像: augmented_with_noise_16.png
# 保存扩增并添加噪声的图像: augmented_with_noise_17.png
# 保存扩增并添加噪声的图像: augmented_with_noise_18.png
# 保存扩增并添加噪声的图像: augmented_with_noise_19.png
# 保存扩增并添加噪声的图像: augmented_with_noise_20.png
# 保存扩增并添加噪声的图像: augmented_with_noise_21.png
# 保存扩增并添加噪声的图像: augmented_with_noise_22.png
# 保存扩增并添加噪声的图像: augmented_with_noise_23.png
# 保存扩增并添加噪声的图像: augmented_with_noise_24.png
# 保存扩增并添加噪声的图像: augmented_with_noise_25.png
# 保存扩增并添加噪声的图像: augmented_with_noise_26.png
# 保存扩增并添加噪声的图像: augmented_with_noise_27.png
# 保存扩增并添加噪声的图像: augmented_with_noise_28.png
# 保存扩增并添加噪声的图像: augmented_with_noise_29.png
# 保存扩增并添加噪声的图像: augmented_with_noise_30.png
# 保存扩增并添加噪声的图像: augmented_with_noise_31.png
# 保存扩增并添加噪声的图像: augmented_with_noise_32.png
# 保存扩增并添加噪声的图像: augmented_with_noise_33.png
# 保存扩增并添加噪声的图像: augmented_with_noise_34.png
# 保存扩增并添加噪声的图像: augmented_with_noise_35.png
# 保存扩增并添加噪声的图像: augmented_with_noise_36.png
# 保存扩增并添加噪声的图像: augmented_with_noise_37.png
# 保存扩增并添加噪声的图像: augmented_with_noise_38.png
# 保存扩增并添加噪声的图像: augmented_with_noise_39.png
# 保存扩增并添加噪声的图像: augmented_with_noise_40.png
# 保存扩增并添加噪声的图像: augmented_with_noise_41.png
# 保存扩增并添加噪声的图像: augmented_with_noise_42.png
# 保存扩增并添加噪声的图像: augmented_with_noise_43.png
# 保存扩增并添加噪声的图像: augmented_with_noise_44.png
# 保存扩增并添加噪声的图像: augmented_with_noise_45.png
# 保存扩增并添加噪声的图像: augmented_with_noise_46.png
# 保存扩增并添加噪声的图像: augmented_with_noise_47.png
# 保存扩增并添加噪声的图像: augmented_with_noise_48.png
# 保存扩增并添加噪声的图像: augmented_with_noise_49.png
# 保存扩增并添加噪声的图像: augmented_with_noise_50.png
# 保存扩增并添加噪声的图像: augmented_with_noise_51.png
# 保存扩增并添加噪声的图像: augmented_with_noise_52.png
# 保存扩增并添加噪声的图像: augmented_with_noise_53.png
# 保存扩增并添加噪声的图像: augmented_with_noise_54.png
# 保存扩增并添加噪声的图像: augmented_with_noise_55.png
# 保存扩增并添加噪声的图像: augmented_with_noise_56.png
# 保存扩增并添加噪声的图像: augmented_with_noise_57.png
# 保存扩增并添加噪声的图像: augmented_with_noise_58.png
# 保存扩增并添加噪声的图像: augmented_with_noise_59.png
# 保存扩增并添加噪声的图像: augmented_with_noise_60.png
# 保存扩增并添加噪声的图像: augmented_with_noise_61.png
# 保存扩增并添加噪声的图像: augmented_with_noise_62.png
# 保存扩增并添加噪声的图像: augmented_with_noise_63.png
# 保存扩增并添加噪声的图像: augmented_with_noise_64.png
# 保存扩增并添加噪声的图像: augmented_with_noise_65.png
# 保存扩增并添加噪声的图像: augmented_with_noise_66.png
# 保存扩增并添加噪声的图像: augmented_with_noise_67.png
# 保存扩增并添加噪声的图像: augmented_with_noise_68.png
# 保存扩增并添加噪声的图像: augmented_with_noise_69.png
# 保存扩增并添加噪声的图像: augmented_with_noise_70.png
# 保存扩增并添加噪声的图像: augmented_with_noise_71.png
# 保存扩增并添加噪声的图像: augmented_with_noise_72.png
# 保存扩增并添加噪声的图像: augmented_with_noise_73.png
# 保存扩增并添加噪声的图像: augmented_with_noise_74.png
# 保存扩增并添加噪声的图像: augmented_with_noise_75.png
# 保存扩增并添加噪声的图像: augmented_with_noise_76.png
# 保存扩增并添加噪声的图像: augmented_with_noise_77.png
# 保存扩增并添加噪声的图像: augmented_with_noise_78.png
# 保存扩增并添加噪声的图像: augmented_with_noise_79.png
# 保存扩增并添加噪声的图像: augmented_with_noise_80.png
# 保存扩增并添加噪声的图像: augmented_with_noise_81.png
# 保存扩增并添加噪声的图像: augmented_with_noise_82.png
# 保存扩增并添加噪声的图像: augmented_with_noise_83.png
# 保存扩增并添加噪声的图像: augmented_with_noise_84.png
# 保存扩增并添加噪声的图像: augmented_with_noise_85.png
# 保存扩增并添加噪声的图像: augmented_with_noise_86.png
# 保存扩增并添加噪声的图像: augmented_with_noise_87.png
# 保存扩增并添加噪声的图像: augmented_with_noise_88.png
# 保存扩增并添加噪声的图像: augmented_with_noise_89.png
# 保存扩增并添加噪声的图像: augmented_with_noise_90.png
# 保存扩增并添加噪声的图像: augmented_with_noise_91.png
# 保存扩增并添加噪声的图像: augmented_with_noise_92.png
# 保存扩增并添加噪声的图像: augmented_with_noise_93.png
# 保存扩增并添加噪声的图像: augmented_with_noise_94.png
# 保存扩增并添加噪声的图像: augmented_with_noise_95.png
# 保存扩增并添加噪声的图像: augmented_with_noise_96.png
# 保存扩增并添加噪声的图像: augmented_with_noise_97.png
# 保存扩增并添加噪声的图像: augmented_with_noise_98.png
# 保存扩增并添加噪声的图像: augmented_with_noise_99.png
# 保存扩增并添加噪声的图像: augmented_with_noise_100.png
# 保存扩增并添加噪声的图像: augmented_with_noise_101.png
# 保存扩增并添加噪声的图像: augmented_with_noise_102.png
# 保存扩增并添加噪声的图像: augmented_with_noise_103.png
# 保存扩增并添加噪声的图像: augmented_with_noise_104.png
# 保存扩增并添加噪声的图像: augmented_with_noise_105.png
# 保存扩增并添加噪声的图像: augmented_with_noise_106.png
# 保存扩增并添加噪声的图像: augmented_with_noise_107.png
# 保存扩增并添加噪声的图像: augmented_with_noise_108.png
# 保存扩增并添加噪声的图像: augmented_with_noise_109.png
# 保存扩增并添加噪声的图像: augmented_with_noise_110.png
# 保存扩增并添加噪声的图像: augmented_with_noise_111.png
# 保存扩增并添加噪声的图像: augmented_with_noise_112.png
# 保存扩增并添加噪声的图像: augmented_with_noise_113.png
# 保存扩增并添加噪声的图像: augmented_with_noise_114.png
# 保存扩增并添加噪声的图像: augmented_with_noise_115.png
# 保存扩增并添加噪声的图像: augmented_with_noise_116.png
# 保存扩增并添加噪声的图像: augmented_with_noise_117.png
# 保存扩增并添加噪声的图像: augmented_with_noise_118.png
# 保存扩增并添加噪声的图像: augmented_with_noise_119.png
# 保存扩增并添加噪声的图像: augmented_with_noise_120.png
# 保存扩增并添加噪声的图像: augmented_with_noise_121.png
# 保存扩增并添加噪声的图像: augmented_with_noise_122.png
# 保存扩增并添加噪声的图像: augmented_with_noise_123.png
# 保存扩增并添加噪声的图像: augmented_with_noise_124.png
# 保存扩增并添加噪声的图像: augmented_with_noise_125.png
# 保存扩增并添加噪声的图像: augmented_with_noise_126.png
# 保存扩增并添加噪声的图像: augmented_with_noise_127.png
# 保存扩增并添加噪声的图像: augmented_with_noise_128.png
# 保存扩增并添加噪声的图像: augmented_with_noise_129.png
# 保存扩增并添加噪声的图像: augmented_with_noise_130.png
# 保存扩增并添加噪声的图像: augmented_with_noise_131.png
# 保存扩增并添加噪声的图像: augmented_with_noise_132.png
# 保存扩增并添加噪声的图像: augmented_with_noise_133.png
# 保存扩增并添加噪声的图像: augmented_with_noise_134.png
# 保存扩增并添加噪声的图像: augmented_with_noise_135.png
# 保存扩增并添加噪声的图像: augmented_with_noise_136.png
# 保存扩增并添加噪声的图像: augmented_with_noise_137.png
# 保存扩增并添加噪声的图像: augmented_with_noise_138.png
# 保存扩增并添加噪声的图像: augmented_with_noise_139.png
# 保存扩增并添加噪声的图像: augmented_with_noise_140.png
# 保存扩增并添加噪声的图像: augmented_with_noise_141.png
# 保存扩增并添加噪声的图像: augmented_with_noise_142.png
# 保存扩增并添加噪声的图像: augmented_with_noise_143.png
# 保存扩增并添加噪声的图像: augmented_with_noise_144.png
# 保存扩增并添加噪声的图像: augmented_with_noise_145.png
# 保存扩增并添加噪声的图像: augmented_with_noise_146.png
# 保存扩增并添加噪声的图像: augmented_with_noise_147.png
# 保存扩增并添加噪声的图像: augmented_with_noise_148.png
# 保存扩增并添加噪声的图像: augmented_with_noise_149.png
# 保存扩增并添加噪声的图像: augmented_with_noise_150.png
# 保存扩增并添加噪声的图像: augmented_with_noise_151.png
# 保存扩增并添加噪声的图像: augmented_with_noise_152.png
# 保存扩增并添加噪声的图像: augmented_with_noise_153.png
# 保存扩增并添加噪声的图像: augmented_with_noise_154.png
# 保存扩增并添加噪声的图像: augmented_with_noise_155.png
# 保存扩增并添加噪声的图像: augmented_with_noise_156.png
# 保存扩增并添加噪声的图像: augmented_with_noise_157.png
# 保存扩增并添加噪声的图像: augmented_with_noise_158.png
# 保存扩增并添加噪声的图像: augmented_with_noise_159.png
# 保存扩增并添加噪声的图像: augmented_with_noise_160.png
# 保存扩增并添加噪声的图像: augmented_with_noise_161.png
# 保存扩增并添加噪声的图像: augmented_with_noise_162.png
# 保存扩增并添加噪声的图像: augmented_with_noise_163.png
# 保存扩增并添加噪声的图像: augmented_with_noise_164.png
# 保存扩增并添加噪声的图像: augmented_with_noise_165.png
# 保存扩增并添加噪声的图像: augmented_with_noise_166.png
# 保存扩增并添加噪声的图像: augmented_with_noise_167.png
# 保存扩增并添加噪声的图像: augmented_with_noise_168.png
# 保存扩增并添加噪声的图像: augmented_with_noise_169.png
# 保存扩增并添加噪声的图像: augmented_with_noise_170.png
# 保存扩增并添加噪声的图像: augmented_with_noise_171.png
# 保存扩增并添加噪声的图像: augmented_with_noise_172.png
# 保存扩增并添加噪声的图像: augmented_with_noise_173.png
# 保存扩增并添加噪声的图像: augmented_with_noise_174.png
# 保存扩增并添加噪声的图像: augmented_with_noise_175.png
# 保存扩增并添加噪声的图像: augmented_with_noise_176.png
# 保存扩增并添加噪声的图像: augmented_with_noise_177.png
# 保存扩增并添加噪声的图像: augmented_with_noise_178.png
# 保存扩增并添加噪声的图像: augmented_with_noise_179.png
# 保存扩增并添加噪声的图像: augmented_with_noise_180.png
# 保存扩增并添加噪声的图像: augmented_with_noise_181.png
# 保存扩增并添加噪声的图像: augmented_with_noise_182.png
# 保存扩增并添加噪声的图像: augmented_with_noise_183.png
# 保存扩增并添加噪声的图像: augmented_with_noise_184.png
# 保存扩增并添加噪声的图像: augmented_with_noise_185.png
# 保存扩增并添加噪声的图像: augmented_with_noise_186.png
# 保存扩增并添加噪声的图像: augmented_with_noise_187.png
# 保存扩增并添加噪声的图像: augmented_with_noise_188.png
# 保存扩增并添加噪声的图像: augmented_with_noise_189.png
# 保存扩增并添加噪声的图像: augmented_with_noise_190.png
# 保存扩增并添加噪声的图像: augmented_with_noise_191.png
# 保存扩增并添加噪声的图像: augmented_with_noise_192.png
# 保存扩增并添加噪声的图像: augmented_with_noise_193.png
# 保存扩增并添加噪声的图像: augmented_with_noise_194.png
# 保存扩增并添加噪声的图像: augmented_with_noise_195.png
# 保存扩增并添加噪声的图像: augmented_with_noise_196.png
# 保存扩增并添加噪声的图像: augmented_with_noise_197.png
# 保存扩增并添加噪声的图像: augmented_with_noise_198.png
# 保存扩增并添加噪声的图像: augmented_with_noise_199.png
# 保存扩增并添加噪声的图像: augmented_with_noise_200.png
# 保存扩增并添加噪声的图像: augmented_with_noise_201.png
# 保存扩增并添加噪声的图像: augmented_with_noise_202.png
# 保存扩增并添加噪声的图像: augmented_with_noise_203.png
# 保存扩增并添加噪声的图像: augmented_with_noise_204.png
# 保存扩增并添加噪声的图像: augmented_with_noise_205.png
# 保存扩增并添加噪声的图像: augmented_with_noise_206.png
# 保存扩增并添加噪声的图像: augmented_with_noise_207.png
# 保存扩增并添加噪声的图像: augmented_with_noise_208.png
# 保存扩增并添加噪声的图像: augmented_with_noise_209.png
# 保存扩增并添加噪声的图像: augmented_with_noise_210.png
# 保存扩增并添加噪声的图像: augmented_with_noise_211.png
# 保存扩增并添加噪声的图像: augmented_with_noise_212.png
# 保存扩增并添加噪声的图像: augmented_with_noise_213.png
# 保存扩增并添加噪声的图像: augmented_with_noise_214.png
# 保存扩增并添加噪声的图像: augmented_with_noise_215.png
# 保存扩增并添加噪声的图像: augmented_with_noise_216.png
# 保存扩增并添加噪声的图像: augmented_with_noise_217.png
# 保存扩增并添加噪声的图像: augmented_with_noise_218.png
# 保存扩增并添加噪声的图像: augmented_with_noise_219.png
# 保存扩增并添加噪声的图像: augmented_with_noise_220.png
# 保存扩增并添加噪声的图像: augmented_with_noise_221.png
# 保存扩增并添加噪声的图像: augmented_with_noise_222.png
# 保存扩增并添加噪声的图像: augmented_with_noise_223.png
# 保存扩增并添加噪声的图像: augmented_with_noise_224.png
# 保存扩增并添加噪声的图像: augmented_with_noise_225.png
# 保存扩增并添加噪声的图像: augmented_with_noise_226.png
# 保存扩增并添加噪声的图像: augmented_with_noise_227.png
# 保存扩增并添加噪声的图像: augmented_with_noise_228.png
# 保存扩增并添加噪声的图像: augmented_with_noise_229.png
# 保存扩增并添加噪声的图像: augmented_with_noise_230.png
# 保存扩增并添加噪声的图像: augmented_with_noise_231.png
# 保存扩增并添加噪声的图像: augmented_with_noise_232.png
# 保存扩增并添加噪声的图像: augmented_with_noise_233.png
# 保存扩增并添加噪声的图像: augmented_with_noise_234.png
# 保存扩增并添加噪声的图像: augmented_with_noise_235.png
# 保存扩增并添加噪声的图像: augmented_with_noise_236.png
# 保存扩增并添加噪声的图像: augmented_with_noise_237.png
# 保存扩增并添加噪声的图像: augmented_with_noise_238.png
# 保存扩增并添加噪声的图像: augmented_with_noise_239.png
# 保存扩增并添加噪声的图像: augmented_with_noise_240.png
# 保存扩增并添加噪声的图像: augmented_with_noise_241.png
# 保存扩增并添加噪声的图像: augmented_with_noise_242.png
# 保存扩增并添加噪声的图像: augmented_with_noise_243.png
# 保存扩增并添加噪声的图像: augmented_with_noise_244.png
# 保存扩增并添加噪声的图像: augmented_with_noise_245.png
# 保存扩增并添加噪声的图像: augmented_with_noise_246.png
# 保存扩增并添加噪声的图像: augmented_with_noise_247.png
# 保存扩增并添加噪声的图像: augmented_with_noise_248.png
# 保存扩增并添加噪声的图像: augmented_with_noise_249.png
# 保存扩增并添加噪声的图像: augmented_with_noise_250.png
# 保存扩增并添加噪声的图像: augmented_with_noise_251.png
# 保存扩增并添加噪声的图像: augmented_with_noise_252.png
# 保存扩增并添加噪声的图像: augmented_with_noise_253.png
# 保存扩增并添加噪声的图像: augmented_with_noise_254.png
# 保存扩增并添加噪声的图像: augmented_with_noise_255.png
# 保存扩增并添加噪声的图像: augmented_with_noise_256.png
# 保存扩增并添加噪声的图像: augmented_with_noise_257.png
# 保存扩增并添加噪声的图像: augmented_with_noise_258.png
# 保存扩增并添加噪声的图像: augmented_with_noise_259.png
# 保存扩增并添加噪声的图像: augmented_with_noise_260.png
# 保存扩增并添加噪声的图像: augmented_with_noise_261.png
# 保存扩增并添加噪声的图像: augmented_with_noise_262.png
# 保存扩增并添加噪声的图像: augmented_with_noise_263.png
# 保存扩增并添加噪声的图像: augmented_with_noise_264.png
# 保存扩增并添加噪声的图像: augmented_with_noise_265.png
# 保存扩增并添加噪声的图像: augmented_with_noise_266.png
# 保存扩增并添加噪声的图像: augmented_with_noise_267.png
# 保存扩增并添加噪声的图像: augmented_with_noise_268.png
# 保存扩增并添加噪声的图像: augmented_with_noise_269.png
# 保存扩增并添加噪声的图像: augmented_with_noise_270.png
# 保存扩增并添加噪声的图像: augmented_with_noise_271.png
# 保存扩增并添加噪声的图像: augmented_with_noise_272.png
# 保存扩增并添加噪声的图像: augmented_with_noise_273.png
# 保存扩增并添加噪声的图像: augmented_with_noise_274.png
# 保存扩增并添加噪声的图像: augmented_with_noise_275.png
# 保存扩增并添加噪声的图像: augmented_with_noise_276.png
# 保存扩增并添加噪声的图像: augmented_with_noise_277.png
# 保存扩增并添加噪声的图像: augmented_with_noise_278.png
# 保存扩增并添加噪声的图像: augmented_with_noise_279.png
# 保存扩增并添加噪声的图像: augmented_with_noise_280.png
# 保存扩增并添加噪声的图像: augmented_with_noise_281.png
# 保存扩增并添加噪声的图像: augmented_with_noise_282.png
# 保存扩增并添加噪声的图像: augmented_with_noise_283.png
# 保存扩增并添加噪声的图像: augmented_with_noise_284.png
# 保存扩增并添加噪声的图像: augmented_with_noise_285.png
# 保存扩增并添加噪声的图像: augmented_with_noise_286.png
# 保存扩增并添加噪声的图像: augmented_with_noise_287.png
# 保存扩增并添加噪声的图像: augmented_with_noise_288.png
# 保存扩增并添加噪声的图像: augmented_with_noise_289.png
# 保存扩增并添加噪声的图像: augmented_with_noise_290.png
# 保存扩增并添加噪声的图像: augmented_with_noise_291.png
# 保存扩增并添加噪声的图像: augmented_with_noise_292.png
# 保存扩增并添加噪声的图像: augmented_with_noise_293.png
# 保存扩增并添加噪声的图像: augmented_with_noise_294.png
# 保存扩增并添加噪声的图像: augmented_with_noise_295.png
# 保存扩增并添加噪声的图像: augmented_with_noise_296.png
# 保存扩增并添加噪声的图像: augmented_with_noise_297.png
# 保存扩增并添加噪声的图像: augmented_with_noise_298.png
# 保存扩增并添加噪声的图像: augmented_with_noise_299.png
# 保存扩增并添加噪声的图像: augmented_with_noise_300.png
# 保存扩增并添加噪声的图像: augmented_with_noise_301.png
# 保存扩增并添加噪声的图像: augmented_with_noise_302.png
# 保存扩增并添加噪声的图像: augmented_with_noise_303.png
# 保存扩增并添加噪声的图像: augmented_with_noise_304.png
# 保存扩增并添加噪声的图像: augmented_with_noise_305.png
# 保存扩增并添加噪声的图像: augmented_with_noise_306.png
# 保存扩增并添加噪声的图像: augmented_with_noise_307.png
# 保存扩增并添加噪声的图像: augmented_with_noise_308.png
# 保存扩增并添加噪声的图像: augmented_with_noise_309.png
# 保存扩增并添加噪声的图像: augmented_with_noise_310.png
# 保存扩增并添加噪声的图像: augmented_with_noise_311.png
# 保存扩增并添加噪声的图像: augmented_with_noise_312.png
# 保存扩增并添加噪声的图像: augmented_with_noise_313.png
# 保存扩增并添加噪声的图像: augmented_with_noise_314.png
# 保存扩增并添加噪声的图像: augmented_with_noise_315.png
# 保存扩增并添加噪声的图像: augmented_with_noise_316.png
# 保存扩增并添加噪声的图像: augmented_with_noise_317.png
# 保存扩增并添加噪声的图像: augmented_with_noise_318.png
# 保存扩增并添加噪声的图像: augmented_with_noise_319.png
# 保存扩增并添加噪声的图像: augmented_with_noise_320.png
# 保存扩增并添加噪声的图像: augmented_with_noise_321.png
# 保存扩增并添加噪声的图像: augmented_with_noise_322.png
# 保存扩增并添加噪声的图像: augmented_with_noise_323.png
# 保存扩增并添加噪声的图像: augmented_with_noise_324.png
# 保存扩增并添加噪声的图像: augmented_with_noise_325.png
# 保存扩增并添加噪声的图像: augmented_with_noise_326.png
# 保存扩增并添加噪声的图像: augmented_with_noise_327.png
# 保存扩增并添加噪声的图像: augmented_with_noise_328.png
# 保存扩增并添加噪声的图像: augmented_with_noise_329.png
# 保存扩增并添加噪声的图像: augmented_with_noise_330.png
# 保存扩增并添加噪声的图像: augmented_with_noise_331.png
# 保存扩增并添加噪声的图像: augmented_with_noise_332.png
# 保存扩增并添加噪声的图像: augmented_with_noise_333.png
# 保存扩增并添加噪声的图像: augmented_with_noise_334.png
# 保存扩增并添加噪声的图像: augmented_with_noise_335.png
# 保存扩增并添加噪声的图像: augmented_with_noise_336.png
# 保存扩增并添加噪声的图像: augmented_with_noise_337.png
# 保存扩增并添加噪声的图像: augmented_with_noise_338.png
# 保存扩增并添加噪声的图像: augmented_with_noise_339.png
# 保存扩增并添加噪声的图像: augmented_with_noise_340.png
# 保存扩增并添加噪声的图像: augmented_with_noise_341.png
# 保存扩增并添加噪声的图像: augmented_with_noise_342.png
# 保存扩增并添加噪声的图像: augmented_with_noise_343.png
# 保存扩增并添加噪声的图像: augmented_with_noise_344.png
# 保存扩增并添加噪声的图像: augmented_with_noise_345.png
# 保存扩增并添加噪声的图像: augmented_with_noise_346.png
# 保存扩增并添加噪声的图像: augmented_with_noise_347.png
# 保存扩增并添加噪声的图像: augmented_with_noise_348.png
# 保存扩增并添加噪声的图像: augmented_with_noise_349.png
# 保存扩增并添加噪声的图像: augmented_with_noise_350.png
# 保存扩增并添加噪声的图像: augmented_with_noise_351.png
# 保存扩增并添加噪声的图像: augmented_with_noise_352.png
# 保存扩增并添加噪声的图像: augmented_with_noise_353.png
# 保存扩增并添加噪声的图像: augmented_with_noise_354.png
# 保存扩增并添加噪声的图像: augmented_with_noise_355.png
# 保存扩增并添加噪声的图像: augmented_with_noise_356.png
# 保存扩增并添加噪声的图像: augmented_with_noise_357.png
# 保存扩增并添加噪声的图像: augmented_with_noise_358.png
# 保存扩增并添加噪声的图像: augmented_with_noise_359.png
# 保存扩增并添加噪声的图像: augmented_with_noise_360.png
# 保存扩增并添加噪声的图像: augmented_with_noise_361.png
# 保存扩增并添加噪声的图像: augmented_with_noise_362.png
# 保存扩增并添加噪声的图像: augmented_with_noise_363.png
# 保存扩增并添加噪声的图像: augmented_with_noise_364.png
# 保存扩增并添加噪声的图像: augmented_with_noise_365.png
# 保存扩增并添加噪声的图像: augmented_with_noise_366.png
# 保存扩增并添加噪声的图像: augmented_with_noise_367.png
# 保存扩增并添加噪声的图像: augmented_with_noise_368.png
# 保存扩增并添加噪声的图像: augmented_with_noise_369.png
# 保存扩增并添加噪声的图像: augmented_with_noise_370.png
# 保存扩增并添加噪声的图像: augmented_with_noise_371.png
# 保存扩增并添加噪声的图像: augmented_with_noise_372.png
# 保存扩增并添加噪声的图像: augmented_with_noise_373.png
# 保存扩增并添加噪声的图像: augmented_with_noise_374.png
# 保存扩增并添加噪声的图像: augmented_with_noise_375.png
# 保存扩增并添加噪声的图像: augmented_with_noise_376.png
# 保存扩增并添加噪声的图像: augmented_with_noise_377.png
# 保存扩增并添加噪声的图像: augmented_with_noise_378.png
# 保存扩增并添加噪声的图像: augmented_with_noise_379.png
# 保存扩增并添加噪声的图像: augmented_with_noise_380.png
# 保存扩增并添加噪声的图像: augmented_with_noise_381.png
# 保存扩增并添加噪声的图像: augmented_with_noise_382.png
# 保存扩增并添加噪声的图像: augmented_with_noise_383.png
# 保存扩增并添加噪声的图像: augmented_with_noise_384.png
# 保存扩增并添加噪声的图像: augmented_with_noise_385.png
# 保存扩增并添加噪声的图像: augmented_with_noise_386.png
# 保存扩增并添加噪声的图像: augmented_with_noise_387.png
# 保存扩增并添加噪声的图像: augmented_with_noise_388.png
# 保存扩增并添加噪声的图像: augmented_with_noise_389.png
# 保存扩增并添加噪声的图像: augmented_with_noise_390.png
# 保存扩增并添加噪声的图像: augmented_with_noise_391.png
# 保存扩增并添加噪声的图像: augmented_with_noise_392.png
# 保存扩增并添加噪声的图像: augmented_with_noise_393.png
# 保存扩增并添加噪声的图像: augmented_with_noise_394.png
# 保存扩增并添加噪声的图像: augmented_with_noise_395.png
# 保存扩增并添加噪声的图像: augmented_with_noise_396.png
# 保存扩增并添加噪声的图像: augmented_with_noise_397.png
# 保存扩增并添加噪声的图像: augmented_with_noise_398.png
# 保存扩增并添加噪声的图像: augmented_with_noise_399.png
# 保存扩增并添加噪声的图像: augmented_with_noise_400.png
# 保存扩增并添加噪声的图像: augmented_with_noise_401.png
# 保存扩增并添加噪声的图像: augmented_with_noise_402.png
# 保存扩增并添加噪声的图像: augmented_with_noise_403.png
# 保存扩增并添加噪声的图像: augmented_with_noise_404.png
# 保存扩增并添加噪声的图像: augmented_with_noise_405.png
# 保存扩增并添加噪声的图像: augmented_with_noise_406.png
# 保存扩增并添加噪声的图像: augmented_with_noise_407.png
# 保存扩增并添加噪声的图像: augmented_with_noise_408.png
# 保存扩增并添加噪声的图像: augmented_with_noise_409.png
# 保存扩增并添加噪声的图像: augmented_with_noise_410.png
# 保存扩增并添加噪声的图像: augmented_with_noise_411.png
# 保存扩增并添加噪声的图像: augmented_with_noise_412.png
# 保存扩增并添加噪声的图像: augmented_with_noise_413.png
# 保存扩增并添加噪声的图像: augmented_with_noise_414.png
# 保存扩增并添加噪声的图像: augmented_with_noise_415.png
# 保存扩增并添加噪声的图像: augmented_with_noise_416.png
# 保存扩增并添加噪声的图像: augmented_with_noise_417.png
# 保存扩增并添加噪声的图像: augmented_with_noise_418.png
# 保存扩增并添加噪声的图像: augmented_with_noise_419.png
# 保存扩增并添加噪声的图像: augmented_with_noise_420.png
# 保存扩增并添加噪声的图像: augmented_with_noise_421.png
# 保存扩增并添加噪声的图像: augmented_with_noise_422.png
# 保存扩增并添加噪声的图像: augmented_with_noise_423.png
# 保存扩增并添加噪声的图像: augmented_with_noise_424.png
# 保存扩增并添加噪声的图像: augmented_with_noise_425.png
# 保存扩增并添加噪声的图像: augmented_with_noise_426.png
# 保存扩增并添加噪声的图像: augmented_with_noise_427.png
# 保存扩增并添加噪声的图像: augmented_with_noise_428.png
# 保存扩增并添加噪声的图像: augmented_with_noise_429.png
# 保存扩增并添加噪声的图像: augmented_with_noise_430.png
# 保存扩增并添加噪声的图像: augmented_with_noise_431.png
# 保存扩增并添加噪声的图像: augmented_with_noise_432.png
# 保存扩增并添加噪声的图像: augmented_with_noise_433.png
# 保存扩增并添加噪声的图像: augmented_with_noise_434.png
# 保存扩增并添加噪声的图像: augmented_with_noise_435.png
# 保存扩增并添加噪声的图像: augmented_with_noise_436.png
# 保存扩增并添加噪声的图像: augmented_with_noise_437.png
# 保存扩增并添加噪声的图像: augmented_with_noise_438.png
# 保存扩增并添加噪声的图像: augmented_with_noise_439.png
# 保存扩增并添加噪声的图像: augmented_with_noise_440.png
# 保存扩增并添加噪声的图像: augmented_with_noise_441.png
# 保存扩增并添加噪声的图像: augmented_with_noise_442.png
# 保存扩增并添加噪声的图像: augmented_with_noise_443.png
# 保存扩增并添加噪声的图像: augmented_with_noise_444.png
# 保存扩增并添加噪声的图像: augmented_with_noise_445.png
# 保存扩增并添加噪声的图像: augmented_with_noise_446.png
# 保存扩增并添加噪声的图像: augmented_with_noise_447.png
# 保存扩增并添加噪声的图像: augmented_with_noise_448.png
# 保存扩增并添加噪声的图像: augmented_with_noise_449.png
# 保存扩增并添加噪声的图像: augmented_with_noise_450.png
# 保存扩增并添加噪声的图像: augmented_with_noise_451.png
# 保存扩增并添加噪声的图像: augmented_with_noise_452.png
# 保存扩增并添加噪声的图像: augmented_with_noise_453.png
# 保存扩增并添加噪声的图像: augmented_with_noise_454.png
# 保存扩增并添加噪声的图像: augmented_with_noise_455.png
# 保存扩增并添加噪声的图像: augmented_with_noise_456.png
# 保存扩增并添加噪声的图像: augmented_with_noise_457.png
# 保存扩增并添加噪声的图像: augmented_with_noise_458.png
# 保存扩增并添加噪声的图像: augmented_with_noise_459.png
# 保存扩增并添加噪声的图像: augmented_with_noise_460.png
# 保存扩增并添加噪声的图像: augmented_with_noise_461.png
# 保存扩增并添加噪声的图像: augmented_with_noise_462.png
# 保存扩增并添加噪声的图像: augmented_with_noise_463.png
# 保存扩增并添加噪声的图像: augmented_with_noise_464.png
# 保存扩增并添加噪声的图像: augmented_with_noise_465.png
# 保存扩增并添加噪声的图像: augmented_with_noise_466.png
# 保存扩增并添加噪声的图像: augmented_with_noise_467.png
# 保存扩增并添加噪声的图像: augmented_with_noise_468.png
# 保存扩增并添加噪声的图像: augmented_with_noise_469.png
# 保存扩增并添加噪声的图像: augmented_with_noise_470.png
# 保存扩增并添加噪声的图像: augmented_with_noise_471.png
# 保存扩增并添加噪声的图像: augmented_with_noise_472.png
# 保存扩增并添加噪声的图像: augmented_with_noise_473.png
# 保存扩增并添加噪声的图像: augmented_with_noise_474.png
# 保存扩增并添加噪声的图像: augmented_with_noise_475.png
# 保存扩增并添加噪声的图像: augmented_with_noise_476.png
# 保存扩增并添加噪声的图像: augmented_with_noise_477.png
# 保存扩增并添加噪声的图像: augmented_with_noise_478.png
# 保存扩增并添加噪声的图像: augmented_with_noise_479.png
# 保存扩增并添加噪声的图像: augmented_with_noise_480.png
# 保存扩增并添加噪声的图像: augmented_with_noise_481.png
# 保存扩增并添加噪声的图像: augmented_with_noise_482.png
# 保存扩增并添加噪声的图像: augmented_with_noise_483.png
# 保存扩增并添加噪声的图像: augmented_with_noise_484.png
# 保存扩增并添加噪声的图像: augmented_with_noise_485.png
# 保存扩增并添加噪声的图像: augmented_with_noise_486.png
# 保存扩增并添加噪声的图像: augmented_with_noise_487.png
# 保存扩增并添加噪声的图像: augmented_with_noise_488.png
# 保存扩增并添加噪声的图像: augmented_with_noise_489.png
# 保存扩增并添加噪声的图像: augmented_with_noise_490.png
# 保存扩增并添加噪声的图像: augmented_with_noise_491.png
# 保存扩增并添加噪声的图像: augmented_with_noise_492.png
# 保存扩增并添加噪声的图像: augmented_with_noise_493.png
# 保存扩增并添加噪声的图像: augmented_with_noise_494.png
# 保存扩增并添加噪声的图像: augmented_with_noise_495.png
# 保存扩增并添加噪声的图像: augmented_with_noise_496.png
# 保存扩增并添加噪声的图像: augmented_with_noise_497.png
# 保存扩增并添加噪声的图像: augmented_with_noise_498.png
# 保存扩增并添加噪声的图像: augmented_with_noise_499.png
# 保存扩增并添加噪声的图像: augmented_with_noise_500.png
# 保存扩增并添加噪声的图像: augmented_with_noise_501.png
# 保存扩增并添加噪声的图像: augmented_with_noise_502.png
# 保存扩增并添加噪声的图像: augmented_with_noise_503.png
# 保存扩增并添加噪声的图像: augmented_with_noise_504.png
# 保存扩增并添加噪声的图像: augmented_with_noise_505.png
# 保存扩增并添加噪声的图像: augmented_with_noise_506.png
# 保存扩增并添加噪声的图像: augmented_with_noise_507.png
# 保存扩增并添加噪声的图像: augmented_with_noise_508.png
# 保存扩增并添加噪声的图像: augmented_with_noise_509.png
# 保存扩增并添加噪声的图像: augmented_with_noise_510.png
# 保存扩增并添加噪声的图像: augmented_with_noise_511.png
# 保存扩增并添加噪声的图像: augmented_with_noise_512.png
# 保存扩增并添加噪声的图像: augmented_with_noise_513.png
# 保存扩增并添加噪声的图像: augmented_with_noise_514.png
# 保存扩增并添加噪声的图像: augmented_with_noise_515.png
# 保存扩增并添加噪声的图像: augmented_with_noise_516.png
# 保存扩增并添加噪声的图像: augmented_with_noise_517.png
# 保存扩增并添加噪声的图像: augmented_with_noise_518.png
# 保存扩增并添加噪声的图像: augmented_with_noise_519.png
# 保存扩增并添加噪声的图像: augmented_with_noise_520.png
# 保存扩增并添加噪声的图像: augmented_with_noise_521.png
# 保存扩增并添加噪声的图像: augmented_with_noise_522.png
# 保存扩增并添加噪声的图像: augmented_with_noise_523.png
# 保存扩增并添加噪声的图像: augmented_with_noise_524.png
# 保存扩增并添加噪声的图像: augmented_with_noise_525.png
# 保存扩增并添加噪声的图像: augmented_with_noise_526.png
# 保存扩增并添加噪声的图像: augmented_with_noise_527.png
# 保存扩增并添加噪声的图像: augmented_with_noise_528.png
# 保存扩增并添加噪声的图像: augmented_with_noise_529.png
# 保存扩增并添加噪声的图像: augmented_with_noise_530.png
# 保存扩增并添加噪声的图像: augmented_with_noise_531.png
# 保存扩增并添加噪声的图像: augmented_with_noise_532.png
# 保存扩增并添加噪声的图像: augmented_with_noise_533.png
# 保存扩增并添加噪声的图像: augmented_with_noise_534.png
# 保存扩增并添加噪声的图像: augmented_with_noise_535.png
# 保存扩增并添加噪声的图像: augmented_with_noise_536.png
# 保存扩增并添加噪声的图像: augmented_with_noise_537.png
# 保存扩增并添加噪声的图像: augmented_with_noise_538.png
# 保存扩增并添加噪声的图像: augmented_with_noise_539.png
# 保存扩增并添加噪声的图像: augmented_with_noise_540.png
# 保存扩增并添加噪声的图像: augmented_with_noise_541.png
# 保存扩增并添加噪声的图像: augmented_with_noise_542.png
# 保存扩增并添加噪声的图像: augmented_with_noise_543.png
# 保存扩增并添加噪声的图像: augmented_with_noise_544.png
# 保存扩增并添加噪声的图像: augmented_with_noise_545.png
# 保存扩增并添加噪声的图像: augmented_with_noise_546.png
# 保存扩增并添加噪声的图像: augmented_with_noise_547.png
# 保存扩增并添加噪声的图像: augmented_with_noise_548.png
# 保存扩增并添加噪声的图像: augmented_with_noise_549.png
# 保存扩增并添加噪声的图像: augmented_with_noise_550.png
# 保存扩增并添加噪声的图像: augmented_with_noise_551.png
# 保存扩增并添加噪声的图像: augmented_with_noise_552.png
# 保存扩增并添加噪声的图像: augmented_with_noise_553.png
# 保存扩增并添加噪声的图像: augmented_with_noise_554.png
# 保存扩增并添加噪声的图像: augmented_with_noise_555.png
# 保存扩增并添加噪声的图像: augmented_with_noise_556.png
# 保存扩增并添加噪声的图像: augmented_with_noise_557.png
# 保存扩增并添加噪声的图像: augmented_with_noise_558.png
# 保存扩增并添加噪声的图像: augmented_with_noise_559.png
# 保存扩增并添加噪声的图像: augmented_with_noise_560.png
# 保存扩增并添加噪声的图像: augmented_with_noise_561.png
# 保存扩增并添加噪声的图像: augmented_with_noise_562.png
# 保存扩增并添加噪声的图像: augmented_with_noise_563.png
# 保存扩增并添加噪声的图像: augmented_with_noise_564.png
# 保存扩增并添加噪声的图像: augmented_with_noise_565.png
# 保存扩增并添加噪声的图像: augmented_with_noise_566.png
# 保存扩增并添加噪声的图像: augmented_with_noise_567.png
# 保存扩增并添加噪声的图像: augmented_with_noise_568.png
# 保存扩增并添加噪声的图像: augmented_with_noise_569.png
# 保存扩增并添加噪声的图像: augmented_with_noise_570.png
# 保存扩增并添加噪声的图像: augmented_with_noise_571.png
# 保存扩增并添加噪声的图像: augmented_with_noise_572.png
# 保存扩增并添加噪声的图像: augmented_with_noise_573.png
# 保存扩增并添加噪声的图像: augmented_with_noise_574.png
# 保存扩增并添加噪声的图像: augmented_with_noise_575.png
# 保存扩增并添加噪声的图像: augmented_with_noise_576.png
# 保存扩增并添加噪声的图像: augmented_with_noise_577.png
# 保存扩增并添加噪声的图像: augmented_with_noise_578.png
# 保存扩增并添加噪声的图像: augmented_with_noise_579.png
# 保存扩增并添加噪声的图像: augmented_with_noise_580.png
# 保存扩增并添加噪声的图像: augmented_with_noise_581.png
# 保存扩增并添加噪声的图像: augmented_with_noise_582.png
# 保存扩增并添加噪声的图像: augmented_with_noise_583.png
# 保存扩增并添加噪声的图像: augmented_with_noise_584.png
# 保存扩增并添加噪声的图像: augmented_with_noise_585.png
# 保存扩增并添加噪声的图像: augmented_with_noise_586.png
# 保存扩增并添加噪声的图像: augmented_with_noise_587.png
# 保存扩增并添加噪声的图像: augmented_with_noise_588.png
# 保存扩增并添加噪声的图像: augmented_with_noise_589.png
# 保存扩增并添加噪声的图像: augmented_with_noise_590.png
# 保存扩增并添加噪声的图像: augmented_with_noise_591.png
# 保存扩增并添加噪声的图像: augmented_with_noise_592.png
# 保存扩增并添加噪声的图像: augmented_with_noise_593.png
# 保存扩增并添加噪声的图像: augmented_with_noise_594.png
# 保存扩增并添加噪声的图像: augmented_with_noise_595.png
# 保存扩增并添加噪声的图像: augmented_with_noise_596.png
# 保存扩增并添加噪声的图像: augmented_with_noise_597.png
# 保存扩增并添加噪声的图像: augmented_with_noise_598.png
# 保存扩增并添加噪声的图像: augmented_with_noise_599.png
# 保存扩增并添加噪声的图像: augmented_with_noise_600.png
# 保存扩增并添加噪声的图像: augmented_with_noise_601.png
# 保存扩增并添加噪声的图像: augmented_with_noise_602.png
# 保存扩增并添加噪声的图像: augmented_with_noise_603.png
# 保存扩增并添加噪声的图像: augmented_with_noise_604.png
# 保存扩增并添加噪声的图像: augmented_with_noise_605.png
# 保存扩增并添加噪声的图像: augmented_with_noise_606.png
# 保存扩增并添加噪声的图像: augmented_with_noise_607.png
# 保存扩增并添加噪声的图像: augmented_with_noise_608.png
# 保存扩增并添加噪声的图像: augmented_with_noise_609.png
# 保存扩增并添加噪声的图像: augmented_with_noise_610.png
# 保存扩增并添加噪声的图像: augmented_with_noise_611.png
# 保存扩增并添加噪声的图像: augmented_with_noise_612.png
# 保存扩增并添加噪声的图像: augmented_with_noise_613.png
# 保存扩增并添加噪声的图像: augmented_with_noise_614.png
# 保存扩增并添加噪声的图像: augmented_with_noise_615.png
# 保存扩增并添加噪声的图像: augmented_with_noise_616.png
# 保存扩增并添加噪声的图像: augmented_with_noise_617.png
# 保存扩增并添加噪声的图像: augmented_with_noise_618.png
# 保存扩增并添加噪声的图像: augmented_with_noise_619.png
# 保存扩增并添加噪声的图像: augmented_with_noise_620.png
# 保存扩增并添加噪声的图像: augmented_with_noise_621.png
# 保存扩增并添加噪声的图像: augmented_with_noise_622.png
# 保存扩增并添加噪声的图像: augmented_with_noise_623.png
# 保存扩增并添加噪声的图像: augmented_with_noise_624.png
# 保存扩增并添加噪声的图像: augmented_with_noise_625.png
# 保存扩增并添加噪声的图像: augmented_with_noise_626.png
# 保存扩增并添加噪声的图像: augmented_with_noise_627.png
# 保存扩增并添加噪声的图像: augmented_with_noise_628.png
# 保存扩增并添加噪声的图像: augmented_with_noise_629.png
# 保存扩增并添加噪声的图像: augmented_with_noise_630.png
# 保存扩增并添加噪声的图像: augmented_with_noise_631.png
# 保存扩增并添加噪声的图像: augmented_with_noise_632.png
# 保存扩增并添加噪声的图像: augmented_with_noise_633.png
# 保存扩增并添加噪声的图像: augmented_with_noise_634.png
# 保存扩增并添加噪声的图像: augmented_with_noise_635.png
# 保存扩增并添加噪声的图像: augmented_with_noise_636.png
# 保存扩增并添加噪声的图像: augmented_with_noise_637.png
# 保存扩增并添加噪声的图像: augmented_with_noise_638.png
# 保存扩增并添加噪声的图像: augmented_with_noise_639.png
# 保存扩增并添加噪声的图像: augmented_with_noise_640.png
# 保存扩增并添加噪声的图像: augmented_with_noise_641.png
# 保存扩增并添加噪声的图像: augmented_with_noise_642.png
# 保存扩增并添加噪声的图像: augmented_with_noise_643.png
# 保存扩增并添加噪声的图像: augmented_with_noise_644.png
# 保存扩增并添加噪声的图像: augmented_with_noise_645.png
# 保存扩增并添加噪声的图像: augmented_with_noise_646.png
# 保存扩增并添加噪声的图像: augmented_with_noise_647.png
# 保存扩增并添加噪声的图像: augmented_with_noise_648.png
# 保存扩增并添加噪声的图像: augmented_with_noise_649.png
# 保存扩增并添加噪声的图像: augmented_with_noise_650.png
# 保存扩增并添加噪声的图像: augmented_with_noise_651.png
# 保存扩增并添加噪声的图像: augmented_with_noise_652.png
# 保存扩增并添加噪声的图像: augmented_with_noise_653.png
# 保存扩增并添加噪声的图像: augmented_with_noise_654.png
# 保存扩增并添加噪声的图像: augmented_with_noise_655.png
# 保存扩增并添加噪声的图像: augmented_with_noise_656.png
# 保存扩增并添加噪声的图像: augmented_with_noise_657.png
# 保存扩增并添加噪声的图像: augmented_with_noise_658.png
# 保存扩增并添加噪声的图像: augmented_with_noise_659.png
# 保存扩增并添加噪声的图像: augmented_with_noise_660.png
# 保存扩增并添加噪声的图像: augmented_with_noise_661.png
# 保存扩增并添加噪声的图像: augmented_with_noise_662.png
# 保存扩增并添加噪声的图像: augmented_with_noise_663.png
# 保存扩增并添加噪声的图像: augmented_with_noise_664.png
# 保存扩增并添加噪声的图像: augmented_with_noise_665.png
# 保存扩增并添加噪声的图像: augmented_with_noise_666.png
# 保存扩增并添加噪声的图像: augmented_with_noise_667.png
# 保存扩增并添加噪声的图像: augmented_with_noise_668.png
# 保存扩增并添加噪声的图像: augmented_with_noise_669.png
# 保存扩增并添加噪声的图像: augmented_with_noise_670.png
# 保存扩增并添加噪声的图像: augmented_with_noise_671.png
# 保存扩增并添加噪声的图像: augmented_with_noise_672.png
# 保存扩增并添加噪声的图像: augmented_with_noise_673.png
# 保存扩增并添加噪声的图像: augmented_with_noise_674.png
# 保存扩增并添加噪声的图像: augmented_with_noise_675.png
# 保存扩增并添加噪声的图像: augmented_with_noise_676.png
# 保存扩增并添加噪声的图像: augmented_with_noise_677.png
# 保存扩增并添加噪声的图像: augmented_with_noise_678.png
# 保存扩增并添加噪声的图像: augmented_with_noise_679.png
# 保存扩增并添加噪声的图像: augmented_with_noise_680.png
# 保存扩增并添加噪声的图像: augmented_with_noise_681.png
# 保存扩增并添加噪声的图像: augmented_with_noise_682.png
# 保存扩增并添加噪声的图像: augmented_with_noise_683.png
# 保存扩增并添加噪声的图像: augmented_with_noise_684.png
# 保存扩增并添加噪声的图像: augmented_with_noise_685.png
# 保存扩增并添加噪声的图像: augmented_with_noise_686.png
# 保存扩增并添加噪声的图像: augmented_with_noise_687.png
# 保存扩增并添加噪声的图像: augmented_with_noise_688.png
# 保存扩增并添加噪声的图像: augmented_with_noise_689.png
# 保存扩增并添加噪声的图像: augmented_with_noise_690.png
# 保存扩增并添加噪声的图像: augmented_with_noise_691.png
# 保存扩增并添加噪声的图像: augmented_with_noise_692.png
# 保存扩增并添加噪声的图像: augmented_with_noise_693.png
# 保存扩增并添加噪声的图像: augmented_with_noise_694.png
# 保存扩增并添加噪声的图像: augmented_with_noise_695.png
# 保存扩增并添加噪声的图像: augmented_with_noise_696.png
# 保存扩增并添加噪声的图像: augmented_with_noise_697.png
# 保存扩增并添加噪声的图像: augmented_with_noise_698.png
# 保存扩增并添加噪声的图像: augmented_with_noise_699.png
# 保存扩增并添加噪声的图像: augmented_with_noise_700.png
# 保存扩增并添加噪声的图像: augmented_with_noise_701.png
# 保存扩增并添加噪声的图像: augmented_with_noise_702.png
# 保存扩增并添加噪声的图像: augmented_with_noise_703.png
# 保存扩增并添加噪声的图像: augmented_with_noise_704.png
# 保存扩增并添加噪声的图像: augmented_with_noise_705.png
# 保存扩增并添加噪声的图像: augmented_with_noise_706.png
# 保存扩增并添加噪声的图像: augmented_with_noise_707.png
# 保存扩增并添加噪声的图像: augmented_with_noise_708.png
# 保存扩增并添加噪声的图像: augmented_with_noise_709.png
# 保存扩增并添加噪声的图像: augmented_with_noise_710.png
# 保存扩增并添加噪声的图像: augmented_with_noise_711.png
# 保存扩增并添加噪声的图像: augmented_with_noise_712.png
# 保存扩增并添加噪声的图像: augmented_with_noise_713.png
# 保存扩增并添加噪声的图像: augmented_with_noise_714.png
# 保存扩增并添加噪声的图像: augmented_with_noise_715.png
# 保存扩增并添加噪声的图像: augmented_with_noise_716.png
# 保存扩增并添加噪声的图像: augmented_with_noise_717.png
# 保存扩增并添加噪声的图像: augmented_with_noise_718.png
# 保存扩增并添加噪声的图像: augmented_with_noise_719.png
# 保存扩增并添加噪声的图像: augmented_with_noise_720.png
# 保存扩增并添加噪声的图像: augmented_with_noise_721.png
# 保存扩增并添加噪声的图像: augmented_with_noise_722.png
# 保存扩增并添加噪声的图像: augmented_with_noise_723.png
# 保存扩增并添加噪声的图像: augmented_with_noise_724.png
# 保存扩增并添加噪声的图像: augmented_with_noise_725.png
# 保存扩增并添加噪声的图像: augmented_with_noise_726.png
# 保存扩增并添加噪声的图像: augmented_with_noise_727.png
# 保存扩增并添加噪声的图像: augmented_with_noise_728.png
# 保存扩增并添加噪声的图像: augmented_with_noise_729.png
# 保存扩增并添加噪声的图像: augmented_with_noise_730.png
# 保存扩增并添加噪声的图像: augmented_with_noise_731.png
# 保存扩增并添加噪声的图像: augmented_with_noise_732.png
# 保存扩增并添加噪声的图像: augmented_with_noise_733.png
# 保存扩增并添加噪声的图像: augmented_with_noise_734.png
# 保存扩增并添加噪声的图像: augmented_with_noise_735.png
# 保存扩增并添加噪声的图像: augmented_with_noise_736.png
# 保存扩增并添加噪声的图像: augmented_with_noise_737.png
# 保存扩增并添加噪声的图像: augmented_with_noise_738.png
# 保存扩增并添加噪声的图像: augmented_with_noise_739.png
# 保存扩增并添加噪声的图像: augmented_with_noise_740.png
# 保存扩增并添加噪声的图像: augmented_with_noise_741.png
# 保存扩增并添加噪声的图像: augmented_with_noise_742.png
# 保存扩增并添加噪声的图像: augmented_with_noise_743.png
# 保存扩增并添加噪声的图像: augmented_with_noise_744.png
# 保存扩增并添加噪声的图像: augmented_with_noise_745.png
# 保存扩增并添加噪声的图像: augmented_with_noise_746.png
# 保存扩增并添加噪声的图像: augmented_with_noise_747.png
# 保存扩增并添加噪声的图像: augmented_with_noise_748.png
# 保存扩增并添加噪声的图像: augmented_with_noise_749.png
# 保存扩增并添加噪声的图像: augmented_with_noise_750.png
# 保存扩增并添加噪声的图像: augmented_with_noise_751.png
# 保存扩增并添加噪声的图像: augmented_with_noise_752.png
# 保存扩增并添加噪声的图像: augmented_with_noise_753.png
# 保存扩增并添加噪声的图像: augmented_with_noise_754.png
# 保存扩增并添加噪声的图像: augmented_with_noise_755.png
# 保存扩增并添加噪声的图像: augmented_with_noise_756.png
# 保存扩增并添加噪声的图像: augmented_with_noise_757.png
# 保存扩增并添加噪声的图像: augmented_with_noise_758.png
# 保存扩增并添加噪声的图像: augmented_with_noise_759.png
# 保存扩增并添加噪声的图像: augmented_with_noise_760.png
# 保存扩增并添加噪声的图像: augmented_with_noise_761.png
# 保存扩增并添加噪声的图像: augmented_with_noise_762.png
# 保存扩增并添加噪声的图像: augmented_with_noise_763.png
# 保存扩增并添加噪声的图像: augmented_with_noise_764.png
# 保存扩增并添加噪声的图像: augmented_with_noise_765.png
# 保存扩增并添加噪声的图像: augmented_with_noise_766.png
# 保存扩增并添加噪声的图像: augmented_with_noise_767.png
# 保存扩增并添加噪声的图像: augmented_with_noise_768.png
# 保存扩增并添加噪声的图像: augmented_with_noise_769.png
# 保存扩增并添加噪声的图像: augmented_with_noise_770.png
# 保存扩增并添加噪声的图像: augmented_with_noise_771.png
# 保存扩增并添加噪声的图像: augmented_with_noise_772.png
# 保存扩增并添加噪声的图像: augmented_with_noise_773.png
# 保存扩增并添加噪声的图像: augmented_with_noise_774.png
# 保存扩增并添加噪声的图像: augmented_with_noise_775.png
# 保存扩增并添加噪声的图像: augmented_with_noise_776.png
# 保存扩增并添加噪声的图像: augmented_with_noise_777.png
# 保存扩增并添加噪声的图像: augmented_with_noise_778.png
# 保存扩增并添加噪声的图像: augmented_with_noise_779.png
# 保存扩增并添加噪声的图像: augmented_with_noise_780.png
# 保存扩增并添加噪声的图像: augmented_with_noise_781.png
# 保存扩增并添加噪声的图像: augmented_with_noise_782.png
# 保存扩增并添加噪声的图像: augmented_with_noise_783.png
# 保存扩增并添加噪声的图像: augmented_with_noise_784.png
# 保存扩增并添加噪声的图像: augmented_with_noise_785.png
# 保存扩增并添加噪声的图像: augmented_with_noise_786.png
# 保存扩增并添加噪声的图像: augmented_with_noise_787.png
# 保存扩增并添加噪声的图像: augmented_with_noise_788.png
# 保存扩增并添加噪声的图像: augmented_with_noise_789.png
# 保存扩增并添加噪声的图像: augmented_with_noise_790.png
# 保存扩增并添加噪声的图像: augmented_with_noise_791.png
# 保存扩增并添加噪声的图像: augmented_with_noise_792.png
# 保存扩增并添加噪声的图像: augmented_with_noise_793.png
# 保存扩增并添加噪声的图像: augmented_with_noise_794.png
# 保存扩增并添加噪声的图像: augmented_with_noise_795.png
# 保存扩增并添加噪声的图像: augmented_with_noise_796.png
# 保存扩增并添加噪声的图像: augmented_with_noise_797.png
# 保存扩增并添加噪声的图像: augmented_with_noise_798.png
# 保存扩增并添加噪声的图像: augmented_with_noise_799.png
# 保存扩增并添加噪声的图像: augmented_with_noise_800.png
# 保存扩增并添加噪声的图像: augmented_with_noise_801.png
# 保存扩增并添加噪声的图像: augmented_with_noise_802.png
# 保存扩增并添加噪声的图像: augmented_with_noise_803.png
# 保存扩增并添加噪声的图像: augmented_with_noise_804.png
# 保存扩增并添加噪声的图像: augmented_with_noise_805.png
# 保存扩增并添加噪声的图像: augmented_with_noise_806.png
# 保存扩增并添加噪声的图像: augmented_with_noise_807.png
# 保存扩增并添加噪声的图像: augmented_with_noise_808.png
# 保存扩增并添加噪声的图像: augmented_with_noise_809.png
# 保存扩增并添加噪声的图像: augmented_with_noise_810.png
# 保存扩增并添加噪声的图像: augmented_with_noise_811.png
# 保存扩增并添加噪声的图像: augmented_with_noise_812.png
# 保存扩增并添加噪声的图像: augmented_with_noise_813.png
# 保存扩增并添加噪声的图像: augmented_with_noise_814.png
# 保存扩增并添加噪声的图像: augmented_with_noise_815.png
# 保存扩增并添加噪声的图像: augmented_with_noise_816.png
# 保存扩增并添加噪声的图像: augmented_with_noise_817.png
# 保存扩增并添加噪声的图像: augmented_with_noise_818.png
# 保存扩增并添加噪声的图像: augmented_with_noise_819.png
# 保存扩增并添加噪声的图像: augmented_with_noise_820.png
# 保存扩增并添加噪声的图像: augmented_with_noise_821.png
# 保存扩增并添加噪声的图像: augmented_with_noise_822.png
# 保存扩增并添加噪声的图像: augmented_with_noise_823.png
# 保存扩增并添加噪声的图像: augmented_with_noise_824.png
# 保存扩增并添加噪声的图像: augmented_with_noise_825.png
# 保存扩增并添加噪声的图像: augmented_with_noise_826.png
# 保存扩增并添加噪声的图像: augmented_with_noise_827.png
# 保存扩增并添加噪声的图像: augmented_with_noise_828.png
# 保存扩增并添加噪声的图像: augmented_with_noise_829.png
# 保存扩增并添加噪声的图像: augmented_with_noise_830.png
# 保存扩增并添加噪声的图像: augmented_with_noise_831.png
# 保存扩增并添加噪声的图像: augmented_with_noise_832.png
# 保存扩增并添加噪声的图像: augmented_with_noise_833.png
# 保存扩增并添加噪声的图像: augmented_with_noise_834.png
# 保存扩增并添加噪声的图像: augmented_with_noise_835.png
# 保存扩增并添加噪声的图像: augmented_with_noise_836.png
# 保存扩增并添加噪声的图像: augmented_with_noise_837.png
# 保存扩增并添加噪声的图像: augmented_with_noise_838.png
# 保存扩增并添加噪声的图像: augmented_with_noise_839.png
# 保存扩增并添加噪声的图像: augmented_with_noise_840.png
# 保存扩增并添加噪声的图像: augmented_with_noise_841.png
# 保存扩增并添加噪声的图像: augmented_with_noise_842.png
# 保存扩增并添加噪声的图像: augmented_with_noise_843.png
# 保存扩增并添加噪声的图像: augmented_with_noise_844.png
# 保存扩增并添加噪声的图像: augmented_with_noise_845.png
# 保存扩增并添加噪声的图像: augmented_with_noise_846.png
# 保存扩增并添加噪声的图像: augmented_with_noise_847.png
# 保存扩增并添加噪声的图像: augmented_with_noise_848.png
# 保存扩增并添加噪声的图像: augmented_with_noise_849.png
# 保存扩增并添加噪声的图像: augmented_with_noise_850.png
# 保存扩增并添加噪声的图像: augmented_with_noise_851.png
# 保存扩增并添加噪声的图像: augmented_with_noise_852.png
# 保存扩增并添加噪声的图像: augmented_with_noise_853.png
# 保存扩增并添加噪声的图像: augmented_with_noise_854.png
# 保存扩增并添加噪声的图像: augmented_with_noise_855.png
# 保存扩增并添加噪声的图像: augmented_with_noise_856.png
# 保存扩增并添加噪声的图像: augmented_with_noise_857.png
# 保存扩增并添加噪声的图像: augmented_with_noise_858.png
# 保存扩增并添加噪声的图像: augmented_with_noise_859.png
# 保存扩增并添加噪声的图像: augmented_with_noise_860.png
# 保存扩增并添加噪声的图像: augmented_with_noise_861.png
# 保存扩增并添加噪声的图像: augmented_with_noise_862.png
# 保存扩增并添加噪声的图像: augmented_with_noise_863.png
# 保存扩增并添加噪声的图像: augmented_with_noise_864.png
# 保存扩增并添加噪声的图像: augmented_with_noise_865.png
# 保存扩增并添加噪声的图像: augmented_with_noise_866.png
# 保存扩增并添加噪声的图像: augmented_with_noise_867.png
# 保存扩增并添加噪声的图像: augmented_with_noise_868.png
# 保存扩增并添加噪声的图像: augmented_with_noise_869.png
# 保存扩增并添加噪声的图像: augmented_with_noise_870.png
# 保存扩增并添加噪声的图像: augmented_with_noise_871.png
# 保存扩增并添加噪声的图像: augmented_with_noise_872.png
# 保存扩增并添加噪声的图像: augmented_with_noise_873.png
# 保存扩增并添加噪声的图像: augmented_with_noise_874.png
# 保存扩增并添加噪声的图像: augmented_with_noise_875.png
# 保存扩增并添加噪声的图像: augmented_with_noise_876.png
# 保存扩增并添加噪声的图像: augmented_with_noise_877.png
# 保存扩增并添加噪声的图像: augmented_with_noise_878.png
# 保存扩增并添加噪声的图像: augmented_with_noise_879.png
# 保存扩增并添加噪声的图像: augmented_with_noise_880.png
# 保存扩增并添加噪声的图像: augmented_with_noise_881.png
# 保存扩增并添加噪声的图像: augmented_with_noise_882.png
# 保存扩增并添加噪声的图像: augmented_with_noise_883.png
# 保存扩增并添加噪声的图像: augmented_with_noise_884.png
# 保存扩增并添加噪声的图像: augmented_with_noise_885.png
# 保存扩增并添加噪声的图像: augmented_with_noise_886.png
# 保存扩增并添加噪声的图像: augmented_with_noise_887.png
# 保存扩增并添加噪声的图像: augmented_with_noise_888.png
# 保存扩增并添加噪声的图像: augmented_with_noise_889.png
# 保存扩增并添加噪声的图像: augmented_with_noise_890.png
# 保存扩增并添加噪声的图像: augmented_with_noise_891.png
# 保存扩增并添加噪声的图像: augmented_with_noise_892.png
# 保存扩增并添加噪声的图像: augmented_with_noise_893.png
# 保存扩增并添加噪声的图像: augmented_with_noise_894.png
# 保存扩增并添加噪声的图像: augmented_with_noise_895.png
# 保存扩增并添加噪声的图像: augmented_with_noise_896.png
# 保存扩增并添加噪声的图像: augmented_with_noise_897.png
# 保存扩增并添加噪声的图像: augmented_with_noise_898.png
# 保存扩增并添加噪声的图像: augmented_with_noise_899.png
# 保存扩增并添加噪声的图像: augmented_with_noise_900.png
# 保存扩增并添加噪声的图像: augmented_with_noise_901.png
# 保存扩增并添加噪声的图像: augmented_with_noise_902.png
# 保存扩增并添加噪声的图像: augmented_with_noise_903.png
# 保存扩增并添加噪声的图像: augmented_with_noise_904.png
# 保存扩增并添加噪声的图像: augmented_with_noise_905.png
# 保存扩增并添加噪声的图像: augmented_with_noise_906.png
# 保存扩增并添加噪声的图像: augmented_with_noise_907.png
# 保存扩增并添加噪声的图像: augmented_with_noise_908.png
# 保存扩增并添加噪声的图像: augmented_with_noise_909.png
# 保存扩增并添加噪声的图像: augmented_with_noise_910.png
# 保存扩增并添加噪声的图像: augmented_with_noise_911.png
# 保存扩增并添加噪声的图像: augmented_with_noise_912.png
# 保存扩增并添加噪声的图像: augmented_with_noise_913.png
# 保存扩增并添加噪声的图像: augmented_with_noise_914.png
# 保存扩增并添加噪声的图像: augmented_with_noise_915.png
# 保存扩增并添加噪声的图像: augmented_with_noise_916.png
# 保存扩增并添加噪声的图像: augmented_with_noise_917.png
# 保存扩增并添加噪声的图像: augmented_with_noise_918.png
# 保存扩增并添加噪声的图像: augmented_with_noise_919.png
# 保存扩增并添加噪声的图像: augmented_with_noise_920.png
# 保存扩增并添加噪声的图像: augmented_with_noise_921.png
# 保存扩增并添加噪声的图像: augmented_with_noise_922.png
# 保存扩增并添加噪声的图像: augmented_with_noise_923.png
# 保存扩增并添加噪声的图像: augmented_with_noise_924.png
# 保存扩增并添加噪声的图像: augmented_with_noise_925.png
# 保存扩增并添加噪声的图像: augmented_with_noise_926.png
# 保存扩增并添加噪声的图像: augmented_with_noise_927.png
# 保存扩增并添加噪声的图像: augmented_with_noise_928.png
# 保存扩增并添加噪声的图像: augmented_with_noise_929.png
# 保存扩增并添加噪声的图像: augmented_with_noise_930.png
# 保存扩增并添加噪声的图像: augmented_with_noise_931.png
# 保存扩增并添加噪声的图像: augmented_with_noise_932.png
# 保存扩增并添加噪声的图像: augmented_with_noise_933.png
# 保存扩增并添加噪声的图像: augmented_with_noise_934.png
# 保存扩增并添加噪声的图像: augmented_with_noise_935.png
# 保存扩增并添加噪声的图像: augmented_with_noise_936.png
# 保存扩增并添加噪声的图像: augmented_with_noise_937.png
# 保存扩增并添加噪声的图像: augmented_with_noise_938.png
# 保存扩增并添加噪声的图像: augmented_with_noise_939.png
# 保存扩增并添加噪声的图像: augmented_with_noise_940.png
# 保存扩增并添加噪声的图像: augmented_with_noise_941.png
# 保存扩增并添加噪声的图像: augmented_with_noise_942.png
# 保存扩增并添加噪声的图像: augmented_with_noise_943.png
# 保存扩增并添加噪声的图像: augmented_with_noise_944.png
# 保存扩增并添加噪声的图像: augmented_with_noise_945.png
# 保存扩增并添加噪声的图像: augmented_with_noise_946.png
# 保存扩增并添加噪声的图像: augmented_with_noise_947.png
# 保存扩增并添加噪声的图像: augmented_with_noise_948.png
# 保存扩增并添加噪声的图像: augmented_with_noise_949.png
# 保存扩增并添加噪声的图像: augmented_with_noise_950.png
# 保存扩增并添加噪声的图像: augmented_with_noise_951.png
# 保存扩增并添加噪声的图像: augmented_with_noise_952.png
# 保存扩增并添加噪声的图像: augmented_with_noise_953.png
# 保存扩增并添加噪声的图像: augmented_with_noise_954.png
# 保存扩增并添加噪声的图像: augmented_with_noise_955.png
# 保存扩增并添加噪声的图像: augmented_with_noise_956.png
# 保存扩增并添加噪声的图像: augmented_with_noise_957.png
# 保存扩增并添加噪声的图像: augmented_with_noise_958.png
# 保存扩增并添加噪声的图像: augmented_with_noise_959.png
# 保存扩增并添加噪声的图像: augmented_with_noise_960.png
# 保存扩增并添加噪声的图像: augmented_with_noise_961.png
# 保存扩增并添加噪声的图像: augmented_with_noise_962.png
# 保存扩增并添加噪声的图像: augmented_with_noise_963.png
# 保存扩增并添加噪声的图像: augmented_with_noise_964.png
# 保存扩增并添加噪声的图像: augmented_with_noise_965.png
# 保存扩增并添加噪声的图像: augmented_with_noise_966.png
# 保存扩增并添加噪声的图像: augmented_with_noise_967.png
# 保存扩增并添加噪声的图像: augmented_with_noise_968.png
# 保存扩增并添加噪声的图像: augmented_with_noise_969.png
# 保存扩增并添加噪声的图像: augmented_with_noise_970.png
# 保存扩增并添加噪声的图像: augmented_with_noise_971.png
# 保存扩增并添加噪声的图像: augmented_with_noise_972.png
# 保存扩增并添加噪声的图像: augmented_with_noise_973.png
# 保存扩增并添加噪声的图像: augmented_with_noise_974.png
# 保存扩增并添加噪声的图像: augmented_with_noise_975.png
# 保存扩增并添加噪声的图像: augmented_with_noise_976.png
# 保存扩增并添加噪声的图像: augmented_with_noise_977.png
# 保存扩增并添加噪声的图像: augmented_with_noise_978.png
# 保存扩增并添加噪声的图像: augmented_with_noise_979.png
# 保存扩增并添加噪声的图像: augmented_with_noise_980.png
# 保存扩增并添加噪声的图像: augmented_with_noise_981.png
# 保存扩增并添加噪声的图像: augmented_with_noise_982.png
# 保存扩增并添加噪声的图像: augmented_with_noise_983.png
# 保存扩增并添加噪声的图像: augmented_with_noise_984.png
# 保存扩增并添加噪声的图像: augmented_with_noise_985.png
# 保存扩增并添加噪声的图像: augmented_with_noise_986.png
# 保存扩增并添加噪声的图像: augmented_with_noise_987.png
# 保存扩增并添加噪声的图像: augmented_with_noise_988.png
# 保存扩增并添加噪声的图像: augmented_with_noise_989.png
# 保存扩增并添加噪声的图像: augmented_with_noise_990.png
# 保存扩增并添加噪声的图像: augmented_with_noise_991.png
# 保存扩增并添加噪声的图像: augmented_with_noise_992.png
# 保存扩增并添加噪声的图像: augmented_with_noise_993.png
# 保存扩增并添加噪声的图像: augmented_with_noise_994.png
# 保存扩增并添加噪声的图像: augmented_with_noise_995.png
# 保存扩增并添加噪声的图像: augmented_with_noise_996.png
# 保存扩增并添加噪声的图像: augmented_with_noise_997.png
# 保存扩增并添加噪声的图像: augmented_with_noise_998.png
# 保存扩增并添加噪声的图像: augmented_with_noise_999.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1000.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1001.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1002.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1003.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1004.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1005.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1006.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1007.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1008.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1009.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1010.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1011.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1012.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1013.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1014.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1015.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1016.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1017.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1018.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1019.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1020.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1021.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1022.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1023.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1024.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1025.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1026.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1027.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1028.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1029.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1030.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1031.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1032.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1033.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1034.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1035.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1036.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1037.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1038.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1039.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1040.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1041.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1042.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1043.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1044.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1045.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1046.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1047.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1048.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1049.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1050.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1051.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1052.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1053.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1054.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1055.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1056.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1057.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1058.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1059.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1060.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1061.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1062.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1063.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1064.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1065.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1066.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1067.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1068.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1069.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1070.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1071.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1072.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1073.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1074.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1075.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1076.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1077.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1078.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1079.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1080.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1081.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1082.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1083.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1084.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1085.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1086.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1087.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1088.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1089.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1090.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1091.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1092.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1093.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1094.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1095.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1096.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1097.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1098.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1099.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1100.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1101.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1102.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1103.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1104.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1105.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1106.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1107.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1108.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1109.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1110.png
# 保存扩增并添加噪声的图像: augmented_with_noise_1111.png
# 保存扩增并添加噪声的图像: augmented_with_noise_